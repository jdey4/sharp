# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim.lr_scheduler as lr_scheduler
from torch import from_numpy as tnsr
from scipy.stats import bernoulli
import torch.nn as nn
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Proposed model
#
# ![Screenshot 2024-10-30 at 8.42.12 AM.png](attachment:4e44200c-ef6a-47b1-bb3b-782bada706fc.png)

# %% [markdown]
# ## Experiment 2:
# ### Observation: During sleep Hippocampus feeds compressed data to Neo-cortex.
#
# ### Hypothesis: Distributing learning to Neo-cortex in compressed form improves performance.

# %%
def _get_member(community, n_members, clockwise=True):
    seq = chr(community*n_members + ord('A'))
    
    if clockwise:
        next_token = chr(community*n_members + ord('A') + 1)
    else:
        next_token = chr(community*n_members + ord('A') + n_members-1)

    for _ in range(n_members-1):
        seq += next_token

        if clockwise:
            next_token = chr(ord(next_token) + 1)
        else:
            next_token = chr(ord(next_token) - 1)

    seq += seq[0]
    return seq 

def get_sequence(n_samples, n_community, n_members, random_state=0):
    
    """
    Generate data sequence divided into communities.

    Parameters
    ----------
    n_samples : int
        Total number of tokens to sample.
    n_community : int
        Total number of community.
    n_members : int
        Total number of members in each community.
    random_state : int, RandomState instance, default=None
        Determines random number generation for dataset creation. Pass an int
        for reproducible output across multiple function calls.

    Returns
    -------
    out : array of shape [n_samples]
        The generated sequence of tokens.
    """

    if random_state != None:
        np.random.seed(random_state)

    visits = []
    direction = []
    total_community_visit = int(np.ceil(n_samples/n_members))
    
    for ii in range(total_community_visit):
        visits.append(
            np.random.choice(n_community)
        )

        if ii == 0 or ii == 1:
            direction.append(True)
        elif visits[-2] == visits[-1] and visits[-3] == visits[-1]:
            direction.append(False)
        elif visits[-2] != visits[-1] and visits[-3] == visits[-1]:
            direction.append(True)
        elif visits[-2] == visits[-1] and visits[-3] != visits[-1]:
            direction.append(True)
        else:
            direction.append(False)

    out = ''
    for ii, community in enumerate(visits):
        out += _get_member(community, n_members, clockwise=direction[ii]) + chr(ord('A')+n_community*n_members)

    return out[:n_samples]

# %%
n_community = 2
n_members = 3

tokens = []

for ii in range(n_community*n_members+1):
    tokens.append(
        chr(ord('A')+ii)
    )

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size_hippocampus, hidden_size_cortex, memory_buffer, num_layers_hippocampus=1, num_layers_cortex=1):
        super(RNN, self).__init__()
        self.cortex_hidden = torch.zeros(1, 1, hidden_size_cortex)
        
        self.hidden_size_cortex = hidden_size_cortex
        self.hidden_size_hippocampus = hidden_size_hippocampus
        self.memory_buffer = memory_buffer
        self.rnn_hippocampus = nn.RNN(input_size+hidden_size_cortex, hidden_size_hippocampus, num_layers_hippocampus, batch_first=True)
        self.rnn_cortex = nn.RNN(input_size, hidden_size_cortex, num_layers_cortex, batch_first=True)
        
        self.fc = nn.Linear(hidden_size_hippocampus, len(tokens))

        self.buffer_encoder_layer1 = nn.Linear(memory_buffer, 3*len(tokens))
        self.buffer_encoder_layer2 = nn.Linear(3*len(tokens), len(tokens))
        
    def forward(self, x, h0=None, hc=None, sleep=False, compress=False, memory_replay=None):
        if sleep:
            if compress:
                out = self.buffer_encoder_layer1(memory_replay)
                out = nn.functional.relu(out)
                out = self.buffer_encoder_layer2(out)
                # out = nn.functional.relu(out)
                out = nn.functional.softmax(out, dim=2)
            else:
                out = x.clone()

            # print(out)
            #########################################################
            if hc == None:
                cortex_out, hc = self.rnn_cortex(out)
            else:
                cortex_out, hc = self.rnn_cortex(out, hc)

            # print(cortex_out)
            x = torch.cat((x,cortex_out), dim=2)
                
            if h0 == None:
                out, h0 = self.rnn_hippocampus(x)
            else:   
                out, h0 = self.rnn_hippocampus(x, h0)
    
            out = self.fc(out)
        else:
            x = torch.cat((x,self.cortex_hidden), dim=2)
                
            if h0 == None:
                out, h0 = self.rnn_hippocampus(x)
            else:   
                out, h0 = self.rnn_hippocampus(x, h0)
    
            out = self.fc(out)
        
        
 
        # else:
        #     x = torch.cat((x,self.cortex_hidden), dim=2)
        #     if h0 == None:
        #         out, h0 = self.rnn_hippocampus(x)
        #     else:   
        #         out, h0 = self.rnn_hippocampus(x, h0)
            
        if sleep:
            return out[:,-1,:], h0, hc

        return out[:,-1,:], h0

# %%
class Dataset_converter(Dataset):
    def __init__(self, data, working_memory=1, short_term_memory=8):
        
        one_hot_encoded = np.zeros((len(data), len(tokens)), dtype=float)
        for ii, token in enumerate(data):
            one_hot_encoded[ii,ord(token)-65] = 1
        
        self.X = np.zeros((((len(data)-working_memory-short_term_memory)), short_term_memory, len(tokens)*working_memory))
        self.y = np.zeros((((len(data)-working_memory-short_term_memory)), len(tokens)))

        for ii in range(self.X.shape[0]):
            for jj in range(self.X.shape[1]):
                for kk in range(working_memory):
                    self.X[ii,jj,kk*len(tokens):(kk+1)*len(tokens)] = \
                    one_hot_encoded[ii+jj+kk,:]
                    
            self.y[ii] = \
                one_hot_encoded[ii+jj+kk+1,:]

        self.X = tnsr(self.X).float()
        self.y = tnsr(self.y).float()

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

# %%
def generate_sleep_samples(main_model, n_samples):
    seq = ''
    idx = torch.randint(0, len(tokens), (1,)) [0]
    X_hat = torch.zeros(len(tokens),dtype=torch.float32)
    X_hat[idx] = 1.0
    
    for ii in range(n_samples+50):
        if ii == 0:
            # seq += tokens[idx]        
            X_hat, mem = main_model(X_hat.reshape(1,1,-1))
        else:
            X_hat, mem = main_model(X_hat, mem)
    
        # mem = mem + 1e-1*torch.rand(mem.shape)
        # X_hat = torch.tensor(X_hat, requires_grad=False)
        X_hat = torch.nn.functional.softmax(X_hat, dim=1)
        dist_categ = torch.distributions.Categorical(probs=X_hat.reshape(-1))
        idx = dist_categ.sample()
    
        X_hat = torch.zeros(len(tokens),dtype=torch.float32)
        X_hat[idx] = 1.0
        X_hat = X_hat.reshape(1,1,-1)   
    
        if ii>50:
            seq += tokens[idx]

    return seq

# %%
### initial training ###
total_samples = 100000
initial_training_sample = 20000
sleep_samples = 10000
working_memory = 1
short_term_memory = 1
hidden_size_hippocampus = 10
hidden_size_cortex = 100
memory_buffer = 10*len(tokens)
num_layers = 1
lr = 9e-4
lr_sleep = 9e-4
reps = 5
test_acc = [[] for _ in range(reps)]

for rep in range(reps):
    print('Doing rep ', rep)
    
    data = get_sequence(total_samples, 2, 3, random_state=rep)
    # data = pd.read_csv("../Seq_500000.txt")['seq'][0]
    
    
    data_set = Dataset_converter(data[:initial_training_sample], working_memory, short_term_memory)
    
    main_model = RNN(len(tokens)*working_memory, hidden_size_hippocampus, hidden_size_cortex, memory_buffer, num_layers)
    main_model.rnn_cortex.requires_grad = False
    main_model.buffer_encoder_layer1.requires_grad = False
    main_model.buffer_encoder_layer2.requires_grad = False
    
    train_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    
    optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    criterion = torch.nn.CrossEntropyLoss()
    
    total = 0
    correct = np.zeros(1000,dtype=float)
    for X, y in train_loader:
        optimizer.zero_grad()
    
        if total == 0:
            predicted_y, hidden = main_model(X)
        else:
            predicted_y, hidden = main_model(X, mem)
            
        loss = criterion(predicted_y, y)
        loss.backward(retain_graph=True)
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            total += 1
            if true_y == estimated_y:
                    correct[total%1000] = 1
            else:
                correct[total%1000] = 0
    
            test_acc[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if total%1000 == 0:
                print(f'Iter : {total+1}, loss: {loss:.4f}, accuracy: {test_acc[rep][-1]:.4f}')


    print('Going to sleep ...')
    data_sleep = generate_sleep_samples(main_model, sleep_samples)
    main_model.rnn_cortex.requires_grad = True
    main_model.buffer_encoder_layer1.requires_grad = True
    main_model.buffer_encoder_layer2.requires_grad = True
    
    data_set = Dataset_converter(data_sleep, memory_buffer//len(tokens), short_term_memory)
    sleep_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    optimizer = torch.optim.Adam([
                                    {'params': main_model.rnn_hippocampus.parameters(), 'weight_decay': 1e-8},  # Apply weight decay to hippocampus
                                    {'params': main_model.rnn_cortex.parameters()},  # No weight decay for cortex
                                    {'params': main_model.fc.parameters()},
                                    {'params': main_model.buffer_encoder_layer1.parameters()},
                                    {'params': main_model.buffer_encoder_layer2.parameters()},
                                ], lr=lr_sleep)
    # optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    
    criterion = torch.nn.CrossEntropyLoss()
    sleep_iter = 0
    
    for X, y in sleep_loader:
        optimizer.zero_grad()
        y = X[0][:,len(tokens):2*len(tokens)].clone()
        
        if sleep_iter == 0:
            predicted_y, hidden, hidden_sleep = main_model(X[0][:,:len(tokens)].reshape(1,1,-1), sleep=True, compress=True, memory_replay=X)
        else:
            predicted_y, hidden, hidden_sleep = main_model(X[0][:,:len(tokens)].reshape(1,1,-1), mem, mem_, sleep=True, compress=True, memory_replay=X)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            mem_ = hidden_sleep.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            sleep_iter += 1
            if true_y == estimated_y:
                    correct[sleep_iter%1000] = 1
            else:
                correct[sleep_iter%1000] = 0
    
            test_acc[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if sleep_iter%1000 == 0:
                print(f'Iter : {sleep_iter+1}, loss: {loss:.4f}, accuracy: {test_acc[rep][-1]:.4f}')


    print('Going to awake phase ...')
    # data_sleep = generate_sleep_samples(main_model, sleep_samples)
    main_model.rnn_cortex.requires_grad = False
    main_model.buffer_encoder_layer1.requires_grad = False
    main_model.buffer_encoder_layer2.requires_grad = False
    data_set = Dataset_converter(data[initial_training_sample:], working_memory, short_term_memory)
    test_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    optimizer = torch.optim.SGD(main_model.parameters(), lr=5e-4, momentum=0.95)
    criterion = torch.nn.CrossEntropyLoss()
    sleep_iter = 0
    
    for X, y in test_loader:
        optimizer.zero_grad()
    
        if sleep_iter == 0:
            predicted_y, hidden, hidden_sleep = main_model(X, sleep=True)
        else:
            predicted_y, hidden, hidden_sleep = main_model(X, mem, mem_, sleep=True)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            mem_ = hidden_sleep.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            sleep_iter += 1
            if true_y == estimated_y:
                    correct[sleep_iter%1000] = 1
            else:
                correct[sleep_iter%1000] = 0
    
            test_acc[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if sleep_iter%1000 == 0:
                print(f'Iter : {sleep_iter+1}, loss: {loss:.4f}, accuracy: {test_acc[rep][-1]:.4f}')
# Out:
# Doing rep  0
# Iter : 1001, loss: 1.3603, accuracy: 0.3740
# Iter : 2001, loss: 1.2191, accuracy: 0.6900
# Iter : 3001, loss: 0.5907, accuracy: 0.7920
# Iter : 4001, loss: 1.0440, accuracy: 0.8050
# Iter : 5001, loss: 1.1568, accuracy: 0.8070
# Iter : 6001, loss: 1.0586, accuracy: 0.7970
# Iter : 7001, loss: 0.4883, accuracy: 0.7990
# Iter : 8001, loss: 0.9308, accuracy: 0.8080
# Iter : 9001, loss: 0.7964, accuracy: 0.7930
# Iter : 10001, loss: 0.6351, accuracy: 0.8080
# Iter : 11001, loss: 0.6382, accuracy: 0.7950
# Iter : 12001, loss: 0.9820, accuracy: 0.8110
# Iter : 13001, loss: 0.5475, accuracy: 0.8070
# Iter : 14001, loss: 0.7201, accuracy: 0.7860
# Iter : 15001, loss: 0.3756, accuracy: 0.7850
# Iter : 16001, loss: 0.8427, accuracy: 0.7980
# Iter : 17001, loss: 0.5415, accuracy: 0.7940
# Iter : 18001, loss: 1.0787, accuracy: 0.7890
# Iter : 19001, loss: 0.8285, accuracy: 0.7760
# Going to sleep ...
# Iter : 1001, loss: 0.0017, accuracy: 0.7830
# Iter : 2001, loss: 0.1357, accuracy: 0.9230
# Iter : 3001, loss: 0.0134, accuracy: 0.9680
# Iter : 4001, loss: 0.0306, accuracy: 0.9780
# Iter : 5001, loss: 0.0042, accuracy: 0.9780
# Iter : 6001, loss: 0.0053, accuracy: 0.9860
# Iter : 7001, loss: 0.0009, accuracy: 0.9950
# Iter : 8001, loss: 0.0027, accuracy: 0.9940
# Iter : 9001, loss: 0.0019, accuracy: 0.9750
# Going to awake phase ...
# Iter : 1001, loss: 0.8830, accuracy: 0.6480
# Iter : 2001, loss: 1.0539, accuracy: 0.8040
# Iter : 3001, loss: 0.8505, accuracy: 0.8270
# Iter : 4001, loss: 0.6519, accuracy: 0.8100
# Iter : 5001, loss: 0.9546, accuracy: 0.8170
# Iter : 6001, loss: 0.6060, accuracy: 0.8290
# Iter : 7001, loss: 0.7517, accuracy: 0.8390
# Iter : 8001, loss: 0.5697, accuracy: 0.8200
# Iter : 9001, loss: 0.5923, accuracy: 0.8610
# Iter : 10001, loss: 0.9999, accuracy: 0.8460
# Iter : 11001, loss: 0.8006, accuracy: 0.8630
# Iter : 12001, loss: 0.6684, accuracy: 0.8490
# Iter : 13001, loss: 0.4259, accuracy: 0.8640
# Iter : 14001, loss: 0.9432, accuracy: 0.8530
# Iter : 15001, loss: 0.8183, accuracy: 0.8390
# Iter : 16001, loss: 1.1115, accuracy: 0.8510
# Iter : 17001, loss: 0.7100, accuracy: 0.8690
# Iter : 18001, loss: 0.7429, accuracy: 0.8670
# Iter : 19001, loss: 0.5352, accuracy: 0.8780
# Iter : 20001, loss: 1.0283, accuracy: 0.8750
# Iter : 21001, loss: 0.5630, accuracy: 0.8840
# Iter : 22001, loss: 0.7010, accuracy: 0.8870
# Iter : 23001, loss: 0.4893, accuracy: 0.8830
# Iter : 24001, loss: 0.5959, accuracy: 0.8920
# Iter : 25001, loss: 0.6752, accuracy: 0.8700
# Iter : 26001, loss: 1.0170, accuracy: 0.8780
# Iter : 27001, loss: 0.9866, accuracy: 0.8850
# Iter : 28001, loss: 0.9160, accuracy: 0.8990
# Iter : 29001, loss: 0.6346, accuracy: 0.8970
# Iter : 30001, loss: 0.5667, accuracy: 0.8900
# Iter : 31001, loss: 0.6828, accuracy: 0.8940
# Iter : 32001, loss: 0.5902, accuracy: 0.8970
# Iter : 33001, loss: 0.7957, accuracy: 0.8980
# Iter : 34001, loss: 0.6613, accuracy: 0.8990
# Iter : 35001, loss: 0.5554, accuracy: 0.8860
# Iter : 36001, loss: 0.9000, accuracy: 0.8880
# Iter : 37001, loss: 1.0661, accuracy: 0.9040
# Iter : 38001, loss: 0.6771, accuracy: 0.8810
# Iter : 39001, loss: 0.7128, accuracy: 0.8960
# Iter : 40001, loss: 0.8582, accuracy: 0.8800
# Iter : 41001, loss: 0.7749, accuracy: 0.8960
# Iter : 42001, loss: 0.7930, accuracy: 0.9010
# Iter : 43001, loss: 0.7466, accuracy: 0.8950
# Iter : 44001, loss: 0.8781, accuracy: 0.8960
# Iter : 45001, loss: 0.4631, accuracy: 0.9030
# Iter : 46001, loss: 0.6818, accuracy: 0.8940
# Iter : 47001, loss: 0.7600, accuracy: 0.8830
# Iter : 48001, loss: 0.7824, accuracy: 0.8970
# Iter : 49001, loss: 0.8416, accuracy: 0.9090
# Iter : 50001, loss: 0.6986, accuracy: 0.8970
# Iter : 51001, loss: 0.8861, accuracy: 0.9070
# Iter : 52001, loss: 0.8491, accuracy: 0.8850
# Iter : 53001, loss: 0.5231, accuracy: 0.9030
# Iter : 54001, loss: 0.7689, accuracy: 0.8930
# Iter : 55001, loss: 0.7362, accuracy: 0.9010
# Iter : 56001, loss: 0.6895, accuracy: 0.8970
# Iter : 57001, loss: 0.9367, accuracy: 0.9000
# Iter : 58001, loss: 0.8172, accuracy: 0.9090
# Iter : 59001, loss: 0.9756, accuracy: 0.9030
# Iter : 60001, loss: 1.1513, accuracy: 0.8630
# Iter : 61001, loss: 0.6437, accuracy: 0.8650
# Iter : 62001, loss: 0.7995, accuracy: 0.8790
# Iter : 63001, loss: 0.7087, accuracy: 0.8650
# Iter : 64001, loss: 0.9948, accuracy: 0.8920
# Iter : 65001, loss: 0.8392, accuracy: 0.8720
# Iter : 66001, loss: 1.0893, accuracy: 0.8860
# Iter : 67001, loss: 0.5103, accuracy: 0.8800
# Iter : 68001, loss: 1.0497, accuracy: 0.8680
# Iter : 69001, loss: 0.4689, accuracy: 0.8760
# Iter : 70001, loss: 0.7662, accuracy: 0.8900
# Iter : 71001, loss: 0.7684, accuracy: 0.8770
# Iter : 72001, loss: 0.8523, accuracy: 0.8820
# Iter : 73001, loss: 1.1685, accuracy: 0.8850
# Iter : 74001, loss: 0.9002, accuracy: 0.9030
# Iter : 75001, loss: 1.0675, accuracy: 0.8880
# Iter : 76001, loss: 0.4363, accuracy: 0.9090
# Iter : 77001, loss: 0.9362, accuracy: 0.8680
# Iter : 78001, loss: 0.8159, accuracy: 0.8930
# Iter : 79001, loss: 0.8006, accuracy: 0.8870
# Doing rep  1
# Iter : 1001, loss: 0.7158, accuracy: 0.4480
# Iter : 2001, loss: 0.7419, accuracy: 0.6790
# Iter : 3001, loss: 0.5919, accuracy: 0.7830
# Iter : 4001, loss: 0.4798, accuracy: 0.8030
# Iter : 5001, loss: 0.2459, accuracy: 0.8100
# Iter : 6001, loss: 0.6411, accuracy: 0.7950
# Iter : 7001, loss: 0.5237, accuracy: 0.7980
# Iter : 8001, loss: 0.6130, accuracy: 0.7990
# Iter : 9001, loss: 0.8697, accuracy: 0.7850
# Iter : 10001, loss: 1.0360, accuracy: 0.7910
# Iter : 11001, loss: 0.5767, accuracy: 0.8190
# Iter : 12001, loss: 0.5649, accuracy: 0.8060
# Iter : 13001, loss: 0.7347, accuracy: 0.7950
# Iter : 14001, loss: 0.4776, accuracy: 0.8000
# Iter : 15001, loss: 0.8879, accuracy: 0.7910
# Iter : 16001, loss: 0.8969, accuracy: 0.7930
# Iter : 17001, loss: 0.9413, accuracy: 0.7930
# Iter : 18001, loss: 0.6532, accuracy: 0.8020
# Iter : 19001, loss: 0.5606, accuracy: 0.7980
# Going to sleep ...
# Iter : 1001, loss: 0.0560, accuracy: 0.8520
# Iter : 2001, loss: 0.1156, accuracy: 0.9540
# Iter : 3001, loss: 0.0027, accuracy: 0.9700
# Iter : 4001, loss: 0.0009, accuracy: 0.9970
# Iter : 5001, loss: 0.0217, accuracy: 0.9810
# Iter : 6001, loss: 0.0058, accuracy: 0.9920
# Iter : 7001, loss: 0.3077, accuracy: 0.9960
# Iter : 8001, loss: 0.0069, accuracy: 0.9780
# Iter : 9001, loss: 0.0069, accuracy: 0.9950
# Going to awake phase ...
# Iter : 1001, loss: 0.5176, accuracy: 0.7130
# Iter : 2001, loss: 0.6942, accuracy: 0.8020
# Iter : 3001, loss: 0.6264, accuracy: 0.8480
# Iter : 4001, loss: 0.6601, accuracy: 0.8620
# Iter : 5001, loss: 0.5999, accuracy: 0.8660
# Iter : 6001, loss: 0.4336, accuracy: 0.8690
# Iter : 7001, loss: 0.6877, accuracy: 0.8740
# Iter : 8001, loss: 0.6074, accuracy: 0.8970
# Iter : 9001, loss: 0.8425, accuracy: 0.8980
# Iter : 10001, loss: 0.6386, accuracy: 0.9040
# Iter : 11001, loss: 0.9310, accuracy: 0.8930
# Iter : 12001, loss: 0.8897, accuracy: 0.8930
# Iter : 13001, loss: 0.4555, accuracy: 0.9080
# Iter : 14001, loss: 0.7718, accuracy: 0.9040
# Iter : 15001, loss: 0.7826, accuracy: 0.9020
# Iter : 16001, loss: 0.8472, accuracy: 0.8950
# Iter : 17001, loss: 0.8115, accuracy: 0.8970
# Iter : 18001, loss: 0.7460, accuracy: 0.9040
# Iter : 19001, loss: 0.8481, accuracy: 0.8960
# Iter : 20001, loss: 0.5311, accuracy: 0.9100
# Iter : 21001, loss: 0.7403, accuracy: 0.9060
# Iter : 22001, loss: 0.8564, accuracy: 0.8960
# Iter : 23001, loss: 0.8812, accuracy: 0.8950
# Iter : 24001, loss: 0.5491, accuracy: 0.9090
# Iter : 25001, loss: 1.1093, accuracy: 0.9120
# Iter : 26001, loss: 0.9097, accuracy: 0.9090
# Iter : 27001, loss: 1.0583, accuracy: 0.9030
# Iter : 28001, loss: 0.6667, accuracy: 0.8930
# Iter : 29001, loss: 0.6532, accuracy: 0.8900
# Iter : 30001, loss: 0.5591, accuracy: 0.9100
# Iter : 31001, loss: 0.4745, accuracy: 0.9050
# Iter : 32001, loss: 0.6383, accuracy: 0.8940
# Iter : 33001, loss: 0.5559, accuracy: 0.9080
# Iter : 34001, loss: 0.7513, accuracy: 0.9030
# Iter : 35001, loss: 0.7481, accuracy: 0.8830
# Iter : 36001, loss: 0.8730, accuracy: 0.9090
# Iter : 37001, loss: 0.7216, accuracy: 0.8960
# Iter : 38001, loss: 0.8034, accuracy: 0.9010
# Iter : 39001, loss: 0.8853, accuracy: 0.9000
# Iter : 40001, loss: 0.6852, accuracy: 0.8930
# Iter : 41001, loss: 0.6874, accuracy: 0.8950
# Iter : 42001, loss: 0.5230, accuracy: 0.9000
# Iter : 43001, loss: 0.8498, accuracy: 0.9030
# Iter : 44001, loss: 0.5897, accuracy: 0.9070
# Iter : 45001, loss: 1.0252, accuracy: 0.8990
# Iter : 46001, loss: 0.6121, accuracy: 0.8930
# Iter : 47001, loss: 0.9189, accuracy: 0.9020
# Iter : 48001, loss: 0.8780, accuracy: 0.8990
# Iter : 49001, loss: 0.7253, accuracy: 0.8950
# Iter : 50001, loss: 0.6938, accuracy: 0.9130
# Iter : 51001, loss: 0.8752, accuracy: 0.8980
# Iter : 52001, loss: 0.5650, accuracy: 0.9080
# Iter : 53001, loss: 0.4659, accuracy: 0.9150
# Iter : 54001, loss: 0.7058, accuracy: 0.8920
# Iter : 55001, loss: 0.5862, accuracy: 0.9050
# Iter : 56001, loss: 0.5786, accuracy: 0.8950
# Iter : 57001, loss: 0.4943, accuracy: 0.8970
# Iter : 58001, loss: 0.9791, accuracy: 0.9070
# Iter : 59001, loss: 0.3427, accuracy: 0.8990
# Iter : 60001, loss: 1.0316, accuracy: 0.8900
# Iter : 61001, loss: 0.5046, accuracy: 0.9190
# Iter : 62001, loss: 0.8042, accuracy: 0.8980
# Iter : 63001, loss: 0.7763, accuracy: 0.8780
# Iter : 64001, loss: 0.3437, accuracy: 0.9170
# Iter : 65001, loss: 0.5449, accuracy: 0.9030
# Iter : 66001, loss: 0.4955, accuracy: 0.9020
# Iter : 67001, loss: 0.5863, accuracy: 0.8940
# Iter : 68001, loss: 1.0395, accuracy: 0.9120
# Iter : 69001, loss: 0.4804, accuracy: 0.9010
# Iter : 70001, loss: 0.7418, accuracy: 0.8910
# Iter : 71001, loss: 0.6148, accuracy: 0.9090
# Iter : 72001, loss: 0.7270, accuracy: 0.8970
# Iter : 73001, loss: 0.8884, accuracy: 0.9130
# Iter : 74001, loss: 0.7735, accuracy: 0.9080
# Iter : 75001, loss: 0.7029, accuracy: 0.8970
# Iter : 76001, loss: 0.7297, accuracy: 0.8930
# Iter : 77001, loss: 0.8316, accuracy: 0.9100
# Iter : 78001, loss: 0.6964, accuracy: 0.8890
# Iter : 79001, loss: 0.5889, accuracy: 0.8940
# Doing rep  2
# Iter : 1001, loss: 1.3363, accuracy: 0.4210
# Iter : 2001, loss: 0.4169, accuracy: 0.6600
# Iter : 3001, loss: 0.5388, accuracy: 0.7820
# Iter : 4001, loss: 0.4742, accuracy: 0.8170
# Iter : 5001, loss: 0.6033, accuracy: 0.7980
# Iter : 6001, loss: 0.5519, accuracy: 0.7870
# Iter : 7001, loss: 0.8536, accuracy: 0.7920
# Iter : 8001, loss: 0.5341, accuracy: 0.7980
# Iter : 9001, loss: 0.4344, accuracy: 0.8080
# Iter : 10001, loss: 0.5092, accuracy: 0.8050
# Iter : 11001, loss: 0.6678, accuracy: 0.8030
# Iter : 12001, loss: 0.5088, accuracy: 0.8030
# Iter : 13001, loss: 0.8078, accuracy: 0.8050
# Iter : 14001, loss: 1.1094, accuracy: 0.8010
# Iter : 15001, loss: 0.6906, accuracy: 0.8060
# Iter : 16001, loss: 0.3281, accuracy: 0.8120
# Iter : 17001, loss: 0.7455, accuracy: 0.8110
# Iter : 18001, loss: 0.9982, accuracy: 0.8010
# Iter : 19001, loss: 0.7454, accuracy: 0.7970
# Going to sleep ...
# Iter : 1001, loss: 0.0540, accuracy: 0.8380
# Iter : 2001, loss: 0.2224, accuracy: 0.9430
# Iter : 3001, loss: 0.0032, accuracy: 0.9760
# Iter : 4001, loss: 0.0332, accuracy: 0.9840
# Iter : 5001, loss: 0.0004, accuracy: 0.9730
# Iter : 6001, loss: 0.0031, accuracy: 0.9550
# Iter : 7001, loss: 0.0268, accuracy: 0.9830
# Iter : 8001, loss: 0.0493, accuracy: 0.9720
# Iter : 9001, loss: 0.0026, accuracy: 0.9700
# Going to awake phase ...
# Iter : 1001, loss: 1.0357, accuracy: 0.7400
# Iter : 2001, loss: 0.8460, accuracy: 0.7930
# Iter : 3001, loss: 0.6789, accuracy: 0.7980
# Iter : 4001, loss: 0.5585, accuracy: 0.7990
# Iter : 5001, loss: 0.7654, accuracy: 0.8070
# Iter : 6001, loss: 0.6050, accuracy: 0.8170
# Iter : 7001, loss: 0.4719, accuracy: 0.7950
# Iter : 8001, loss: 0.8183, accuracy: 0.8060
# Iter : 9001, loss: 0.9335, accuracy: 0.7950
# Iter : 10001, loss: 0.4742, accuracy: 0.7900
# Iter : 11001, loss: 0.5837, accuracy: 0.7960
# Iter : 12001, loss: 0.9161, accuracy: 0.8100
# Iter : 13001, loss: 0.6839, accuracy: 0.7840
# Iter : 14001, loss: 0.4856, accuracy: 0.8070
# Iter : 15001, loss: 0.8739, accuracy: 0.8120
# Iter : 16001, loss: 0.9452, accuracy: 0.8170
# Iter : 17001, loss: 0.7888, accuracy: 0.8040
# Iter : 18001, loss: 0.5652, accuracy: 0.8050
# Iter : 19001, loss: 0.7426, accuracy: 0.8110
# Iter : 20001, loss: 0.7295, accuracy: 0.7940
# Iter : 21001, loss: 0.7645, accuracy: 0.7950
# Iter : 22001, loss: 1.3429, accuracy: 0.8280
# Iter : 23001, loss: 0.5891, accuracy: 0.8000
# Iter : 24001, loss: 0.4576, accuracy: 0.8020
# Iter : 25001, loss: 0.5567, accuracy: 0.7860
# Iter : 26001, loss: 0.8544, accuracy: 0.8080
# Iter : 27001, loss: 0.6423, accuracy: 0.7990
# Iter : 28001, loss: 1.0146, accuracy: 0.8100
# Iter : 29001, loss: 1.0954, accuracy: 0.8250
# Iter : 30001, loss: 0.4788, accuracy: 0.8070
# Iter : 31001, loss: 0.5975, accuracy: 0.8130
# Iter : 32001, loss: 0.5052, accuracy: 0.8240
# Iter : 33001, loss: 1.0097, accuracy: 0.8210
# Iter : 34001, loss: 0.6263, accuracy: 0.8050
# Iter : 35001, loss: 0.8253, accuracy: 0.8140
# Iter : 36001, loss: 0.7459, accuracy: 0.8040
# Iter : 37001, loss: 0.6385, accuracy: 0.7880
# Iter : 38001, loss: 0.7993, accuracy: 0.8080
# Iter : 39001, loss: 0.6818, accuracy: 0.8070
# Iter : 40001, loss: 0.8509, accuracy: 0.8260
# Iter : 41001, loss: 0.7573, accuracy: 0.8440
# Iter : 42001, loss: 0.8038, accuracy: 0.8240
# Iter : 43001, loss: 0.4714, accuracy: 0.8390
# Iter : 44001, loss: 0.5409, accuracy: 0.8520
# Iter : 45001, loss: 0.7906, accuracy: 0.8350
# Iter : 46001, loss: 0.9448, accuracy: 0.8640
# Iter : 47001, loss: 0.5672, accuracy: 0.8380
# Iter : 48001, loss: 0.7596, accuracy: 0.8360
# Iter : 49001, loss: 0.5482, accuracy: 0.8680
# Iter : 50001, loss: 0.4097, accuracy: 0.8690
# Iter : 51001, loss: 0.5008, accuracy: 0.8710
# Iter : 52001, loss: 0.5488, accuracy: 0.8740
# Iter : 53001, loss: 0.7254, accuracy: 0.8790
# Iter : 54001, loss: 0.8655, accuracy: 0.8740
# Iter : 55001, loss: 0.7212, accuracy: 0.8810
# Iter : 56001, loss: 0.9075, accuracy: 0.8470
# Iter : 57001, loss: 0.7250, accuracy: 0.8230
# Iter : 58001, loss: 0.4019, accuracy: 0.8520
# Iter : 59001, loss: 1.0437, accuracy: 0.8720
# Iter : 60001, loss: 0.5160, accuracy: 0.8580
# Iter : 61001, loss: 0.6394, accuracy: 0.8750
# Iter : 62001, loss: 0.4635, accuracy: 0.9040
# Iter : 63001, loss: 0.9531, accuracy: 0.8830
# Iter : 64001, loss: 0.6438, accuracy: 0.8880
# Iter : 65001, loss: 0.7068, accuracy: 0.9000
# Iter : 66001, loss: 0.7385, accuracy: 0.9020
# Iter : 67001, loss: 0.7197, accuracy: 0.8820
# Iter : 68001, loss: 1.0323, accuracy: 0.9040
# Iter : 69001, loss: 0.6258, accuracy: 0.8910
# Iter : 70001, loss: 0.9153, accuracy: 0.8760
# Iter : 71001, loss: 0.6589, accuracy: 0.8820
# Iter : 72001, loss: 1.0382, accuracy: 0.8820
# Iter : 73001, loss: 0.5171, accuracy: 0.8990
# Iter : 74001, loss: 0.5124, accuracy: 0.8920
# Iter : 75001, loss: 0.9421, accuracy: 0.9020
# Iter : 76001, loss: 1.0528, accuracy: 0.8980
# Iter : 77001, loss: 0.5646, accuracy: 0.9060
# Iter : 78001, loss: 0.5819, accuracy: 0.8930
# Iter : 79001, loss: 0.5976, accuracy: 0.8960
# Doing rep  3
# Iter : 1001, loss: 0.8762, accuracy: 0.4240
# Iter : 2001, loss: 0.5767, accuracy: 0.7560
# Iter : 3001, loss: 0.9486, accuracy: 0.7890
# Iter : 4001, loss: 0.9183, accuracy: 0.8120
# Iter : 5001, loss: 0.9540, accuracy: 0.7930
# Iter : 6001, loss: 0.6719, accuracy: 0.8110
# Iter : 7001, loss: 0.5496, accuracy: 0.8000
# Iter : 8001, loss: 0.3717, accuracy: 0.7930
# Iter : 9001, loss: 1.0795, accuracy: 0.7980
# Iter : 10001, loss: 0.6526, accuracy: 0.7870
# Iter : 11001, loss: 1.2170, accuracy: 0.7910
# Iter : 12001, loss: 0.8950, accuracy: 0.7840
# Iter : 13001, loss: 0.3403, accuracy: 0.8290
# Iter : 14001, loss: 0.3538, accuracy: 0.8150
# Iter : 15001, loss: 0.5002, accuracy: 0.8230
# Iter : 16001, loss: 0.7301, accuracy: 0.7910
# Iter : 17001, loss: 0.4420, accuracy: 0.8170
# Iter : 18001, loss: 0.3766, accuracy: 0.8100
# Iter : 19001, loss: 0.9633, accuracy: 0.8020
# Going to sleep ...
# Iter : 1001, loss: 0.0101, accuracy: 0.8700
# Iter : 2001, loss: 0.0476, accuracy: 0.9490
# Iter : 3001, loss: 0.0343, accuracy: 0.9770
# Iter : 4001, loss: 0.0319, accuracy: 0.9520
# Iter : 5001, loss: 0.0088, accuracy: 0.9690
# Iter : 6001, loss: 1.5679, accuracy: 0.9790
# Iter : 7001, loss: 0.0159, accuracy: 0.9630
# Iter : 8001, loss: 0.0053, accuracy: 0.9790
# Iter : 9001, loss: 0.0076, accuracy: 0.9840
# Going to awake phase ...
# Iter : 1001, loss: 1.0512, accuracy: 0.6960
# Iter : 2001, loss: 1.1280, accuracy: 0.8160
# Iter : 3001, loss: 0.6018, accuracy: 0.8400
# Iter : 4001, loss: 0.6795, accuracy: 0.8380
# Iter : 5001, loss: 0.6179, accuracy: 0.8570
# Iter : 6001, loss: 0.8340, accuracy: 0.8680
# Iter : 7001, loss: 0.5801, accuracy: 0.8630
# Iter : 8001, loss: 0.9833, accuracy: 0.8730
# Iter : 9001, loss: 0.5395, accuracy: 0.8740
# Iter : 10001, loss: 0.4788, accuracy: 0.8910
# Iter : 11001, loss: 0.6765, accuracy: 0.8990
# Iter : 12001, loss: 0.4266, accuracy: 0.8940
# Iter : 13001, loss: 1.0445, accuracy: 0.8920
# Iter : 14001, loss: 0.8073, accuracy: 0.8800
# Iter : 15001, loss: 0.8934, accuracy: 0.8720
# Iter : 16001, loss: 0.9061, accuracy: 0.8720
# Iter : 17001, loss: 1.0450, accuracy: 0.8840
# Iter : 18001, loss: 0.7785, accuracy: 0.8810
# Iter : 19001, loss: 0.7542, accuracy: 0.8770
# Iter : 20001, loss: 0.7198, accuracy: 0.8920
# Iter : 21001, loss: 0.9448, accuracy: 0.8800
# Iter : 22001, loss: 0.9422, accuracy: 0.8750
# Iter : 23001, loss: 0.5635, accuracy: 0.8840
# Iter : 24001, loss: 0.5818, accuracy: 0.8920
# Iter : 25001, loss: 0.5398, accuracy: 0.8940
# Iter : 26001, loss: 0.6258, accuracy: 0.8910
# Iter : 27001, loss: 0.7934, accuracy: 0.8920
# Iter : 28001, loss: 0.7912, accuracy: 0.8850
# Iter : 29001, loss: 0.7897, accuracy: 0.8970
# Iter : 30001, loss: 0.5291, accuracy: 0.8770
# Iter : 31001, loss: 0.6312, accuracy: 0.8790
# Iter : 32001, loss: 0.5098, accuracy: 0.8640
# Iter : 33001, loss: 0.8224, accuracy: 0.8670
# Iter : 34001, loss: 0.5327, accuracy: 0.8610
# Iter : 35001, loss: 1.0060, accuracy: 0.8580
# Iter : 36001, loss: 0.4511, accuracy: 0.8730
# Iter : 37001, loss: 0.7478, accuracy: 0.8660
# Iter : 38001, loss: 0.9059, accuracy: 0.8750
# Iter : 39001, loss: 0.7327, accuracy: 0.8780
# Iter : 40001, loss: 0.8656, accuracy: 0.8610
# Iter : 41001, loss: 0.3518, accuracy: 0.8680
# Iter : 42001, loss: 0.7522, accuracy: 0.8800
# Iter : 43001, loss: 0.7288, accuracy: 0.8800
# Iter : 44001, loss: 0.4199, accuracy: 0.8940
# Iter : 45001, loss: 0.7300, accuracy: 0.8560
# Iter : 46001, loss: 0.6976, accuracy: 0.8780
# Iter : 47001, loss: 0.5955, accuracy: 0.8850
# Iter : 48001, loss: 0.6810, accuracy: 0.9030
# Iter : 49001, loss: 0.7495, accuracy: 0.8740
# Iter : 50001, loss: 0.7413, accuracy: 0.8740
# Iter : 51001, loss: 0.6182, accuracy: 0.8820
# Iter : 52001, loss: 0.7514, accuracy: 0.8810
# Iter : 53001, loss: 0.8306, accuracy: 0.8880
# Iter : 54001, loss: 0.5426, accuracy: 0.8720
# Iter : 55001, loss: 0.5106, accuracy: 0.8920
# Iter : 56001, loss: 0.4819, accuracy: 0.8710
# Iter : 57001, loss: 0.4913, accuracy: 0.8880
# Iter : 58001, loss: 0.5147, accuracy: 0.8810
# Iter : 59001, loss: 1.1213, accuracy: 0.8870
# Iter : 60001, loss: 0.6494, accuracy: 0.8710
# Iter : 61001, loss: 0.7619, accuracy: 0.8770
# Iter : 62001, loss: 0.6051, accuracy: 0.8570
# Iter : 63001, loss: 0.6546, accuracy: 0.8720
# Iter : 64001, loss: 0.9151, accuracy: 0.8800
# Iter : 65001, loss: 0.5908, accuracy: 0.8850
# Iter : 66001, loss: 1.1159, accuracy: 0.8930
# Iter : 67001, loss: 1.1273, accuracy: 0.8770
# Iter : 68001, loss: 0.9811, accuracy: 0.8910
# Iter : 69001, loss: 0.7867, accuracy: 0.8920
# Iter : 70001, loss: 0.6817, accuracy: 0.8420
# Iter : 71001, loss: 0.7094, accuracy: 0.8550
# Iter : 72001, loss: 0.6950, accuracy: 0.8550
# Iter : 73001, loss: 0.5611, accuracy: 0.8730
# Iter : 74001, loss: 1.0620, accuracy: 0.8790
# Iter : 75001, loss: 0.7135, accuracy: 0.8750
# Iter : 76001, loss: 0.7177, accuracy: 0.8870
# Iter : 77001, loss: 1.1889, accuracy: 0.8580
# Iter : 78001, loss: 0.7844, accuracy: 0.8590
# Iter : 79001, loss: 0.6054, accuracy: 0.8900
# Doing rep  4
# Iter : 1001, loss: 1.0401, accuracy: 0.4440
# Iter : 2001, loss: 0.8327, accuracy: 0.6940
# Iter : 3001, loss: 0.7747, accuracy: 0.7870
# Iter : 4001, loss: 0.6814, accuracy: 0.8030
# Iter : 5001, loss: 1.0700, accuracy: 0.7910
# Iter : 6001, loss: 0.5217, accuracy: 0.8090
# Iter : 7001, loss: 0.9332, accuracy: 0.8050
# Iter : 8001, loss: 0.9433, accuracy: 0.8070
# Iter : 9001, loss: 0.3421, accuracy: 0.7970
# Iter : 10001, loss: 0.3666, accuracy: 0.8140
# Iter : 11001, loss: 0.8195, accuracy: 0.7890
# Iter : 12001, loss: 0.9221, accuracy: 0.7960
# Iter : 13001, loss: 0.7236, accuracy: 0.8270
# Iter : 14001, loss: 0.5464, accuracy: 0.8090
# Iter : 15001, loss: 0.9398, accuracy: 0.7950
# Iter : 16001, loss: 0.5559, accuracy: 0.8210
# Iter : 17001, loss: 0.3698, accuracy: 0.8320
# Iter : 18001, loss: 0.5881, accuracy: 0.8080
# Iter : 19001, loss: 0.4724, accuracy: 0.8150
# Going to sleep ...
# Iter : 1001, loss: 0.1242, accuracy: 0.8340
# Iter : 2001, loss: 0.0023, accuracy: 0.8670
# Iter : 3001, loss: 0.0139, accuracy: 0.9600
# Iter : 4001, loss: 0.0046, accuracy: 0.9640
# Iter : 5001, loss: 0.0021, accuracy: 0.9710
# Iter : 6001, loss: 0.0060, accuracy: 0.9650
# Iter : 7001, loss: 0.0052, accuracy: 0.9940
# Iter : 8001, loss: 0.0080, accuracy: 0.9820
# Iter : 9001, loss: 0.3194, accuracy: 0.9870
# Going to awake phase ...
# Iter : 1001, loss: 1.3603, accuracy: 0.7610
# Iter : 2001, loss: 0.5040, accuracy: 0.8350
# Iter : 3001, loss: 0.4491, accuracy: 0.8600
# Iter : 4001, loss: 0.6638, accuracy: 0.8730
# Iter : 5001, loss: 0.5309, accuracy: 0.8930
# Iter : 6001, loss: 1.1361, accuracy: 0.9010
# Iter : 7001, loss: 1.3369, accuracy: 0.8970
# Iter : 8001, loss: 0.5388, accuracy: 0.9160
# Iter : 9001, loss: 1.1811, accuracy: 0.9030
# Iter : 10001, loss: 0.9085, accuracy: 0.9050
# Iter : 11001, loss: 0.6486, accuracy: 0.9080
# Iter : 12001, loss: 0.3064, accuracy: 0.8960
# Iter : 13001, loss: 0.5463, accuracy: 0.8890
# Iter : 14001, loss: 1.1429, accuracy: 0.8960
# Iter : 15001, loss: 0.6067, accuracy: 0.8890
# Iter : 16001, loss: 0.8919, accuracy: 0.9110
# Iter : 17001, loss: 0.7437, accuracy: 0.8880
# Iter : 18001, loss: 0.6449, accuracy: 0.9000
# Iter : 19001, loss: 0.7032, accuracy: 0.9000
# Iter : 20001, loss: 0.7303, accuracy: 0.8990
# Iter : 21001, loss: 0.5538, accuracy: 0.8940
# Iter : 22001, loss: 0.6414, accuracy: 0.8900
# Iter : 23001, loss: 0.8018, accuracy: 0.8930
# Iter : 24001, loss: 0.6510, accuracy: 0.8940
# Iter : 25001, loss: 0.7778, accuracy: 0.9020
# Iter : 26001, loss: 0.4403, accuracy: 0.9100
# Iter : 27001, loss: 0.8927, accuracy: 0.9070
# Iter : 28001, loss: 0.4977, accuracy: 0.9110
# Iter : 29001, loss: 0.7233, accuracy: 0.8970
# Iter : 30001, loss: 0.8146, accuracy: 0.9070
# Iter : 31001, loss: 0.5687, accuracy: 0.9000
# Iter : 32001, loss: 1.1372, accuracy: 0.8910
# Iter : 33001, loss: 0.3901, accuracy: 0.9010
# Iter : 34001, loss: 0.5056, accuracy: 0.9000
# Iter : 35001, loss: 0.6423, accuracy: 0.9070
# Iter : 36001, loss: 0.9973, accuracy: 0.9060
# Iter : 37001, loss: 0.6698, accuracy: 0.8970
# Iter : 38001, loss: 3.0475, accuracy: 0.9070
# Iter : 39001, loss: 0.4685, accuracy: 0.8930
# Iter : 40001, loss: 0.7655, accuracy: 0.8890
# Iter : 41001, loss: 0.7902, accuracy: 0.9090
# Iter : 42001, loss: 0.8924, accuracy: 0.9030
# Iter : 43001, loss: 0.7542, accuracy: 0.8960
# Iter : 44001, loss: 0.4439, accuracy: 0.8920
# Iter : 45001, loss: 0.7774, accuracy: 0.8880
# Iter : 46001, loss: 0.5023, accuracy: 0.9060
# Iter : 47001, loss: 0.7491, accuracy: 0.9070
# Iter : 48001, loss: 0.6658, accuracy: 0.9040
# Iter : 49001, loss: 0.6023, accuracy: 0.8880
# Iter : 50001, loss: 0.8027, accuracy: 0.9010
# Iter : 51001, loss: 0.5919, accuracy: 0.9140
# Iter : 52001, loss: 0.5489, accuracy: 0.9040
# Iter : 53001, loss: 0.8753, accuracy: 0.9050
# Iter : 54001, loss: 0.4954, accuracy: 0.8960
# Iter : 55001, loss: 0.8413, accuracy: 0.8970
# Iter : 56001, loss: 0.7636, accuracy: 0.8840
# Iter : 57001, loss: 0.8041, accuracy: 0.8910
# Iter : 58001, loss: 0.4156, accuracy: 0.8990
# Iter : 59001, loss: 0.9022, accuracy: 0.9000
# Iter : 60001, loss: 0.7817, accuracy: 0.8920
# Iter : 61001, loss: 0.7524, accuracy: 0.9000
# Iter : 62001, loss: 0.8679, accuracy: 0.8990
# Iter : 63001, loss: 0.5744, accuracy: 0.9020
# Iter : 64001, loss: 0.9447, accuracy: 0.8900
# Iter : 65001, loss: 0.4622, accuracy: 0.9110
# Iter : 66001, loss: 0.6213, accuracy: 0.9030
# Iter : 67001, loss: 0.5335, accuracy: 0.9010
# Iter : 68001, loss: 0.9123, accuracy: 0.9000
# Iter : 69001, loss: 0.5084, accuracy: 0.9040
# Iter : 70001, loss: 0.7405, accuracy: 0.8930
# Iter : 71001, loss: 0.4451, accuracy: 0.9020
# Iter : 72001, loss: 0.7908, accuracy: 0.9120
# Iter : 73001, loss: 0.7813, accuracy: 0.8890
# Iter : 74001, loss: 0.6193, accuracy: 0.9100
# Iter : 75001, loss: 0.9436, accuracy: 0.9110
# Iter : 76001, loss: 0.8231, accuracy: 0.9020
# Iter : 77001, loss: 0.5952, accuracy: 0.9130
# Iter : 78001, loss: 0.6132, accuracy: 0.8960
# Iter : 79001, loss: 0.5498, accuracy: 0.9040

# %%
test_acc = np.array(test_acc)
# test_acc_not_sparse = np.array(test_acc_not_sparse)
# test_acc_control = np.array(test_acc_control)
sleep_break = 20000
sns.set(
        color_codes=True, palette="bright", style="white", context="talk", font_scale=1.5
    )
font = 40

fig, ax = plt.subplots(1, 1, figsize=(8,8), sharex=True, sharey=True)

ax.hlines(0.1, 0, total_samples+sleep_break, linestyles='dashed', label='Optimal Performance', color='k')

ax.plot(np.median(1-test_acc[:,:initial_training_sample],axis=0),linewidth=2, color='r', label='with cortex')
ax.fill_between(np.arange(1,initial_training_sample+1), np.quantile(1-test_acc[:,:initial_training_sample], 0.25, axis=0), np.quantile(1-test_acc[:,:initial_training_sample], 0.75, axis=0), color='r', alpha=.3)

ax.plot(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc[0][initial_training_sample+sleep_samples:])), np.median(1-test_acc[:,initial_training_sample+sleep_samples:],axis=0),linewidth=2, color='r')
ax.fill_between(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc[0][initial_training_sample+sleep_samples:])), np.quantile(1-test_acc[:,initial_training_sample+sleep_samples:], 0.25, axis=0), np.quantile(1-test_acc[:,initial_training_sample+sleep_samples:], 0.75, axis=0), color='r', alpha=.3)


# ax.plot(np.median(1-test_acc_not_sparse[:,:initial_training_sample],axis=0),linewidth=2, color='b', label='with cortex no sparsity')
# ax.fill_between(np.arange(1,initial_training_sample+1), np.quantile(1-test_acc_not_sparse[:,:initial_training_sample], 0.25, axis=0), np.quantile(1-test_acc_not_sparse[:,:initial_training_sample], 0.75, axis=0), color='b', alpha=.3)

# ax.plot(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_not_sparse[0][initial_training_sample+sleep_samples:])), np.median(1-test_acc_not_sparse[:,initial_training_sample+sleep_samples:],axis=0),linewidth=2, color='b')
# ax.fill_between(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_not_sparse[0][initial_training_sample+sleep_samples:])), np.quantile(1-test_acc_not_sparse[:,initial_training_sample+sleep_samples:], 0.25, axis=0), np.quantile(1-test_acc_not_sparse[:,initial_training_sample+sleep_samples:], 0.75, axis=0), color='b', alpha=.3)

ax.vlines(initial_training_sample, 0.1, 1, linestyles='dashed', color='b')
ax.vlines(initial_training_sample+sleep_break, 0.1, 1, linestyles='dashed', color='b')


# ax.plot(np.median(1-test_acc_control[:,:initial_training_sample],axis=0),linewidth=2, color='k', label='without cortex')
# ax.fill_between(np.arange(1,initial_training_sample+1), np.quantile(1-test_acc_control[:,:initial_training_sample], 0.25, axis=0), np.quantile(1-test_acc_control[:,:initial_training_sample], 0.75, axis=0), color='k', alpha=.3)

# ax.plot(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_control[0][initial_training_sample:])), np.median(1-test_acc_control[:,initial_training_sample:],axis=0),linewidth=2, color='k')
# ax.fill_between(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_control[0][initial_training_sample:])), np.quantile(1-test_acc_control[:,initial_training_sample:], 0.25, axis=0), np.quantile(1-test_acc_control[:,initial_training_sample:], 0.75, axis=0), color='k', alpha=.3)


plt.xticks([1, total_samples+sleep_break])
plt.yticks([0.1, 0.5, 1.0])

ax.set_ylabel('Error', fontsize=font)
# ax.set_yscale('log') 


ax.tick_params(labelsize=40)
    
right_side = ax.spines["right"]
right_side.set_visible(False)
top_side = ax.spines["top"]
top_side.set_visible(False)

fig.text(.37, .92, 'Sleep', rotation=0, fontsize=20)
fig.legend(bbox_to_anchor=(0.5, -0.02), bbox_transform=plt.gcf().transFigure,
                        ncol=2, loc='upper center', fontsize=20, frameon=False)
plt.tight_layout()
