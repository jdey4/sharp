# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim.lr_scheduler as lr_scheduler
from torch import from_numpy as tnsr
from scipy.stats import bernoulli
import torch.nn as nn
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 3 hypothesis for sleep:
# 1. capacity improvement
# 2. homeostasis (balancing firing)
# 3. performance improvement
# 4. conversion to semantic memory in cortex

# %% [markdown]
# ## Experiment 1:
# ### Observation: During sleep connections in Hippocampus weaken and connections in the cortical region strengthen.
# ### Hypothesis: Distributing learning to Neo-cortex gives Hippocampus more capacity.
#  - During wake, train a hippocampus RNN (with lower hidden size) on the data, freeze the cortical RNN.
#  - During sleep generate sequence from the trained RNN.
#  - Now train both hippocampus + cortical RNN on the generated data.
#  - After the sleep period in the second wake period, train only the hippocampus RNN, freezing the cortical RNN.
#
# ### Expectation: The hippocampus RNN now has better capacity.

# %% [markdown]
# ## Proposed Model
# ![sleep_exp.png](attachment:476bfb1a-d7a2-48ba-a6e5-d5167c2dcd88.png)

# %%
def _get_member(community, n_members, clockwise=True):
    seq = chr(community*n_members + ord('A'))
    
    if clockwise:
        next_token = chr(community*n_members + ord('A') + 1)
    else:
        next_token = chr(community*n_members + ord('A') + n_members-1)

    for _ in range(n_members-1):
        seq += next_token

        if clockwise:
            next_token = chr(ord(next_token) + 1)
        else:
            next_token = chr(ord(next_token) - 1)

    seq += seq[0]
    return seq 

def get_sequence(n_samples, n_community, n_members, random_state=0):
    
    """
    Generate data sequence divided into communities.

    Parameters
    ----------
    n_samples : int
        Total number of tokens to sample.
    n_community : int
        Total number of community.
    n_members : int
        Total number of members in each community.
    random_state : int, RandomState instance, default=None
        Determines random number generation for dataset creation. Pass an int
        for reproducible output across multiple function calls.

    Returns
    -------
    out : array of shape [n_samples]
        The generated sequence of tokens.
    """

    if random_state != None:
        np.random.seed(random_state)

    visits = []
    direction = []
    total_community_visit = int(np.ceil(n_samples/n_members))
    
    for ii in range(total_community_visit):
        visits.append(
            np.random.choice(n_community)
        )

        if ii == 0 or ii == 1:
            direction.append(True)
        elif visits[-2] == visits[-1] and visits[-3] == visits[-1]:
            direction.append(False)
        elif visits[-2] != visits[-1] and visits[-3] == visits[-1]:
            direction.append(True)
        elif visits[-2] == visits[-1] and visits[-3] != visits[-1]:
            direction.append(True)
        else:
            direction.append(False)

    out = ''
    for ii, community in enumerate(visits):
        out += _get_member(community, n_members, clockwise=direction[ii]) + chr(ord('A')+n_community*n_members)

    return out[:n_samples]

# %%
n_community = 2
n_members = 3

tokens = []

for ii in range(n_community*n_members+1):
    tokens.append(
        chr(ord('A')+ii)
    )

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size_hippocampus, hidden_size_cortex, num_layers_hippocampus=1, num_layers_cortex=1, memory_buffer=10):
        super(RNN, self).__init__()
        self.cortex_hidden = torch.zeros(1, 1, hidden_size_cortex)
        
        self.hidden_size_cortex = hidden_size_cortex
        self.hidden_size_hippocampus = hidden_size_hippocampus
        self.rnn_hippocampus = nn.RNN(input_size+hidden_size_cortex, hidden_size_hippocampus, num_layers_hippocampus, batch_first=True)
        self.rnn_cortex = nn.RNN(input_size, hidden_size_cortex, num_layers_cortex, batch_first=True)
        
        self.fc = nn.Linear(hidden_size_hippocampus, len(tokens))
        
    def forward(self, x, h0=None, hc=None, sleep=False):
        if sleep:
            if hc == None:
                cortex_out, hc = self.rnn_cortex(x)
            else:
                cortex_out, hc = self.rnn_cortex(x, hc)
            
            x = torch.cat((x,cortex_out), dim=2)
                
            if h0 == None:
                out, h0 = self.rnn_hippocampus(x)
            else:   
                out, h0 = self.rnn_hippocampus(x, h0)
    
            out = self.fc(out)
        else:
            x = torch.cat((x,self.cortex_hidden), dim=2)
                
            if h0 == None:
                out, h0 = self.rnn_hippocampus(x)
            else:   
                out, h0 = self.rnn_hippocampus(x, h0)
    
            out = self.fc(out)
        
        
 
        # else:
        #     x = torch.cat((x,self.cortex_hidden), dim=2)
        #     if h0 == None:
        #         out, h0 = self.rnn_hippocampus(x)
        #     else:   
        #         out, h0 = self.rnn_hippocampus(x, h0)
            
        if sleep:
            return out[:,-1,:], h0, hc

        return out[:,-1,:], h0

# %%
class Dataset_converter(Dataset):
    def __init__(self, data, working_memory=1, short_term_memory=8):
        
        one_hot_encoded = np.zeros((len(data), len(tokens)), dtype=float)
        for ii, token in enumerate(data):
            one_hot_encoded[ii,ord(token)-65] = 1
        
        self.X = np.zeros((((len(data)-working_memory-short_term_memory)), short_term_memory, len(tokens)*working_memory))
        self.y = np.zeros((((len(data)-working_memory-short_term_memory)), len(tokens)))

        for ii in range(self.X.shape[0]):
            for jj in range(self.X.shape[1]):
                for kk in range(working_memory):
                    self.X[ii,jj,kk*len(tokens):(kk+1)*len(tokens)] = \
                    one_hot_encoded[ii+jj+kk,:]
                    
            self.y[ii] = \
                one_hot_encoded[ii+jj+kk+1,:]

        self.X = tnsr(self.X).float()
        self.y = tnsr(self.y).float()

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

# %%
def generate_sleep_samples(main_model, n_samples):
    seq = ''
    idx = torch.randint(0, len(tokens), (1,)) [0]
    X_hat = torch.zeros(len(tokens),dtype=torch.float32)
    X_hat[idx] = 1.0
    
    for ii in range(n_samples+50):
        if ii == 0:
            # seq += tokens[idx]        
            X_hat, mem = main_model(X_hat.reshape(1,1,-1))
        else:
            X_hat, mem = main_model(X_hat, mem)
    
        # mem = mem + 1e-1*torch.rand(mem.shape)
        # X_hat = torch.tensor(X_hat, requires_grad=False)
        X_hat = torch.nn.functional.softmax(X_hat, dim=1)
        dist_categ = torch.distributions.Categorical(probs=X_hat.reshape(-1))
        idx = dist_categ.sample()
    
        X_hat = torch.zeros(len(tokens),dtype=torch.float32)
        X_hat[idx] = 1.0
        X_hat = X_hat.reshape(1,1,-1)   
    
        if ii>50:
            seq += tokens[idx]

    return seq

# %%
### initial training ###
total_samples = 100000
initial_training_sample = 20000
sleep_samples = 20000
working_memory = 1
short_term_memory = 1
hidden_size_hippocampus = 10
hidden_size_cortex = 100
num_layers = 1
lr = 9e-4
reps = 5
test_acc = [[] for _ in range(reps)]

for rep in range(reps):
    print('Doing rep ', rep)
    
    data = get_sequence(total_samples, 2, 3, random_state=rep)
    # data = pd.read_csv("../Seq_500000.txt")['seq'][0]
    
    
    data_set = Dataset_converter(data[:initial_training_sample], working_memory, short_term_memory)
    
    main_model = RNN(len(tokens)*working_memory, hidden_size_hippocampus, hidden_size_cortex, num_layers)
    main_model.rnn_cortex.requires_grad = False
    
    train_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    
    optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    criterion = torch.nn.CrossEntropyLoss()
    
    total = 0
    correct = np.zeros(1000,dtype=float)
    for X, y in train_loader:
        optimizer.zero_grad()
    
        if total == 0:
            predicted_y, hidden = main_model(X)
        else:
            predicted_y, hidden = main_model(X, mem)
            
        loss = criterion(predicted_y, y)
        loss.backward(retain_graph=True)
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            total += 1
            if true_y == estimated_y:
                    correct[total%1000] = 1
            else:
                correct[total%1000] = 0
    
            test_acc[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if total%1000 == 0:
                print(f'Iter : {total+1}, loss: {loss:.4f}, accuracy: {test_acc[rep][-1]:.4f}')


    print('Going to sleep ...')
    data_sleep = generate_sleep_samples(main_model, sleep_samples)
    main_model.rnn_cortex.requires_grad = True
    data_set = Dataset_converter(data_sleep, working_memory, short_term_memory)
    sleep_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    optimizer = torch.optim.Adam([
                                    {'params': main_model.rnn_hippocampus.parameters(), 'weight_decay': 1e-8},  # Apply weight decay to hippocampus
                                    {'params': main_model.rnn_cortex.parameters()},  # No weight decay for cortex
                                    {'params': main_model.fc.parameters()},
                                ], lr=lr)
    # optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    
    criterion = torch.nn.CrossEntropyLoss()
    sleep_iter = 0
    
    for X, y in sleep_loader:
        optimizer.zero_grad()
    
        if sleep_iter == 0:
            predicted_y, hidden, hidden_sleep = main_model(X, sleep=True)
        else:
            predicted_y, hidden, hidden_sleep = main_model(X, mem, mem_, sleep=True)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            mem_ = hidden_sleep.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            sleep_iter += 1
            if true_y == estimated_y:
                    correct[sleep_iter%1000] = 1
            else:
                correct[sleep_iter%1000] = 0
    
            test_acc[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if sleep_iter%1000 == 0:
                print(f'Iter : {sleep_iter+1}, loss: {loss:.4f}, accuracy: {test_acc[rep][-1]:.4f}')


    print('Going to awake phase ...')
    # data_sleep = generate_sleep_samples(main_model, sleep_samples)
    main_model.rnn_cortex.requires_grad = False
    data_set = Dataset_converter(data[initial_training_sample:], working_memory, short_term_memory)
    test_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    criterion = torch.nn.CrossEntropyLoss()
    sleep_iter = 0
    
    for X, y in test_loader:
        optimizer.zero_grad()
    
        if sleep_iter == 0:
            predicted_y, hidden, hidden_sleep = main_model(X, sleep=True)
        else:
            predicted_y, hidden, hidden_sleep = main_model(X, mem, mem_, sleep=True)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            mem_ = hidden_sleep.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            sleep_iter += 1
            if true_y == estimated_y:
                    correct[sleep_iter%1000] = 1
            else:
                correct[sleep_iter%1000] = 0
    
            test_acc[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if sleep_iter%1000 == 0:
                print(f'Iter : {sleep_iter+1}, loss: {loss:.4f}, accuracy: {test_acc[rep][-1]:.4f}')
# Out:
# Doing rep  0
# Iter : 1001, loss: 1.4302, accuracy: 0.4220
# Iter : 2001, loss: 1.4374, accuracy: 0.7460
# Iter : 3001, loss: 0.4471, accuracy: 0.7990
# Iter : 4001, loss: 1.2191, accuracy: 0.7910
# Iter : 5001, loss: 1.2163, accuracy: 0.8090
# Iter : 6001, loss: 1.5038, accuracy: 0.7800
# Iter : 7001, loss: 0.2930, accuracy: 0.7990
# Iter : 8001, loss: 1.1635, accuracy: 0.8150
# Iter : 9001, loss: 0.7529, accuracy: 0.8050
# Iter : 10001, loss: 0.6550, accuracy: 0.8090
# Iter : 11001, loss: 0.6776, accuracy: 0.7890
# Iter : 12001, loss: 1.1501, accuracy: 0.8150
# Iter : 13001, loss: 0.6433, accuracy: 0.8050
# Iter : 14001, loss: 0.7847, accuracy: 0.7910
# Iter : 15001, loss: 0.4223, accuracy: 0.7920
# Iter : 16001, loss: 0.8452, accuracy: 0.8080
# Iter : 17001, loss: 0.4479, accuracy: 0.8000
# Iter : 18001, loss: 1.1774, accuracy: 0.7940
# Iter : 19001, loss: 0.9015, accuracy: 0.7780
# Going to sleep ...
# Iter : 1001, loss: 0.0095, accuracy: 0.8010
# Iter : 2001, loss: 0.7596, accuracy: 0.7940
# Iter : 3001, loss: 0.0004, accuracy: 0.7990
# Iter : 4001, loss: 0.0008, accuracy: 0.7950
# Iter : 5001, loss: 0.0107, accuracy: 0.7800
# Iter : 6001, loss: 0.6891, accuracy: 0.7870
# Iter : 7001, loss: 0.0027, accuracy: 0.7930
# Iter : 8001, loss: 0.3038, accuracy: 0.8200
# Iter : 9001, loss: 0.3561, accuracy: 0.7120
# Iter : 10001, loss: 0.0030, accuracy: 0.7460
# Iter : 11001, loss: 0.7440, accuracy: 0.7840
# Iter : 12001, loss: 0.6085, accuracy: 0.7940
# Iter : 13001, loss: 0.8011, accuracy: 0.7940
# Iter : 14001, loss: 0.0127, accuracy: 0.7890
# Iter : 15001, loss: 0.6851, accuracy: 0.7990
# Iter : 16001, loss: 0.0116, accuracy: 0.7940
# Iter : 17001, loss: 0.0054, accuracy: 0.7960
# Iter : 18001, loss: 0.5921, accuracy: 0.7790
# Iter : 19001, loss: 0.0110, accuracy: 0.8060
# Going to awake phase ...
# Iter : 1001, loss: 1.5002, accuracy: 0.8040
# Iter : 2001, loss: 0.8701, accuracy: 0.8390
# Iter : 3001, loss: 1.0335, accuracy: 0.8600
# Iter : 4001, loss: 0.8683, accuracy: 0.8390
# Iter : 5001, loss: 0.9486, accuracy: 0.8620
# Iter : 6001, loss: 0.6668, accuracy: 0.8560
# Iter : 7001, loss: 0.7083, accuracy: 0.8780
# Iter : 8001, loss: 0.4870, accuracy: 0.8600
# Iter : 9001, loss: 0.7371, accuracy: 0.8830
# Iter : 10001, loss: 0.6405, accuracy: 0.8900
# Iter : 11001, loss: 0.8026, accuracy: 0.8980
# Iter : 12001, loss: 0.4382, accuracy: 0.8710
# Iter : 13001, loss: 0.3899, accuracy: 0.8930
# Iter : 14001, loss: 0.7924, accuracy: 0.8880
# Iter : 15001, loss: 1.2241, accuracy: 0.8830
# Iter : 16001, loss: 1.2503, accuracy: 0.8950
# Iter : 17001, loss: 0.7219, accuracy: 0.8960
# Iter : 18001, loss: 0.6691, accuracy: 0.8820
# Iter : 19001, loss: 0.4498, accuracy: 0.9000
# Iter : 20001, loss: 1.2318, accuracy: 0.9040
# Iter : 21001, loss: 0.4836, accuracy: 0.9040
# Iter : 22001, loss: 0.4502, accuracy: 0.8900
# Iter : 23001, loss: 0.5653, accuracy: 0.9010
# Iter : 24001, loss: 0.2953, accuracy: 0.9100
# Iter : 25001, loss: 0.6480, accuracy: 0.8930
# Iter : 26001, loss: 1.1813, accuracy: 0.8970
# Iter : 27001, loss: 0.7161, accuracy: 0.8950
# Iter : 28001, loss: 0.9059, accuracy: 0.9050
# Iter : 29001, loss: 0.6104, accuracy: 0.9010
# Iter : 30001, loss: 0.5940, accuracy: 0.9090
# Iter : 31001, loss: 0.6636, accuracy: 0.9000
# Iter : 32001, loss: 0.6334, accuracy: 0.8980
# Iter : 33001, loss: 0.7413, accuracy: 0.9080
# Iter : 34001, loss: 1.0554, accuracy: 0.8940
# Iter : 35001, loss: 0.6668, accuracy: 0.9000
# Iter : 36001, loss: 0.7510, accuracy: 0.9000
# Iter : 37001, loss: 0.9082, accuracy: 0.9100
# Iter : 38001, loss: 0.6771, accuracy: 0.8890
# Iter : 39001, loss: 0.6951, accuracy: 0.9010
# Iter : 40001, loss: 0.7840, accuracy: 0.8910
# Iter : 41001, loss: 0.8877, accuracy: 0.9030
# Iter : 42001, loss: 0.6777, accuracy: 0.9000
# Iter : 43001, loss: 0.7622, accuracy: 0.9070
# Iter : 44001, loss: 0.8817, accuracy: 0.8950
# Iter : 45001, loss: 0.3346, accuracy: 0.9050
# Iter : 46001, loss: 0.7042, accuracy: 0.8920
# Iter : 47001, loss: 0.7016, accuracy: 0.8900
# Iter : 48001, loss: 0.6752, accuracy: 0.9020
# Iter : 49001, loss: 0.6324, accuracy: 0.9040
# Iter : 50001, loss: 0.7386, accuracy: 0.8970
# Iter : 51001, loss: 1.0392, accuracy: 0.9120
# Iter : 52001, loss: 0.8408, accuracy: 0.8910
# Iter : 53001, loss: 0.5446, accuracy: 0.9140
# Iter : 54001, loss: 0.7953, accuracy: 0.8970
# Iter : 55001, loss: 0.9643, accuracy: 0.8980
# Iter : 56001, loss: 0.6090, accuracy: 0.8970
# Iter : 57001, loss: 1.1476, accuracy: 0.8970
# Iter : 58001, loss: 0.6320, accuracy: 0.9140
# Iter : 59001, loss: 0.8481, accuracy: 0.9090
# Iter : 60001, loss: 1.2181, accuracy: 0.8960
# Iter : 61001, loss: 0.6624, accuracy: 0.8920
# Iter : 62001, loss: 0.7554, accuracy: 0.9080
# Iter : 63001, loss: 0.8322, accuracy: 0.8950
# Iter : 64001, loss: 0.8773, accuracy: 0.9030
# Iter : 65001, loss: 0.8202, accuracy: 0.8920
# Iter : 66001, loss: 1.2657, accuracy: 0.9010
# Iter : 67001, loss: 0.5287, accuracy: 0.8970
# Iter : 68001, loss: 1.1432, accuracy: 0.8950
# Iter : 69001, loss: 0.5093, accuracy: 0.8990
# Iter : 70001, loss: 0.9405, accuracy: 0.8940
# Iter : 71001, loss: 0.8287, accuracy: 0.8960
# Iter : 72001, loss: 0.7692, accuracy: 0.9050
# Iter : 73001, loss: 1.2580, accuracy: 0.9050
# Iter : 74001, loss: 1.1475, accuracy: 0.9110
# Iter : 75001, loss: 1.2066, accuracy: 0.8900
# Iter : 76001, loss: 0.4000, accuracy: 0.9110
# Iter : 77001, loss: 0.9197, accuracy: 0.8950
# Iter : 78001, loss: 0.8081, accuracy: 0.8940
# Iter : 79001, loss: 0.8158, accuracy: 0.8970
# Doing rep  1
# Iter : 1001, loss: 0.6927, accuracy: 0.4290
# Iter : 2001, loss: 0.7093, accuracy: 0.7200
# Iter : 3001, loss: 0.7632, accuracy: 0.7560
# Iter : 4001, loss: 0.5402, accuracy: 0.8040
# Iter : 5001, loss: 0.2920, accuracy: 0.8250
# Iter : 6001, loss: 0.8321, accuracy: 0.8030
# Iter : 7001, loss: 0.3733, accuracy: 0.7910
# Iter : 8001, loss: 0.6198, accuracy: 0.7870
# Iter : 9001, loss: 0.8235, accuracy: 0.7940
# Iter : 10001, loss: 1.0395, accuracy: 0.7930
# Iter : 11001, loss: 0.4702, accuracy: 0.8270
# Iter : 12001, loss: 0.6420, accuracy: 0.8170
# Iter : 13001, loss: 0.8898, accuracy: 0.7960
# Iter : 14001, loss: 0.3559, accuracy: 0.8110
# Iter : 15001, loss: 0.9795, accuracy: 0.8170
# Iter : 16001, loss: 0.8584, accuracy: 0.8080
# Iter : 17001, loss: 0.8430, accuracy: 0.7950
# Iter : 18001, loss: 0.6376, accuracy: 0.8050
# Iter : 19001, loss: 0.6574, accuracy: 0.7980
# Going to sleep ...
# Iter : 1001, loss: 0.5554, accuracy: 0.8260
# Iter : 2001, loss: 1.1610, accuracy: 0.7910
# Iter : 3001, loss: 0.0012, accuracy: 0.8200
# Iter : 4001, loss: 0.2758, accuracy: 0.8300
# Iter : 5001, loss: 0.3730, accuracy: 0.8190
# Iter : 6001, loss: 0.8731, accuracy: 0.8020
# Iter : 7001, loss: 0.0050, accuracy: 0.8340
# Iter : 8001, loss: 0.9581, accuracy: 0.8420
# Iter : 9001, loss: 0.0035, accuracy: 0.8300
# Iter : 10001, loss: 0.4857, accuracy: 0.8220
# Iter : 11001, loss: 0.0049, accuracy: 0.8440
# Iter : 12001, loss: 2.6255, accuracy: 0.8260
# Iter : 13001, loss: 0.0013, accuracy: 0.8030
# Iter : 14001, loss: 0.6470, accuracy: 0.7890
# Iter : 15001, loss: 0.0179, accuracy: 0.8290
# Iter : 16001, loss: 0.9316, accuracy: 0.8210
# Iter : 17001, loss: 0.0251, accuracy: 0.8080
# Iter : 18001, loss: 0.0050, accuracy: 0.7930
# Iter : 19001, loss: 0.0590, accuracy: 0.8020
# Going to awake phase ...
# Iter : 1001, loss: 0.6074, accuracy: 0.8020
# Iter : 2001, loss: 0.7058, accuracy: 0.8450
# Iter : 3001, loss: 0.6523, accuracy: 0.8520
# Iter : 4001, loss: 0.6825, accuracy: 0.8560
# Iter : 5001, loss: 0.6327, accuracy: 0.8730
# Iter : 6001, loss: 0.2797, accuracy: 0.8750
# Iter : 7001, loss: 0.6705, accuracy: 0.8850
# Iter : 8001, loss: 0.4492, accuracy: 0.9070
# Iter : 9001, loss: 0.8152, accuracy: 0.8960
# Iter : 10001, loss: 0.6868, accuracy: 0.8950
# Iter : 11001, loss: 1.0672, accuracy: 0.8900
# Iter : 12001, loss: 0.7040, accuracy: 0.8890
# Iter : 13001, loss: 0.4141, accuracy: 0.9050
# Iter : 14001, loss: 0.7709, accuracy: 0.8830
# Iter : 15001, loss: 0.7963, accuracy: 0.8970
# Iter : 16001, loss: 0.7217, accuracy: 0.8810
# Iter : 17001, loss: 0.4408, accuracy: 0.8920
# Iter : 18001, loss: 0.9364, accuracy: 0.8890
# Iter : 19001, loss: 0.6716, accuracy: 0.8890
# Iter : 20001, loss: 0.4727, accuracy: 0.9040
# Iter : 21001, loss: 0.7435, accuracy: 0.8930
# Iter : 22001, loss: 0.8182, accuracy: 0.8850
# Iter : 23001, loss: 1.0305, accuracy: 0.9000
# Iter : 24001, loss: 0.5398, accuracy: 0.9120
# Iter : 25001, loss: 0.5510, accuracy: 0.9080
# Iter : 26001, loss: 0.5754, accuracy: 0.9080
# Iter : 27001, loss: 1.0251, accuracy: 0.9040
# Iter : 28001, loss: 0.4330, accuracy: 0.8980
# Iter : 29001, loss: 0.6872, accuracy: 0.8880
# Iter : 30001, loss: 0.6663, accuracy: 0.9060
# Iter : 31001, loss: 0.5273, accuracy: 0.9100
# Iter : 32001, loss: 0.7887, accuracy: 0.8880
# Iter : 33001, loss: 0.8870, accuracy: 0.9020
# Iter : 34001, loss: 0.9348, accuracy: 0.9060
# Iter : 35001, loss: 0.7668, accuracy: 0.8990
# Iter : 36001, loss: 0.6479, accuracy: 0.9000
# Iter : 37001, loss: 0.8331, accuracy: 0.8980
# Iter : 38001, loss: 0.8178, accuracy: 0.9110
# Iter : 39001, loss: 1.1651, accuracy: 0.9020
# Iter : 40001, loss: 0.8913, accuracy: 0.8920
# Iter : 41001, loss: 0.6132, accuracy: 0.9030
# Iter : 42001, loss: 0.5150, accuracy: 0.9000
# Iter : 43001, loss: 0.7270, accuracy: 0.8940
# Iter : 44001, loss: 0.6747, accuracy: 0.9090
# Iter : 45001, loss: 0.6787, accuracy: 0.9010
# Iter : 46001, loss: 0.7156, accuracy: 0.8920
# Iter : 47001, loss: 0.6199, accuracy: 0.9130
# Iter : 48001, loss: 0.9006, accuracy: 0.8880
# Iter : 49001, loss: 0.6718, accuracy: 0.8990
# Iter : 50001, loss: 0.5949, accuracy: 0.8860
# Iter : 51001, loss: 0.9810, accuracy: 0.9010
# Iter : 52001, loss: 0.4458, accuracy: 0.8980
# Iter : 53001, loss: 0.6516, accuracy: 0.9090
# Iter : 54001, loss: 1.0589, accuracy: 0.8750
# Iter : 55001, loss: 0.6159, accuracy: 0.8910
# Iter : 56001, loss: 0.8194, accuracy: 0.9010
# Iter : 57001, loss: 0.5536, accuracy: 0.9030
# Iter : 58001, loss: 1.0294, accuracy: 0.9020
# Iter : 59001, loss: 0.3619, accuracy: 0.8990
# Iter : 60001, loss: 1.1724, accuracy: 0.8880
# Iter : 61001, loss: 0.7479, accuracy: 0.8740
# Iter : 62001, loss: 0.7186, accuracy: 0.8810
# Iter : 63001, loss: 1.1006, accuracy: 0.8830
# Iter : 64001, loss: 0.4521, accuracy: 0.8850
# Iter : 65001, loss: 0.4559, accuracy: 0.8740
# Iter : 66001, loss: 0.4699, accuracy: 0.8970
# Iter : 67001, loss: 0.5062, accuracy: 0.8690
# Iter : 68001, loss: 1.1140, accuracy: 0.9010
# Iter : 69001, loss: 0.5536, accuracy: 0.8960
# Iter : 70001, loss: 0.6039, accuracy: 0.8510
# Iter : 71001, loss: 0.5745, accuracy: 0.8630
# Iter : 72001, loss: 0.4894, accuracy: 0.8510
# Iter : 73001, loss: 0.9056, accuracy: 0.8540
# Iter : 74001, loss: 0.7121, accuracy: 0.8810
# Iter : 75001, loss: 0.4789, accuracy: 0.8730
# Iter : 76001, loss: 0.7821, accuracy: 0.8490
# Iter : 77001, loss: 0.7062, accuracy: 0.8720
# Iter : 78001, loss: 0.6000, accuracy: 0.8330
# Iter : 79001, loss: 0.6713, accuracy: 0.8500
# Doing rep  2
# Iter : 1001, loss: 1.2015, accuracy: 0.4230
# Iter : 2001, loss: 0.4629, accuracy: 0.7410
# Iter : 3001, loss: 0.5627, accuracy: 0.7950
# Iter : 4001, loss: 0.4497, accuracy: 0.8210
# Iter : 5001, loss: 0.5349, accuracy: 0.8070
# Iter : 6001, loss: 0.4277, accuracy: 0.7950
# Iter : 7001, loss: 1.0521, accuracy: 0.8020
# Iter : 8001, loss: 0.7337, accuracy: 0.8090
# Iter : 9001, loss: 0.6137, accuracy: 0.8130
# Iter : 10001, loss: 0.5826, accuracy: 0.8040
# Iter : 11001, loss: 0.6733, accuracy: 0.8050
# Iter : 12001, loss: 0.5237, accuracy: 0.8040
# Iter : 13001, loss: 0.6651, accuracy: 0.8230
# Iter : 14001, loss: 1.0426, accuracy: 0.8220
# Iter : 15001, loss: 0.6669, accuracy: 0.8110
# Iter : 16001, loss: 0.4015, accuracy: 0.8220
# Iter : 17001, loss: 0.6944, accuracy: 0.8200
# Iter : 18001, loss: 1.0513, accuracy: 0.8120
# Iter : 19001, loss: 0.6323, accuracy: 0.7990
# Going to sleep ...
# Iter : 1001, loss: 0.0083, accuracy: 0.7960
# Iter : 2001, loss: 0.0011, accuracy: 0.8120
# Iter : 3001, loss: 0.0177, accuracy: 0.7980
# Iter : 4001, loss: 0.0042, accuracy: 0.7980
# Iter : 5001, loss: 0.3627, accuracy: 0.8090
# Iter : 6001, loss: 0.3006, accuracy: 0.7960
# Iter : 7001, loss: 0.9586, accuracy: 0.7770
# Iter : 8001, loss: 0.0136, accuracy: 0.7840
# Iter : 9001, loss: 0.0500, accuracy: 0.8050
# Iter : 10001, loss: 1.0068, accuracy: 0.8100
# Iter : 11001, loss: 0.0552, accuracy: 0.7960
# Iter : 12001, loss: 0.3635, accuracy: 0.8310
# Iter : 13001, loss: 0.0210, accuracy: 0.8010
# Iter : 14001, loss: 0.0392, accuracy: 0.8080
# Iter : 15001, loss: 0.0094, accuracy: 0.7920
# Iter : 16001, loss: 0.5264, accuracy: 0.8250
# Iter : 17001, loss: 0.0071, accuracy: 0.8290
# Iter : 18001, loss: 0.8708, accuracy: 0.7920
# Iter : 19001, loss: 0.7471, accuracy: 0.7920
# Going to awake phase ...
# Iter : 1001, loss: 0.7137, accuracy: 0.8050
# Iter : 2001, loss: 0.8293, accuracy: 0.7910
# Iter : 3001, loss: 0.6343, accuracy: 0.8040
# Iter : 4001, loss: 0.4057, accuracy: 0.8010
# Iter : 5001, loss: 0.7912, accuracy: 0.8010
# Iter : 6001, loss: 0.7968, accuracy: 0.8320
# Iter : 7001, loss: 0.4140, accuracy: 0.8180
# Iter : 8001, loss: 0.8465, accuracy: 0.8110
# Iter : 9001, loss: 1.0499, accuracy: 0.8160
# Iter : 10001, loss: 0.4228, accuracy: 0.8040
# Iter : 11001, loss: 0.4531, accuracy: 0.8350
# Iter : 12001, loss: 1.1593, accuracy: 0.8630
# Iter : 13001, loss: 0.6870, accuracy: 0.8470
# Iter : 14001, loss: 0.3780, accuracy: 0.8580
# Iter : 15001, loss: 0.8883, accuracy: 0.8790
# Iter : 16001, loss: 1.1387, accuracy: 0.8780
# Iter : 17001, loss: 0.8964, accuracy: 0.8860
# Iter : 18001, loss: 0.6029, accuracy: 0.8990
# Iter : 19001, loss: 0.7908, accuracy: 0.9030
# Iter : 20001, loss: 0.6449, accuracy: 0.8770
# Iter : 21001, loss: 0.7264, accuracy: 0.8960
# Iter : 22001, loss: 1.4571, accuracy: 0.9140
# Iter : 23001, loss: 0.5246, accuracy: 0.8920
# Iter : 24001, loss: 0.4466, accuracy: 0.9010
# Iter : 25001, loss: 0.5362, accuracy: 0.8930
# Iter : 26001, loss: 0.9114, accuracy: 0.9040
# Iter : 27001, loss: 0.6764, accuracy: 0.8990
# Iter : 28001, loss: 1.0535, accuracy: 0.9040
# Iter : 29001, loss: 1.1676, accuracy: 0.9130
# Iter : 30001, loss: 0.3685, accuracy: 0.9010
# Iter : 31001, loss: 0.5323, accuracy: 0.9060
# Iter : 32001, loss: 0.4309, accuracy: 0.9080
# Iter : 33001, loss: 1.1393, accuracy: 0.9060
# Iter : 34001, loss: 0.5467, accuracy: 0.9000
# Iter : 35001, loss: 0.9453, accuracy: 0.8970
# Iter : 36001, loss: 0.8269, accuracy: 0.8940
# Iter : 37001, loss: 0.6845, accuracy: 0.8940
# Iter : 38001, loss: 0.7292, accuracy: 0.8880
# Iter : 39001, loss: 0.6753, accuracy: 0.8920
# Iter : 40001, loss: 0.8406, accuracy: 0.8930
# Iter : 41001, loss: 0.7657, accuracy: 0.9110
# Iter : 42001, loss: 0.8217, accuracy: 0.9000
# Iter : 43001, loss: 0.6149, accuracy: 0.9020
# Iter : 44001, loss: 0.5606, accuracy: 0.9070
# Iter : 45001, loss: 0.6849, accuracy: 0.8950
# Iter : 46001, loss: 0.8967, accuracy: 0.9000
# Iter : 47001, loss: 0.6099, accuracy: 0.8890
# Iter : 48001, loss: 0.7341, accuracy: 0.8920
# Iter : 49001, loss: 0.6181, accuracy: 0.9080
# Iter : 50001, loss: 0.3550, accuracy: 0.8880
# Iter : 51001, loss: 0.3477, accuracy: 0.8930
# Iter : 52001, loss: 0.4703, accuracy: 0.9020
# Iter : 53001, loss: 0.7735, accuracy: 0.9050
# Iter : 54001, loss: 0.8197, accuracy: 0.9020
# Iter : 55001, loss: 0.6320, accuracy: 0.8980
# Iter : 56001, loss: 0.9667, accuracy: 0.8960
# Iter : 57001, loss: 0.5742, accuracy: 0.8970
# Iter : 58001, loss: 0.3745, accuracy: 0.9050
# Iter : 59001, loss: 1.0229, accuracy: 0.8940
# Iter : 60001, loss: 0.5404, accuracy: 0.8900
# Iter : 61001, loss: 0.5927, accuracy: 0.9000
# Iter : 62001, loss: 0.4784, accuracy: 0.9120
# Iter : 63001, loss: 0.6616, accuracy: 0.8940
# Iter : 64001, loss: 0.6268, accuracy: 0.8880
# Iter : 65001, loss: 0.7312, accuracy: 0.8990
# Iter : 66001, loss: 0.6629, accuracy: 0.8980
# Iter : 67001, loss: 0.7028, accuracy: 0.8950
# Iter : 68001, loss: 1.0632, accuracy: 0.9040
# Iter : 69001, loss: 0.5385, accuracy: 0.8930
# Iter : 70001, loss: 1.2370, accuracy: 0.9050
# Iter : 71001, loss: 0.6631, accuracy: 0.8940
# Iter : 72001, loss: 1.1289, accuracy: 0.8900
# Iter : 73001, loss: 0.5035, accuracy: 0.9000
# Iter : 74001, loss: 0.4364, accuracy: 0.8940
# Iter : 75001, loss: 1.0305, accuracy: 0.9030
# Iter : 76001, loss: 1.1102, accuracy: 0.9090
# Iter : 77001, loss: 0.6007, accuracy: 0.9040
# Iter : 78001, loss: 0.5748, accuracy: 0.9030
# Iter : 79001, loss: 0.5751, accuracy: 0.9020
# Doing rep  3
# Iter : 1001, loss: 0.8432, accuracy: 0.4060
# Iter : 2001, loss: 0.5900, accuracy: 0.7180
# Iter : 3001, loss: 0.9098, accuracy: 0.8010
# Iter : 4001, loss: 0.7718, accuracy: 0.8090
# Iter : 5001, loss: 0.7143, accuracy: 0.7940
# Iter : 6001, loss: 0.6507, accuracy: 0.8010
# Iter : 7001, loss: 0.5261, accuracy: 0.7940
# Iter : 8001, loss: 0.5231, accuracy: 0.7880
# Iter : 9001, loss: 1.3419, accuracy: 0.7910
# Iter : 10001, loss: 0.6922, accuracy: 0.7870
# Iter : 11001, loss: 1.0407, accuracy: 0.8000
# Iter : 12001, loss: 0.9878, accuracy: 0.7800
# Iter : 13001, loss: 0.5587, accuracy: 0.8120
# Iter : 14001, loss: 0.3192, accuracy: 0.8110
# Iter : 15001, loss: 0.5689, accuracy: 0.8110
# Iter : 16001, loss: 0.7959, accuracy: 0.7900
# Iter : 17001, loss: 0.3900, accuracy: 0.8080
# Iter : 18001, loss: 0.4009, accuracy: 0.7990
# Iter : 19001, loss: 0.9156, accuracy: 0.7870
# Going to sleep ...
# Iter : 1001, loss: 0.0508, accuracy: 0.8290
# Iter : 2001, loss: 0.0013, accuracy: 0.8210
# Iter : 3001, loss: 0.0020, accuracy: 0.8390
# Iter : 4001, loss: 0.2462, accuracy: 0.8330
# Iter : 5001, loss: 0.0117, accuracy: 0.8420
# Iter : 6001, loss: 0.4609, accuracy: 0.8470
# Iter : 7001, loss: 0.0071, accuracy: 0.8220
# Iter : 8001, loss: 0.6393, accuracy: 0.8000
# Iter : 9001, loss: 0.3977, accuracy: 0.8230
# Iter : 10001, loss: 0.0021, accuracy: 0.8440
# Iter : 11001, loss: 0.7218, accuracy: 0.8140
# Iter : 12001, loss: 0.0495, accuracy: 0.8280
# Iter : 13001, loss: 0.0051, accuracy: 0.8060
# Iter : 14001, loss: 0.0021, accuracy: 0.8390
# Iter : 15001, loss: 0.9213, accuracy: 0.7780
# Iter : 16001, loss: 1.0091, accuracy: 0.8290
# Iter : 17001, loss: 0.8842, accuracy: 0.8210
# Iter : 18001, loss: 0.0052, accuracy: 0.8410
# Iter : 19001, loss: 0.6759, accuracy: 0.8150
# Going to awake phase ...
# Iter : 1001, loss: 1.1383, accuracy: 0.8190
# Iter : 2001, loss: 1.0494, accuracy: 0.7920
# Iter : 3001, loss: 0.6119, accuracy: 0.8040
# Iter : 4001, loss: 0.7451, accuracy: 0.7860
# Iter : 5001, loss: 0.5770, accuracy: 0.8150
# Iter : 6001, loss: 0.8307, accuracy: 0.8140
# Iter : 7001, loss: 0.5600, accuracy: 0.8190
# Iter : 8001, loss: 0.9754, accuracy: 0.8120
# Iter : 9001, loss: 0.5226, accuracy: 0.8040
# Iter : 10001, loss: 0.5278, accuracy: 0.8080
# Iter : 11001, loss: 0.6068, accuracy: 0.8240
# Iter : 12001, loss: 0.3897, accuracy: 0.8160
# Iter : 13001, loss: 0.8665, accuracy: 0.8250
# Iter : 14001, loss: 0.7407, accuracy: 0.8270
# Iter : 15001, loss: 1.0032, accuracy: 0.8300
# Iter : 16001, loss: 0.9077, accuracy: 0.8350
# Iter : 17001, loss: 0.8365, accuracy: 0.8390
# Iter : 18001, loss: 0.8388, accuracy: 0.8660
# Iter : 19001, loss: 0.7942, accuracy: 0.8540
# Iter : 20001, loss: 0.8416, accuracy: 0.8570
# Iter : 21001, loss: 0.9609, accuracy: 0.8610
# Iter : 22001, loss: 1.0639, accuracy: 0.8780
# Iter : 23001, loss: 0.6158, accuracy: 0.8950
# Iter : 24001, loss: 0.7368, accuracy: 0.8970
# Iter : 25001, loss: 0.9744, accuracy: 0.8820
# Iter : 26001, loss: 0.7241, accuracy: 0.8940
# Iter : 27001, loss: 1.0208, accuracy: 0.8980
# Iter : 28001, loss: 0.7759, accuracy: 0.8830
# Iter : 29001, loss: 0.7353, accuracy: 0.8860
# Iter : 30001, loss: 0.4649, accuracy: 0.8880
# Iter : 31001, loss: 0.5799, accuracy: 0.8500
# Iter : 32001, loss: 0.4222, accuracy: 0.8690
# Iter : 33001, loss: 1.1053, accuracy: 0.8030
# Iter : 34001, loss: 0.4633, accuracy: 0.7990
# Iter : 35001, loss: 1.0348, accuracy: 0.7950
# Iter : 36001, loss: 0.4142, accuracy: 0.8040
# Iter : 37001, loss: 0.6663, accuracy: 0.8070
# Iter : 38001, loss: 0.9187, accuracy: 0.8170
# Iter : 39001, loss: 0.5953, accuracy: 0.8040
# Iter : 40001, loss: 0.8684, accuracy: 0.8210
# Iter : 41001, loss: 0.4737, accuracy: 0.8130
# Iter : 42001, loss: 0.7411, accuracy: 0.8160
# Iter : 43001, loss: 0.6580, accuracy: 0.8130
# Iter : 44001, loss: 0.4358, accuracy: 0.8380
# Iter : 45001, loss: 0.7043, accuracy: 0.8130
# Iter : 46001, loss: 0.6802, accuracy: 0.8490
# Iter : 47001, loss: 0.5664, accuracy: 0.8560
# Iter : 48001, loss: 0.7250, accuracy: 0.8780
# Iter : 49001, loss: 0.7573, accuracy: 0.8550
# Iter : 50001, loss: 0.8025, accuracy: 0.8670
# Iter : 51001, loss: 0.7215, accuracy: 0.8690
# Iter : 52001, loss: 0.7198, accuracy: 0.8740
# Iter : 53001, loss: 0.9764, accuracy: 0.8920
# Iter : 54001, loss: 0.4748, accuracy: 0.8840
# Iter : 55001, loss: 0.4666, accuracy: 0.9010
# Iter : 56001, loss: 0.3963, accuracy: 0.8980
# Iter : 57001, loss: 0.4372, accuracy: 0.8980
# Iter : 58001, loss: 0.4897, accuracy: 0.9020
# Iter : 59001, loss: 1.0901, accuracy: 0.9050
# Iter : 60001, loss: 0.5646, accuracy: 0.9010
# Iter : 61001, loss: 0.8889, accuracy: 0.8870
# Iter : 62001, loss: 0.6574, accuracy: 0.8900
# Iter : 63001, loss: 0.6436, accuracy: 0.8960
# Iter : 64001, loss: 0.9870, accuracy: 0.9090
# Iter : 65001, loss: 0.6814, accuracy: 0.9150
# Iter : 66001, loss: 1.2224, accuracy: 0.9030
# Iter : 67001, loss: 1.1630, accuracy: 0.9040
# Iter : 68001, loss: 0.9343, accuracy: 0.9100
# Iter : 69001, loss: 0.8289, accuracy: 0.9040
# Iter : 70001, loss: 0.6376, accuracy: 0.8930
# Iter : 71001, loss: 0.6677, accuracy: 0.8810
# Iter : 72001, loss: 0.6774, accuracy: 0.8880
# Iter : 73001, loss: 0.5433, accuracy: 0.8960
# Iter : 74001, loss: 1.2798, accuracy: 0.9000
# Iter : 75001, loss: 0.6750, accuracy: 0.8960
# Iter : 76001, loss: 0.8215, accuracy: 0.8940
# Iter : 77001, loss: 0.9154, accuracy: 0.8840
# Iter : 78001, loss: 0.9252, accuracy: 0.8970
# Iter : 79001, loss: 0.6725, accuracy: 0.9020
# Doing rep  4
# Iter : 1001, loss: 0.9235, accuracy: 0.4370
# Iter : 2001, loss: 0.5513, accuracy: 0.7080
# Iter : 3001, loss: 1.1030, accuracy: 0.7990
# Iter : 4001, loss: 0.4321, accuracy: 0.7970
# Iter : 5001, loss: 0.9624, accuracy: 0.8010
# Iter : 6001, loss: 0.5813, accuracy: 0.8030
# Iter : 7001, loss: 1.0487, accuracy: 0.7950
# Iter : 8001, loss: 1.1916, accuracy: 0.7990
# Iter : 9001, loss: 0.3778, accuracy: 0.7820
# Iter : 10001, loss: 0.4042, accuracy: 0.8200
# Iter : 11001, loss: 0.5335, accuracy: 0.7990
# Iter : 12001, loss: 0.9309, accuracy: 0.7960
# Iter : 13001, loss: 0.6456, accuracy: 0.8200
# Iter : 14001, loss: 0.5821, accuracy: 0.7980
# Iter : 15001, loss: 0.9507, accuracy: 0.7870
# Iter : 16001, loss: 0.5971, accuracy: 0.8060
# Iter : 17001, loss: 0.3172, accuracy: 0.8210
# Iter : 18001, loss: 0.5606, accuracy: 0.8010
# Iter : 19001, loss: 0.4493, accuracy: 0.8050
# Going to sleep ...
# Iter : 1001, loss: 0.0192, accuracy: 0.8070
# Iter : 2001, loss: 0.0485, accuracy: 0.8250
# Iter : 3001, loss: 0.6134, accuracy: 0.8130
# Iter : 4001, loss: 0.0102, accuracy: 0.7940
# Iter : 5001, loss: 0.0281, accuracy: 0.7840
# Iter : 6001, loss: 0.8443, accuracy: 0.7730
# Iter : 7001, loss: 0.0021, accuracy: 0.8130
# Iter : 8001, loss: 0.9654, accuracy: 0.7950
# Iter : 9001, loss: 0.5877, accuracy: 0.8210
# Iter : 10001, loss: 0.0190, accuracy: 0.8070
# Iter : 11001, loss: 0.0119, accuracy: 0.7960
# Iter : 12001, loss: 0.0007, accuracy: 0.8050
# Iter : 13001, loss: 0.0027, accuracy: 0.8090
# Iter : 14001, loss: 0.5516, accuracy: 0.7930
# Iter : 15001, loss: 0.0652, accuracy: 0.8050
# Iter : 16001, loss: 0.0142, accuracy: 0.7990
# Iter : 17001, loss: 0.0617, accuracy: 0.7910
# Iter : 18001, loss: 0.5577, accuracy: 0.8030
# Iter : 19001, loss: 1.2861, accuracy: 0.7970
# Going to awake phase ...
# Iter : 1001, loss: 0.4687, accuracy: 0.8230
# Iter : 2001, loss: 0.9623, accuracy: 0.8200
# Iter : 3001, loss: 0.4205, accuracy: 0.8180
# Iter : 4001, loss: 0.6408, accuracy: 0.8130
# Iter : 5001, loss: 0.4015, accuracy: 0.8040
# Iter : 6001, loss: 1.0115, accuracy: 0.8220
# Iter : 7001, loss: 1.0156, accuracy: 0.8120
# Iter : 8001, loss: 0.7137, accuracy: 0.8540
# Iter : 9001, loss: 1.0185, accuracy: 0.8620
# Iter : 10001, loss: 0.8356, accuracy: 0.8640
# Iter : 11001, loss: 0.5461, accuracy: 0.8750
# Iter : 12001, loss: 0.5862, accuracy: 0.8660
# Iter : 13001, loss: 0.6127, accuracy: 0.8690
# Iter : 14001, loss: 1.2061, accuracy: 0.8720
# Iter : 15001, loss: 0.6084, accuracy: 0.8630
# Iter : 16001, loss: 1.1084, accuracy: 0.8830
# Iter : 17001, loss: 0.6618, accuracy: 0.8530
# Iter : 18001, loss: 0.6535, accuracy: 0.8660
# Iter : 19001, loss: 0.6607, accuracy: 0.8670
# Iter : 20001, loss: 0.6203, accuracy: 0.8610
# Iter : 21001, loss: 0.6726, accuracy: 0.8440
# Iter : 22001, loss: 0.7383, accuracy: 0.8530
# Iter : 23001, loss: 0.6562, accuracy: 0.8660
# Iter : 24001, loss: 0.7894, accuracy: 0.8470
# Iter : 25001, loss: 1.0147, accuracy: 0.8510
# Iter : 26001, loss: 0.3449, accuracy: 0.8710
# Iter : 27001, loss: 0.7482, accuracy: 0.8650
# Iter : 28001, loss: 0.2916, accuracy: 0.8670
# Iter : 29001, loss: 0.7938, accuracy: 0.8780
# Iter : 30001, loss: 0.6679, accuracy: 0.8740
# Iter : 31001, loss: 0.4949, accuracy: 0.8680
# Iter : 32001, loss: 1.1829, accuracy: 0.8600
# Iter : 33001, loss: 0.4090, accuracy: 0.8730
# Iter : 34001, loss: 0.4033, accuracy: 0.8740
# Iter : 35001, loss: 0.6202, accuracy: 0.8630
# Iter : 36001, loss: 1.1410, accuracy: 0.8650
# Iter : 37001, loss: 0.9274, accuracy: 0.8590
# Iter : 38001, loss: 1.1404, accuracy: 0.8660
# Iter : 39001, loss: 0.4487, accuracy: 0.8620
# Iter : 40001, loss: 0.7207, accuracy: 0.8600
# Iter : 41001, loss: 0.6796, accuracy: 0.8710
# Iter : 42001, loss: 0.7168, accuracy: 0.8800
# Iter : 43001, loss: 0.5687, accuracy: 0.8790
# Iter : 44001, loss: 0.4616, accuracy: 0.8760
# Iter : 45001, loss: 0.5895, accuracy: 0.8380
# Iter : 46001, loss: 0.4192, accuracy: 0.8420
# Iter : 47001, loss: 0.4113, accuracy: 0.8650
# Iter : 48001, loss: 0.6828, accuracy: 0.8740
# Iter : 49001, loss: 0.5608, accuracy: 0.8620
# Iter : 50001, loss: 0.9865, accuracy: 0.8740
# Iter : 51001, loss: 0.6304, accuracy: 0.8860
# Iter : 52001, loss: 0.4325, accuracy: 0.8690
# Iter : 53001, loss: 0.6519, accuracy: 0.8640
# Iter : 54001, loss: 0.4062, accuracy: 0.8940
# Iter : 55001, loss: 0.9294, accuracy: 0.8850
# Iter : 56001, loss: 0.6628, accuracy: 0.8620
# Iter : 57001, loss: 0.7675, accuracy: 0.8730
# Iter : 58001, loss: 0.4274, accuracy: 0.8840
# Iter : 59001, loss: 1.0597, accuracy: 0.8860
# Iter : 60001, loss: 0.9066, accuracy: 0.8840
# Iter : 61001, loss: 0.6838, accuracy: 0.8920
# Iter : 62001, loss: 0.8018, accuracy: 0.8760
# Iter : 63001, loss: 0.3601, accuracy: 0.8730
# Iter : 64001, loss: 0.6775, accuracy: 0.8660
# Iter : 65001, loss: 0.4446, accuracy: 0.8790
# Iter : 66001, loss: 0.6343, accuracy: 0.8660
# Iter : 67001, loss: 0.6981, accuracy: 0.8350
# Iter : 68001, loss: 0.8893, accuracy: 0.8620
# Iter : 69001, loss: 0.6714, accuracy: 0.8790
# Iter : 70001, loss: 0.8537, accuracy: 0.8890
# Iter : 71001, loss: 0.5787, accuracy: 0.8780
# Iter : 72001, loss: 0.5609, accuracy: 0.8530
# Iter : 73001, loss: 0.9843, accuracy: 0.8520
# Iter : 74001, loss: 0.6919, accuracy: 0.8500
# Iter : 75001, loss: 0.5797, accuracy: 0.8770
# Iter : 76001, loss: 0.4829, accuracy: 0.8850
# Iter : 77001, loss: 0.4917, accuracy: 0.8910
# Iter : 78001, loss: 0.7448, accuracy: 0.8840
# Iter : 79001, loss: 0.5024, accuracy: 0.8780

# %%
### initial training ###
reps = 5
test_acc_not_sparse = [[] for _ in range(reps)]

for rep in range(reps):
    print('Doing rep ', rep)
    
    data = get_sequence(total_samples, 2, 3, random_state=rep)
    # data = pd.read_csv("../Seq_500000.txt")['seq'][0]
    
    
    data_set = Dataset_converter(data[:initial_training_sample], working_memory, short_term_memory)
    
    main_model = RNN(len(tokens)*working_memory, hidden_size_hippocampus, hidden_size_cortex, num_layers)
    main_model.rnn_cortex.requires_grad = False
    
    train_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    
    optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    criterion = torch.nn.CrossEntropyLoss()
    
    total = 0
    correct = np.zeros(1000,dtype=float)
    for X, y in train_loader:
        optimizer.zero_grad()
    
        if total == 0:
            predicted_y, hidden = main_model(X)
        else:
            predicted_y, hidden = main_model(X, mem)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            total += 1
            if true_y == estimated_y:
                    correct[total%1000] = 1
            else:
                correct[total%1000] = 0
    
            test_acc_not_sparse[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if total%1000 == 0:
                print(f'Iter : {total+1}, loss: {loss:.4f}, accuracy: {test_acc_not_sparse[rep][-1]:.4f}')


    print('Going to sleep ...')
    data_sleep = generate_sleep_samples(main_model, sleep_samples)
    main_model.rnn_cortex.requires_grad = True
    data_set = Dataset_converter(data_sleep, working_memory, short_term_memory)
    sleep_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    
    criterion = torch.nn.CrossEntropyLoss()
    sleep_iter = 0
    
    for X, y in sleep_loader:
        optimizer.zero_grad()
    
        if sleep_iter == 0:
            predicted_y, hidden, hidden_sleep = main_model(X, mem, sleep=True)
        else:
            predicted_y, hidden, hidden_sleep = main_model(X, mem, mem_, sleep=True)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            mem_ = hidden_sleep.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            sleep_iter += 1
            if true_y == estimated_y:
                    correct[sleep_iter%1000] = 1
            else:
                correct[sleep_iter%1000] = 0
    
            test_acc_not_sparse[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if sleep_iter%1000 == 0:
                print(f'Iter : {sleep_iter+1}, loss: {loss:.4f}, accuracy: {test_acc_not_sparse[rep][-1]:.4f}')


    print('Going to awake phase ...')
    #data_sleep = generate_sleep_samples(main_model, sleep_samples)
    main_model.rnn_cortex.requires_grad = False
    data_set = Dataset_converter(data[initial_training_sample:], working_memory, short_term_memory)
    sleep_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    criterion = torch.nn.CrossEntropyLoss()
    sleep_iter = 0
    
    for X, y in sleep_loader:
        optimizer.zero_grad()
    
        if sleep_iter == 0:
            predicted_y, hidden, hidden_sleep = main_model(X, mem, sleep=True)
        else:
            predicted_y, hidden, hidden_sleep = main_model(X, mem, mem_, sleep=True)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            mem_ = hidden_sleep.clone()
            
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            sleep_iter += 1
            if true_y == estimated_y:
                    correct[sleep_iter%1000] = 1
            else:
                correct[sleep_iter%1000] = 0
    
            test_acc_not_sparse[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if sleep_iter%1000 == 0:
                print(f'Iter : {sleep_iter+1}, loss: {loss:.4f}, accuracy: {test_acc_not_sparse[rep][-1]:.4f}')
# Out:
# Doing rep  0
# Iter : 1001, loss: 1.3646, accuracy: 0.4530
# Iter : 2001, loss: 1.1714, accuracy: 0.6760
# Iter : 3001, loss: 0.4624, accuracy: 0.7760
# Iter : 4001, loss: 1.0601, accuracy: 0.7880
# Iter : 5001, loss: 1.2393, accuracy: 0.8150
# Iter : 6001, loss: 1.1556, accuracy: 0.7740
# Iter : 7001, loss: 0.4504, accuracy: 0.7970
# Iter : 8001, loss: 1.1774, accuracy: 0.8180
# Iter : 9001, loss: 0.8313, accuracy: 0.7900
# Iter : 10001, loss: 0.7918, accuracy: 0.8030
# Iter : 11001, loss: 0.7439, accuracy: 0.7970
# Iter : 12001, loss: 0.9490, accuracy: 0.7990
# Iter : 13001, loss: 0.5543, accuracy: 0.8000
# Iter : 14001, loss: 0.7357, accuracy: 0.7920
# Iter : 15001, loss: 0.4304, accuracy: 0.7850
# Iter : 16001, loss: 0.8049, accuracy: 0.8060
# Iter : 17001, loss: 0.5859, accuracy: 0.7900
# Iter : 18001, loss: 1.0668, accuracy: 0.7880
# Iter : 19001, loss: 0.7841, accuracy: 0.7720
# Going to sleep ...
# Iter : 1001, loss: 0.8058, accuracy: 0.8020
# Iter : 2001, loss: 0.0080, accuracy: 0.7880
# Iter : 3001, loss: 0.0133, accuracy: 0.7960
# Iter : 4001, loss: 0.0071, accuracy: 0.7900
# Iter : 5001, loss: 0.0060, accuracy: 0.7970
# Iter : 6001, loss: 1.0576, accuracy: 0.8120
# Iter : 7001, loss: 0.0030, accuracy: 0.8050
# Iter : 8001, loss: 0.0032, accuracy: 0.7950
# Iter : 9001, loss: 0.0080, accuracy: 0.7950
# Iter : 10001, loss: 0.9078, accuracy: 0.8000
# Iter : 11001, loss: 0.0066, accuracy: 0.8220
# Iter : 12001, loss: 0.0305, accuracy: 0.7920
# Iter : 13001, loss: 0.4487, accuracy: 0.7940
# Iter : 14001, loss: 0.0013, accuracy: 0.7970
# Iter : 15001, loss: 0.0042, accuracy: 0.7930
# Iter : 16001, loss: 0.9787, accuracy: 0.7850
# Iter : 17001, loss: 0.0010, accuracy: 0.8090
# Iter : 18001, loss: 0.0186, accuracy: 0.7830
# Iter : 19001, loss: 0.8040, accuracy: 0.8040
# Going to awake phase ...
# Iter : 1001, loss: 1.3517, accuracy: 0.7930
# Iter : 2001, loss: 0.8460, accuracy: 0.8110
# Iter : 3001, loss: 1.0093, accuracy: 0.8290
# Iter : 4001, loss: 0.8637, accuracy: 0.7810
# Iter : 5001, loss: 0.8915, accuracy: 0.7990
# Iter : 6001, loss: 0.6062, accuracy: 0.7870
# Iter : 7001, loss: 0.7459, accuracy: 0.8150
# Iter : 8001, loss: 0.5243, accuracy: 0.8050
# Iter : 9001, loss: 0.7286, accuracy: 0.8030
# Iter : 10001, loss: 0.7652, accuracy: 0.8080
# Iter : 11001, loss: 0.8018, accuracy: 0.8070
# Iter : 12001, loss: 0.4980, accuracy: 0.8030
# Iter : 13001, loss: 0.4296, accuracy: 0.8030
# Iter : 14001, loss: 0.7916, accuracy: 0.8020
# Iter : 15001, loss: 0.9908, accuracy: 0.7850
# Iter : 16001, loss: 1.0775, accuracy: 0.7890
# Iter : 17001, loss: 0.7912, accuracy: 0.8030
# Iter : 18001, loss: 0.6655, accuracy: 0.7910
# Iter : 19001, loss: 0.5547, accuracy: 0.8090
# Iter : 20001, loss: 1.1445, accuracy: 0.8020
# Iter : 21001, loss: 0.5077, accuracy: 0.8100
# Iter : 22001, loss: 0.5573, accuracy: 0.8080
# Iter : 23001, loss: 0.5476, accuracy: 0.7970
# Iter : 24001, loss: 0.3902, accuracy: 0.8040
# Iter : 25001, loss: 0.6640, accuracy: 0.7880
# Iter : 26001, loss: 1.0140, accuracy: 0.7950
# Iter : 27001, loss: 0.7146, accuracy: 0.8020
# Iter : 28001, loss: 0.9927, accuracy: 0.7950
# Iter : 29001, loss: 0.5466, accuracy: 0.7910
# Iter : 30001, loss: 0.6041, accuracy: 0.8160
# Iter : 31001, loss: 0.6945, accuracy: 0.8020
# Iter : 32001, loss: 0.5769, accuracy: 0.7850
# Iter : 33001, loss: 0.7379, accuracy: 0.8220
# Iter : 34001, loss: 1.0288, accuracy: 0.7960
# Iter : 35001, loss: 0.5607, accuracy: 0.7960
# Iter : 36001, loss: 0.8883, accuracy: 0.8020
# Iter : 37001, loss: 0.8254, accuracy: 0.7920
# Iter : 38001, loss: 0.6673, accuracy: 0.7830
# Iter : 39001, loss: 0.8478, accuracy: 0.7930
# Iter : 40001, loss: 0.8187, accuracy: 0.7910
# Iter : 41001, loss: 0.7922, accuracy: 0.7970
# Iter : 42001, loss: 0.7412, accuracy: 0.8120
# Iter : 43001, loss: 0.8184, accuracy: 0.8120
# Iter : 44001, loss: 0.8902, accuracy: 0.7920
# Iter : 45001, loss: 0.4323, accuracy: 0.8110
# Iter : 46001, loss: 0.6512, accuracy: 0.7900
# Iter : 47001, loss: 0.7510, accuracy: 0.8000
# Iter : 48001, loss: 0.7136, accuracy: 0.8050
# Iter : 49001, loss: 0.7943, accuracy: 0.8010
# Iter : 50001, loss: 0.6607, accuracy: 0.8160
# Iter : 51001, loss: 1.0119, accuracy: 0.8190
# Iter : 52001, loss: 0.8063, accuracy: 0.7860
# Iter : 53001, loss: 0.5561, accuracy: 0.8090
# Iter : 54001, loss: 0.7339, accuracy: 0.8090
# Iter : 55001, loss: 0.8974, accuracy: 0.8070
# Iter : 56001, loss: 0.6969, accuracy: 0.7920
# Iter : 57001, loss: 1.0220, accuracy: 0.8080
# Iter : 58001, loss: 0.6914, accuracy: 0.8280
# Iter : 59001, loss: 0.8297, accuracy: 0.8000
# Iter : 60001, loss: 1.1197, accuracy: 0.8010
# Iter : 61001, loss: 0.6552, accuracy: 0.8080
# Iter : 62001, loss: 0.7579, accuracy: 0.8180
# Iter : 63001, loss: 0.7551, accuracy: 0.7890
# Iter : 64001, loss: 0.7827, accuracy: 0.8070
# Iter : 65001, loss: 0.8495, accuracy: 0.8010
# Iter : 66001, loss: 1.1176, accuracy: 0.7870
# Iter : 67001, loss: 0.6032, accuracy: 0.7990
# Iter : 68001, loss: 1.1470, accuracy: 0.7990
# Iter : 69001, loss: 0.4800, accuracy: 0.7860
# Iter : 70001, loss: 0.8598, accuracy: 0.7960
# Iter : 71001, loss: 0.7486, accuracy: 0.8010
# Iter : 72001, loss: 0.8252, accuracy: 0.8110
# Iter : 73001, loss: 1.1206, accuracy: 0.7990
# Iter : 74001, loss: 1.0131, accuracy: 0.8090
# Iter : 75001, loss: 1.0388, accuracy: 0.7970
# Iter : 76001, loss: 0.4724, accuracy: 0.8190
# Iter : 77001, loss: 0.8778, accuracy: 0.7930
# Iter : 78001, loss: 0.7747, accuracy: 0.8100
# Iter : 79001, loss: 0.7758, accuracy: 0.7820
# Doing rep  1
# Iter : 1001, loss: 0.7426, accuracy: 0.3970
# Iter : 2001, loss: 0.6336, accuracy: 0.6810
# Iter : 3001, loss: 0.5548, accuracy: 0.7900
# Iter : 4001, loss: 0.5355, accuracy: 0.7930
# Iter : 5001, loss: 0.2658, accuracy: 0.8140
# Iter : 6001, loss: 0.7548, accuracy: 0.7900
# Iter : 7001, loss: 0.5422, accuracy: 0.7970
# Iter : 8001, loss: 0.6585, accuracy: 0.7820
# Iter : 9001, loss: 0.8245, accuracy: 0.7890
# Iter : 10001, loss: 1.0686, accuracy: 0.7880
# Iter : 11001, loss: 0.5512, accuracy: 0.8250
# Iter : 12001, loss: 0.5318, accuracy: 0.8070
# Iter : 13001, loss: 0.8336, accuracy: 0.7920
# Iter : 14001, loss: 0.4873, accuracy: 0.8020
# Iter : 15001, loss: 0.9789, accuracy: 0.7870
# Iter : 16001, loss: 0.8677, accuracy: 0.7920
# Iter : 17001, loss: 0.9593, accuracy: 0.7940
# Iter : 18001, loss: 0.6648, accuracy: 0.8030
# Iter : 19001, loss: 0.6066, accuracy: 0.7960
# Going to sleep ...
# Iter : 1001, loss: 1.3010, accuracy: 0.8130
# Iter : 2001, loss: 5.2796, accuracy: 0.8260
# Iter : 3001, loss: 0.0096, accuracy: 0.8120
# Iter : 4001, loss: 0.0074, accuracy: 0.8380
# Iter : 5001, loss: 0.0150, accuracy: 0.8180
# Iter : 6001, loss: 0.0062, accuracy: 0.8330
# Iter : 7001, loss: 0.5965, accuracy: 0.8240
# Iter : 8001, loss: 0.6010, accuracy: 0.8030
# Iter : 9001, loss: 0.1580, accuracy: 0.8280
# Iter : 10001, loss: 0.0086, accuracy: 0.8190
# Iter : 11001, loss: 0.5255, accuracy: 0.8070
# Iter : 12001, loss: 0.0235, accuracy: 0.8270
# Iter : 13001, loss: 0.0131, accuracy: 0.8040
# Iter : 14001, loss: 0.7169, accuracy: 0.8400
# Iter : 15001, loss: 0.0109, accuracy: 0.8100
# Iter : 16001, loss: 0.0236, accuracy: 0.8010
# Iter : 17001, loss: 0.0024, accuracy: 0.7860
# Iter : 18001, loss: 1.2412, accuracy: 0.8340
# Iter : 19001, loss: 0.0124, accuracy: 0.8270
# Going to awake phase ...
# Iter : 1001, loss: 0.6244, accuracy: 0.7990
# Iter : 2001, loss: 0.7172, accuracy: 0.8150
# Iter : 3001, loss: 0.6844, accuracy: 0.7970
# Iter : 4001, loss: 0.7039, accuracy: 0.7750
# Iter : 5001, loss: 0.5857, accuracy: 0.7950
# Iter : 6001, loss: 0.3047, accuracy: 0.7880
# Iter : 7001, loss: 0.7337, accuracy: 0.7950
# Iter : 8001, loss: 0.4862, accuracy: 0.8180
# Iter : 9001, loss: 0.8019, accuracy: 0.8030
# Iter : 10001, loss: 0.7516, accuracy: 0.8020
# Iter : 11001, loss: 1.1275, accuracy: 0.8000
# Iter : 12001, loss: 0.6797, accuracy: 0.7960
# Iter : 13001, loss: 0.4515, accuracy: 0.8130
# Iter : 14001, loss: 0.8115, accuracy: 0.7940
# Iter : 15001, loss: 0.8118, accuracy: 0.8120
# Iter : 16001, loss: 0.7361, accuracy: 0.7960
# Iter : 17001, loss: 0.4751, accuracy: 0.8070
# Iter : 18001, loss: 0.9271, accuracy: 0.7990
# Iter : 19001, loss: 0.6516, accuracy: 0.8090
# Iter : 20001, loss: 0.4709, accuracy: 0.8020
# Iter : 21001, loss: 0.6971, accuracy: 0.7960
# Iter : 22001, loss: 0.8552, accuracy: 0.8110
# Iter : 23001, loss: 0.9469, accuracy: 0.8050
# Iter : 24001, loss: 0.5369, accuracy: 0.8090
# Iter : 25001, loss: 0.8883, accuracy: 0.8080
# Iter : 26001, loss: 0.6690, accuracy: 0.8050
# Iter : 27001, loss: 0.9707, accuracy: 0.8050
# Iter : 28001, loss: 0.4619, accuracy: 0.7860
# Iter : 29001, loss: 0.6531, accuracy: 0.7860
# Iter : 30001, loss: 0.5961, accuracy: 0.7960
# Iter : 31001, loss: 0.5631, accuracy: 0.8010
# Iter : 32001, loss: 0.7643, accuracy: 0.7910
# Iter : 33001, loss: 0.8672, accuracy: 0.7990
# Iter : 34001, loss: 0.8675, accuracy: 0.8100
# Iter : 35001, loss: 0.9142, accuracy: 0.7960
# Iter : 36001, loss: 0.5170, accuracy: 0.8180
# Iter : 37001, loss: 0.7725, accuracy: 0.8030
# Iter : 38001, loss: 0.9271, accuracy: 0.8170
# Iter : 39001, loss: 1.0572, accuracy: 0.8010
# Iter : 40001, loss: 0.8957, accuracy: 0.8050
# Iter : 41001, loss: 0.5678, accuracy: 0.8090
# Iter : 42001, loss: 0.4759, accuracy: 0.7950
# Iter : 43001, loss: 0.7198, accuracy: 0.7910
# Iter : 44001, loss: 0.5716, accuracy: 0.8020
# Iter : 45001, loss: 0.6627, accuracy: 0.8060
# Iter : 46001, loss: 0.6427, accuracy: 0.7970
# Iter : 47001, loss: 0.6819, accuracy: 0.8120
# Iter : 48001, loss: 0.9637, accuracy: 0.7960
# Iter : 49001, loss: 0.7058, accuracy: 0.7970
# Iter : 50001, loss: 0.5779, accuracy: 0.8060
# Iter : 51001, loss: 1.0614, accuracy: 0.8040
# Iter : 52001, loss: 0.5757, accuracy: 0.8020
# Iter : 53001, loss: 0.6316, accuracy: 0.8260
# Iter : 54001, loss: 0.9315, accuracy: 0.8010
# Iter : 55001, loss: 0.6127, accuracy: 0.8030
# Iter : 56001, loss: 0.7831, accuracy: 0.7960
# Iter : 57001, loss: 0.5326, accuracy: 0.8020
# Iter : 58001, loss: 0.9742, accuracy: 0.8160
# Iter : 59001, loss: 0.3635, accuracy: 0.7940
# Iter : 60001, loss: 1.1278, accuracy: 0.7870
# Iter : 61001, loss: 0.7387, accuracy: 0.8140
# Iter : 62001, loss: 0.7372, accuracy: 0.7970
# Iter : 63001, loss: 0.9694, accuracy: 0.7780
# Iter : 64001, loss: 0.4917, accuracy: 0.8150
# Iter : 65001, loss: 0.5172, accuracy: 0.7960
# Iter : 66001, loss: 0.4335, accuracy: 0.8200
# Iter : 67001, loss: 0.5417, accuracy: 0.7920
# Iter : 68001, loss: 1.1059, accuracy: 0.8280
# Iter : 69001, loss: 0.5315, accuracy: 0.8040
# Iter : 70001, loss: 0.7690, accuracy: 0.8210
# Iter : 71001, loss: 0.5721, accuracy: 0.8710
# Iter : 72001, loss: 0.7338, accuracy: 0.8880
# Iter : 73001, loss: 0.9011, accuracy: 0.8980
# Iter : 74001, loss: 0.6628, accuracy: 0.9150
# Iter : 75001, loss: 0.5594, accuracy: 0.9020
# Iter : 76001, loss: 0.3954, accuracy: 0.9000
# Iter : 77001, loss: 0.6433, accuracy: 0.9050
# Iter : 78001, loss: 0.6027, accuracy: 0.8830
# Iter : 79001, loss: 0.6899, accuracy: 0.8940
# Doing rep  2
# Iter : 1001, loss: 1.0110, accuracy: 0.4460
# Iter : 2001, loss: 0.4640, accuracy: 0.7560
# Iter : 3001, loss: 0.5214, accuracy: 0.7870
# Iter : 4001, loss: 0.5287, accuracy: 0.8270
# Iter : 5001, loss: 0.4013, accuracy: 0.8060
# Iter : 6001, loss: 0.5029, accuracy: 0.8040
# Iter : 7001, loss: 1.1161, accuracy: 0.7970
# Iter : 8001, loss: 0.7191, accuracy: 0.8080
# Iter : 9001, loss: 0.5877, accuracy: 0.8050
# Iter : 10001, loss: 0.5376, accuracy: 0.8030
# Iter : 11001, loss: 0.6434, accuracy: 0.8040
# Iter : 12001, loss: 0.5698, accuracy: 0.8030
# Iter : 13001, loss: 0.7484, accuracy: 0.8120
# Iter : 14001, loss: 1.2970, accuracy: 0.8090
# Iter : 15001, loss: 0.6589, accuracy: 0.8070
# Iter : 16001, loss: 0.4389, accuracy: 0.8100
# Iter : 17001, loss: 0.7210, accuracy: 0.8140
# Iter : 18001, loss: 1.0340, accuracy: 0.7940
# Iter : 19001, loss: 0.6478, accuracy: 0.7940
# Going to sleep ...
# Iter : 1001, loss: 0.0053, accuracy: 0.8000
# Iter : 2001, loss: 0.0173, accuracy: 0.8020
# Iter : 3001, loss: 0.0998, accuracy: 0.7930
# Iter : 4001, loss: 0.0014, accuracy: 0.7770
# Iter : 5001, loss: 0.0053, accuracy: 0.7920
# Iter : 6001, loss: 0.0073, accuracy: 0.8060
# Iter : 7001, loss: 0.0202, accuracy: 0.8050
# Iter : 8001, loss: 0.0074, accuracy: 0.7900
# Iter : 9001, loss: 0.6874, accuracy: 0.7990
# Iter : 10001, loss: 0.0079, accuracy: 0.7900
# Iter : 11001, loss: 0.0207, accuracy: 0.7990
# Iter : 12001, loss: 0.0073, accuracy: 0.8030
# Iter : 13001, loss: 0.5341, accuracy: 0.7970
# Iter : 14001, loss: 0.0048, accuracy: 0.8170
# Iter : 15001, loss: 0.0028, accuracy: 0.8110
# Iter : 16001, loss: 0.0025, accuracy: 0.8080
# Iter : 17001, loss: 0.0261, accuracy: 0.7880
# Iter : 18001, loss: 0.0022, accuracy: 0.8150
# Iter : 19001, loss: 0.0029, accuracy: 0.7950
# Going to awake phase ...
# Iter : 1001, loss: 0.7598, accuracy: 0.8060
# Iter : 2001, loss: 0.8443, accuracy: 0.7880
# Iter : 3001, loss: 0.6137, accuracy: 0.7940
# Iter : 4001, loss: 0.4664, accuracy: 0.7920
# Iter : 5001, loss: 0.7284, accuracy: 0.7860
# Iter : 6001, loss: 0.7079, accuracy: 0.8120
# Iter : 7001, loss: 0.4722, accuracy: 0.7940
# Iter : 8001, loss: 0.8854, accuracy: 0.7990
# Iter : 9001, loss: 1.1027, accuracy: 0.8000
# Iter : 10001, loss: 0.4373, accuracy: 0.7930
# Iter : 11001, loss: 0.5549, accuracy: 0.7960
# Iter : 12001, loss: 0.9999, accuracy: 0.7980
# Iter : 13001, loss: 0.6834, accuracy: 0.7730
# Iter : 14001, loss: 0.3949, accuracy: 0.7930
# Iter : 15001, loss: 0.8465, accuracy: 0.8110
# Iter : 16001, loss: 1.0364, accuracy: 0.8130
# Iter : 17001, loss: 0.8497, accuracy: 0.8020
# Iter : 18001, loss: 0.6144, accuracy: 0.8080
# Iter : 19001, loss: 0.7894, accuracy: 0.8050
# Iter : 20001, loss: 0.6889, accuracy: 0.7960
# Iter : 21001, loss: 0.7255, accuracy: 0.7810
# Iter : 22001, loss: 1.4352, accuracy: 0.8160
# Iter : 23001, loss: 0.5708, accuracy: 0.8030
# Iter : 24001, loss: 0.4921, accuracy: 0.8060
# Iter : 25001, loss: 0.5139, accuracy: 0.7860
# Iter : 26001, loss: 0.8980, accuracy: 0.8030
# Iter : 27001, loss: 0.6671, accuracy: 0.7920
# Iter : 28001, loss: 1.0194, accuracy: 0.8060
# Iter : 29001, loss: 1.1258, accuracy: 0.8040
# Iter : 30001, loss: 0.4628, accuracy: 0.7970
# Iter : 31001, loss: 0.5999, accuracy: 0.8070
# Iter : 32001, loss: 0.4917, accuracy: 0.8130
# Iter : 33001, loss: 0.9935, accuracy: 0.8120
# Iter : 34001, loss: 0.6115, accuracy: 0.8000
# Iter : 35001, loss: 0.8849, accuracy: 0.8060
# Iter : 36001, loss: 0.7570, accuracy: 0.7870
# Iter : 37001, loss: 0.6534, accuracy: 0.7860
# Iter : 38001, loss: 0.7784, accuracy: 0.7910
# Iter : 39001, loss: 0.7104, accuracy: 0.7880
# Iter : 40001, loss: 0.8256, accuracy: 0.7890
# Iter : 41001, loss: 0.7399, accuracy: 0.8140
# Iter : 42001, loss: 0.7899, accuracy: 0.7860
# Iter : 43001, loss: 0.4892, accuracy: 0.8180
# Iter : 44001, loss: 0.5391, accuracy: 0.8060
# Iter : 45001, loss: 0.7667, accuracy: 0.7900
# Iter : 46001, loss: 0.9161, accuracy: 0.8160
# Iter : 47001, loss: 0.5824, accuracy: 0.8060
# Iter : 48001, loss: 0.7224, accuracy: 0.7880
# Iter : 49001, loss: 0.5928, accuracy: 0.8120
# Iter : 50001, loss: 0.3819, accuracy: 0.7900
# Iter : 51001, loss: 0.4343, accuracy: 0.8000
# Iter : 52001, loss: 0.5234, accuracy: 0.7970
# Iter : 53001, loss: 0.6844, accuracy: 0.8220
# Iter : 54001, loss: 0.8070, accuracy: 0.7970
# Iter : 55001, loss: 0.7631, accuracy: 0.7900
# Iter : 56001, loss: 0.8767, accuracy: 0.7990
# Iter : 57001, loss: 0.6448, accuracy: 0.8170
# Iter : 58001, loss: 0.4183, accuracy: 0.8140
# Iter : 59001, loss: 1.0295, accuracy: 0.7980
# Iter : 60001, loss: 0.4781, accuracy: 0.7980
# Iter : 61001, loss: 0.6049, accuracy: 0.8010
# Iter : 62001, loss: 0.4380, accuracy: 0.8200
# Iter : 63001, loss: 0.6362, accuracy: 0.8140
# Iter : 64001, loss: 0.6449, accuracy: 0.8390
# Iter : 65001, loss: 0.7930, accuracy: 0.8520
# Iter : 66001, loss: 0.6454, accuracy: 0.8390
# Iter : 67001, loss: 0.6516, accuracy: 0.8430
# Iter : 68001, loss: 1.0815, accuracy: 0.8320
# Iter : 69001, loss: 0.7171, accuracy: 0.8300
# Iter : 70001, loss: 1.2986, accuracy: 0.8360
# Iter : 71001, loss: 0.6816, accuracy: 0.8270
# Iter : 72001, loss: 1.1851, accuracy: 0.8560
# Iter : 73001, loss: 0.4785, accuracy: 0.8310
# Iter : 74001, loss: 0.5203, accuracy: 0.8490
# Iter : 75001, loss: 1.1021, accuracy: 0.8620
# Iter : 76001, loss: 1.1530, accuracy: 0.8860
# Iter : 77001, loss: 0.6091, accuracy: 0.8740
# Iter : 78001, loss: 0.6473, accuracy: 0.8750
# Iter : 79001, loss: 0.5412, accuracy: 0.8570
# Doing rep  3
# Iter : 1001, loss: 0.7635, accuracy: 0.4580
# Iter : 2001, loss: 0.9039, accuracy: 0.7380
# Iter : 3001, loss: 1.3520, accuracy: 0.7980
# Iter : 4001, loss: 0.9599, accuracy: 0.8160
# Iter : 5001, loss: 0.7962, accuracy: 0.7940
# Iter : 6001, loss: 0.7196, accuracy: 0.8120
# Iter : 7001, loss: 0.5777, accuracy: 0.7940
# Iter : 8001, loss: 0.4296, accuracy: 0.8000
# Iter : 9001, loss: 1.1968, accuracy: 0.8020
# Iter : 10001, loss: 0.8542, accuracy: 0.7840
# Iter : 11001, loss: 1.1261, accuracy: 0.7980
# Iter : 12001, loss: 0.9706, accuracy: 0.7950
# Iter : 13001, loss: 0.3985, accuracy: 0.8260
# Iter : 14001, loss: 0.2920, accuracy: 0.8170
# Iter : 15001, loss: 0.4040, accuracy: 0.8200
# Iter : 16001, loss: 0.8550, accuracy: 0.7930
# Iter : 17001, loss: 0.3967, accuracy: 0.8060
# Iter : 18001, loss: 0.3642, accuracy: 0.8110
# Iter : 19001, loss: 0.9832, accuracy: 0.7910
# Going to sleep ...
# Iter : 1001, loss: 1.3592, accuracy: 0.8160
# Iter : 2001, loss: 0.0106, accuracy: 0.8030
# Iter : 3001, loss: 0.1557, accuracy: 0.8080
# Iter : 4001, loss: 0.0225, accuracy: 0.8520
# Iter : 5001, loss: 0.1964, accuracy: 0.8380
# Iter : 6001, loss: 0.3021, accuracy: 0.8270
# Iter : 7001, loss: 0.0113, accuracy: 0.8090
# Iter : 8001, loss: 0.0097, accuracy: 0.8350
# Iter : 9001, loss: 0.6661, accuracy: 0.8360
# Iter : 10001, loss: 0.6267, accuracy: 0.8450
# Iter : 11001, loss: 0.0036, accuracy: 0.8370
# Iter : 12001, loss: 0.0113, accuracy: 0.8210
# Iter : 13001, loss: 0.5925, accuracy: 0.8280
# Iter : 14001, loss: 0.4372, accuracy: 0.8150
# Iter : 15001, loss: 0.0030, accuracy: 0.8110
# Iter : 16001, loss: 0.0318, accuracy: 0.8340
# Iter : 17001, loss: 0.0077, accuracy: 0.8220
# Iter : 18001, loss: 0.0009, accuracy: 0.8120
# Iter : 19001, loss: 0.0018, accuracy: 0.8310
# Going to awake phase ...
# Iter : 1001, loss: 0.9618, accuracy: 0.8120
# Iter : 2001, loss: 0.8016, accuracy: 0.7910
# Iter : 3001, loss: 0.7374, accuracy: 0.7990
# Iter : 4001, loss: 0.6899, accuracy: 0.7790
# Iter : 5001, loss: 0.6290, accuracy: 0.8080
# Iter : 6001, loss: 0.8945, accuracy: 0.8070
# Iter : 7001, loss: 0.5126, accuracy: 0.8140
# Iter : 8001, loss: 1.0947, accuracy: 0.8250
# Iter : 9001, loss: 0.5898, accuracy: 0.8020
# Iter : 10001, loss: 0.4200, accuracy: 0.8070
# Iter : 11001, loss: 0.6945, accuracy: 0.8190
# Iter : 12001, loss: 0.4025, accuracy: 0.8050
# Iter : 13001, loss: 0.8162, accuracy: 0.8070
# Iter : 14001, loss: 0.7945, accuracy: 0.7920
# Iter : 15001, loss: 0.9147, accuracy: 0.8040
# Iter : 16001, loss: 0.9530, accuracy: 0.8210
# Iter : 17001, loss: 0.8828, accuracy: 0.8210
# Iter : 18001, loss: 0.6558, accuracy: 0.8260
# Iter : 19001, loss: 0.7896, accuracy: 0.8000
# Iter : 20001, loss: 0.6877, accuracy: 0.8110
# Iter : 21001, loss: 0.9013, accuracy: 0.8030
# Iter : 22001, loss: 0.9938, accuracy: 0.7930
# Iter : 23001, loss: 0.4887, accuracy: 0.7970
# Iter : 24001, loss: 0.6179, accuracy: 0.8260
# Iter : 25001, loss: 0.4907, accuracy: 0.8200
# Iter : 26001, loss: 0.7059, accuracy: 0.8240
# Iter : 27001, loss: 0.9156, accuracy: 0.8220
# Iter : 28001, loss: 0.8199, accuracy: 0.8180
# Iter : 29001, loss: 0.7815, accuracy: 0.8130
# Iter : 30001, loss: 0.4829, accuracy: 0.8190
# Iter : 31001, loss: 0.5921, accuracy: 0.8090
# Iter : 32001, loss: 0.5022, accuracy: 0.8160
# Iter : 33001, loss: 0.9235, accuracy: 0.8330
# Iter : 34001, loss: 0.4554, accuracy: 0.8190
# Iter : 35001, loss: 0.9160, accuracy: 0.8090
# Iter : 36001, loss: 0.4261, accuracy: 0.8080
# Iter : 37001, loss: 0.6550, accuracy: 0.8040
# Iter : 38001, loss: 0.9360, accuracy: 0.8220
# Iter : 39001, loss: 0.6642, accuracy: 0.8120
# Iter : 40001, loss: 0.8631, accuracy: 0.8150
# Iter : 41001, loss: 0.4976, accuracy: 0.8090
# Iter : 42001, loss: 0.6954, accuracy: 0.8220
# Iter : 43001, loss: 0.7062, accuracy: 0.8220
# Iter : 44001, loss: 0.3935, accuracy: 0.8390
# Iter : 45001, loss: 0.6841, accuracy: 0.8360
# Iter : 46001, loss: 0.6707, accuracy: 0.8630
# Iter : 47001, loss: 0.5229, accuracy: 0.8500
# Iter : 48001, loss: 0.6662, accuracy: 0.8700
# Iter : 49001, loss: 0.7357, accuracy: 0.8360
# Iter : 50001, loss: 0.9159, accuracy: 0.8500
# Iter : 51001, loss: 0.5609, accuracy: 0.8800
# Iter : 52001, loss: 0.7846, accuracy: 0.8920
# Iter : 53001, loss: 1.2400, accuracy: 0.8720
# Iter : 54001, loss: 0.5428, accuracy: 0.8880
# Iter : 55001, loss: 0.4712, accuracy: 0.8960
# Iter : 56001, loss: 0.4620, accuracy: 0.8760
# Iter : 57001, loss: 0.5302, accuracy: 0.9030
# Iter : 58001, loss: 0.4509, accuracy: 0.9050
# Iter : 59001, loss: 1.2845, accuracy: 0.9000
# Iter : 60001, loss: 0.5889, accuracy: 0.8990
# Iter : 61001, loss: 0.7987, accuracy: 0.8880
# Iter : 62001, loss: 0.6018, accuracy: 0.8800
# Iter : 63001, loss: 0.5299, accuracy: 0.8880
# Iter : 64001, loss: 0.9437, accuracy: 0.8950
# Iter : 65001, loss: 0.9279, accuracy: 0.9020
# Iter : 66001, loss: 0.9089, accuracy: 0.8980
# Iter : 67001, loss: 1.2556, accuracy: 0.9020
# Iter : 68001, loss: 0.8771, accuracy: 0.9020
# Iter : 69001, loss: 0.8165, accuracy: 0.9080
# Iter : 70001, loss: 0.6402, accuracy: 0.8950
# Iter : 71001, loss: 0.7181, accuracy: 0.8830
# Iter : 72001, loss: 0.7352, accuracy: 0.8950
# Iter : 73001, loss: 0.5234, accuracy: 0.8930
# Iter : 74001, loss: 1.0626, accuracy: 0.9040
# Iter : 75001, loss: 0.5868, accuracy: 0.8960
# Iter : 76001, loss: 0.9691, accuracy: 0.8910
# Iter : 77001, loss: 1.0162, accuracy: 0.8830
# Iter : 78001, loss: 0.9280, accuracy: 0.8890
# Iter : 79001, loss: 0.6206, accuracy: 0.8900
# Doing rep  4
# Iter : 1001, loss: 1.0396, accuracy: 0.4310
# Iter : 2001, loss: 0.6934, accuracy: 0.7320
# Iter : 3001, loss: 0.8529, accuracy: 0.8070
# Iter : 4001, loss: 0.5961, accuracy: 0.8010
# Iter : 5001, loss: 1.0842, accuracy: 0.7900
# Iter : 6001, loss: 0.5221, accuracy: 0.8010
# Iter : 7001, loss: 0.8884, accuracy: 0.7990
# Iter : 8001, loss: 0.8857, accuracy: 0.7980
# Iter : 9001, loss: 0.3506, accuracy: 0.7810
# Iter : 10001, loss: 0.3856, accuracy: 0.8110
# Iter : 11001, loss: 0.5853, accuracy: 0.7890
# Iter : 12001, loss: 0.9711, accuracy: 0.7920
# Iter : 13001, loss: 0.6772, accuracy: 0.8210
# Iter : 14001, loss: 0.6089, accuracy: 0.7950
# Iter : 15001, loss: 0.9314, accuracy: 0.7850
# Iter : 16001, loss: 0.5241, accuracy: 0.7990
# Iter : 17001, loss: 0.2557, accuracy: 0.8230
# Iter : 18001, loss: 0.5125, accuracy: 0.7900
# Iter : 19001, loss: 0.4340, accuracy: 0.8030
# Going to sleep ...
# Iter : 1001, loss: 0.0038, accuracy: 0.7910
# Iter : 2001, loss: 1.0364, accuracy: 0.8120
# Iter : 3001, loss: 0.0057, accuracy: 0.7770
# Iter : 4001, loss: 0.0079, accuracy: 0.8030
# Iter : 5001, loss: 0.6042, accuracy: 0.8050
# Iter : 6001, loss: 0.0131, accuracy: 0.8120
# Iter : 7001, loss: 0.0049, accuracy: 0.8080
# Iter : 8001, loss: 0.0248, accuracy: 0.7730
# Iter : 9001, loss: 0.0210, accuracy: 0.7920
# Iter : 10001, loss: 0.0098, accuracy: 0.8100
# Iter : 11001, loss: 0.0176, accuracy: 0.7860
# Iter : 12001, loss: 0.0087, accuracy: 0.7970
# Iter : 13001, loss: 0.0033, accuracy: 0.7920
# Iter : 14001, loss: 0.0017, accuracy: 0.8020
# Iter : 15001, loss: 0.7525, accuracy: 0.8000
# Iter : 16001, loss: 0.0084, accuracy: 0.8070
# Iter : 17001, loss: 0.0082, accuracy: 0.7940
# Iter : 18001, loss: 0.0129, accuracy: 0.8060
# Iter : 19001, loss: 0.0285, accuracy: 0.7980
# Going to awake phase ...
# Iter : 1001, loss: 0.4200, accuracy: 0.8200
# Iter : 2001, loss: 0.9715, accuracy: 0.8160
# Iter : 3001, loss: 0.4560, accuracy: 0.8090
# Iter : 4001, loss: 0.6848, accuracy: 0.7930
# Iter : 5001, loss: 0.4331, accuracy: 0.7960
# Iter : 6001, loss: 0.9749, accuracy: 0.8000
# Iter : 7001, loss: 0.9746, accuracy: 0.7860
# Iter : 8001, loss: 0.6712, accuracy: 0.8160
# Iter : 9001, loss: 0.9967, accuracy: 0.8110
# Iter : 10001, loss: 0.8521, accuracy: 0.8050
# Iter : 11001, loss: 0.5931, accuracy: 0.8020
# Iter : 12001, loss: 0.5363, accuracy: 0.7820
# Iter : 13001, loss: 0.6310, accuracy: 0.7990
# Iter : 14001, loss: 1.1294, accuracy: 0.7970
# Iter : 15001, loss: 0.6420, accuracy: 0.7830
# Iter : 16001, loss: 0.9652, accuracy: 0.8080
# Iter : 17001, loss: 0.6935, accuracy: 0.7830
# Iter : 18001, loss: 0.6865, accuracy: 0.7930
# Iter : 19001, loss: 0.6969, accuracy: 0.7990
# Iter : 20001, loss: 0.6752, accuracy: 0.7990
# Iter : 21001, loss: 0.7219, accuracy: 0.7880
# Iter : 22001, loss: 0.6770, accuracy: 0.8010
# Iter : 23001, loss: 0.6968, accuracy: 0.7720
# Iter : 24001, loss: 0.7274, accuracy: 0.7930
# Iter : 25001, loss: 0.9318, accuracy: 0.7910
# Iter : 26001, loss: 0.3820, accuracy: 0.8130
# Iter : 27001, loss: 0.7800, accuracy: 0.7930
# Iter : 28001, loss: 0.4049, accuracy: 0.8000
# Iter : 29001, loss: 0.7862, accuracy: 0.7880
# Iter : 30001, loss: 0.6872, accuracy: 0.8020
# Iter : 31001, loss: 0.4823, accuracy: 0.7930
# Iter : 32001, loss: 1.1945, accuracy: 0.7860
# Iter : 33001, loss: 0.4306, accuracy: 0.8070
# Iter : 34001, loss: 0.4157, accuracy: 0.8060
# Iter : 35001, loss: 0.6521, accuracy: 0.7880
# Iter : 36001, loss: 0.8993, accuracy: 0.8030
# Iter : 37001, loss: 0.8946, accuracy: 0.7940
# Iter : 38001, loss: 1.1052, accuracy: 0.7970
# Iter : 39001, loss: 0.4733, accuracy: 0.7960
# Iter : 40001, loss: 0.7196, accuracy: 0.7900
# Iter : 41001, loss: 0.6850, accuracy: 0.8160
# Iter : 42001, loss: 0.7549, accuracy: 0.8060
# Iter : 43001, loss: 0.6226, accuracy: 0.8010
# Iter : 44001, loss: 0.4872, accuracy: 0.8080
# Iter : 45001, loss: 0.6136, accuracy: 0.7930
# Iter : 46001, loss: 0.4809, accuracy: 0.8060
# Iter : 47001, loss: 0.4626, accuracy: 0.8150
# Iter : 48001, loss: 0.7773, accuracy: 0.8180
# Iter : 49001, loss: 0.8300, accuracy: 0.7870
# Iter : 50001, loss: 0.8817, accuracy: 0.7910
# Iter : 51001, loss: 0.6616, accuracy: 0.8010
# Iter : 52001, loss: 0.5120, accuracy: 0.7950
# Iter : 53001, loss: 0.8755, accuracy: 0.8090
# Iter : 54001, loss: 0.4245, accuracy: 0.8000
# Iter : 55001, loss: 0.8532, accuracy: 0.7940
# Iter : 56001, loss: 0.7213, accuracy: 0.8020
# Iter : 57001, loss: 0.7737, accuracy: 0.7930
# Iter : 58001, loss: 0.4728, accuracy: 0.8050
# Iter : 59001, loss: 0.9875, accuracy: 0.7990
# Iter : 60001, loss: 0.8624, accuracy: 0.8060
# Iter : 61001, loss: 0.5450, accuracy: 0.7960
# Iter : 62001, loss: 0.7635, accuracy: 0.8060
# Iter : 63001, loss: 0.4214, accuracy: 0.8060
# Iter : 64001, loss: 0.7081, accuracy: 0.8010
# Iter : 65001, loss: 0.4602, accuracy: 0.8040
# Iter : 66001, loss: 0.6222, accuracy: 0.8050
# Iter : 67001, loss: 0.5541, accuracy: 0.7990
# Iter : 68001, loss: 0.9177, accuracy: 0.8050
# Iter : 69001, loss: 0.6089, accuracy: 0.8090
# Iter : 70001, loss: 0.7935, accuracy: 0.8170
# Iter : 71001, loss: 0.4790, accuracy: 0.7840
# Iter : 72001, loss: 0.5842, accuracy: 0.8030
# Iter : 73001, loss: 0.8088, accuracy: 0.7920
# Iter : 74001, loss: 0.6428, accuracy: 0.8010
# Iter : 75001, loss: 0.6726, accuracy: 0.7990
# Iter : 76001, loss: 0.5969, accuracy: 0.8070
# Iter : 77001, loss: 0.5580, accuracy: 0.8100
# Iter : 78001, loss: 0.7441, accuracy: 0.8030
# Iter : 79001, loss: 0.5082, accuracy: 0.8010

# %%
### initial training ###
test_acc_control = [[] for _ in range(reps)]

for rep in range(reps):
    print('Doing rep ', rep)
    
    data = get_sequence(total_samples, 2, 3, random_state=rep)
    # data = pd.read_csv("../Seq_500000.txt")['seq'][0]
    
    
    data_set = Dataset_converter(data, working_memory, short_term_memory)
    
    main_model = RNN(len(tokens)*working_memory, hidden_size_hippocampus, hidden_size_cortex, num_layers)
    main_model.rnn_cortex.requires_grad = False
    
    train_loader = DataLoader(data_set, batch_size=1, shuffle=False) 
    
    optimizer = torch.optim.SGD(main_model.parameters(), lr=lr, momentum=0.95)
    criterion = torch.nn.CrossEntropyLoss()
    
    total = 0
    correct = np.zeros(1000,dtype=float)
    for X, y in train_loader:
        optimizer.zero_grad()
    
        if total == 0:
            predicted_y, hidden = main_model(X)
        else:
            predicted_y, hidden = main_model(X, mem)
            
        loss = criterion(predicted_y, y)
        loss.backward()
        optimizer.step()
    
        with torch.no_grad():
            mem = hidden.clone()
            true_y = y.argmax(axis=1)
            estimated_y = predicted_y.argmax(axis=1)
    
            total += 1
            if true_y == estimated_y:
                    correct[total%1000] = 1
            else:
                correct[total%1000] = 0
    
            test_acc_control[rep].append(
                np.sum(correct)/total if total<1000 else np.sum(correct)/1000
            )
            if total%1000 == 0:
                print(f'Iter : {total+1}, loss: {loss:.4f}, accuracy: {test_acc_control[rep][-1]:.4f}')
# Out:
# Doing rep  0
# Iter : 1001, loss: 1.3717, accuracy: 0.4400
# Iter : 2001, loss: 1.2972, accuracy: 0.7140
# Iter : 3001, loss: 0.3723, accuracy: 0.8020
# Iter : 4001, loss: 0.9449, accuracy: 0.8130
# Iter : 5001, loss: 1.3089, accuracy: 0.8000
# Iter : 6001, loss: 1.2677, accuracy: 0.7810
# Iter : 7001, loss: 0.3809, accuracy: 0.7960
# Iter : 8001, loss: 1.0752, accuracy: 0.8050
# Iter : 9001, loss: 0.7235, accuracy: 0.7990
# Iter : 10001, loss: 0.6273, accuracy: 0.8110
# Iter : 11001, loss: 0.6506, accuracy: 0.7860
# Iter : 12001, loss: 1.0570, accuracy: 0.8100
# Iter : 13001, loss: 0.5732, accuracy: 0.8000
# Iter : 14001, loss: 0.7780, accuracy: 0.7990
# Iter : 15001, loss: 0.3633, accuracy: 0.7970
# Iter : 16001, loss: 0.8785, accuracy: 0.8050
# Iter : 17001, loss: 0.4129, accuracy: 0.8010
# Iter : 18001, loss: 1.0727, accuracy: 0.7970
# Iter : 19001, loss: 0.9600, accuracy: 0.7830
# Iter : 20001, loss: 0.6365, accuracy: 0.8040
# Iter : 21001, loss: 1.4943, accuracy: 0.7970
# Iter : 22001, loss: 0.7893, accuracy: 0.8200
# Iter : 23001, loss: 0.9282, accuracy: 0.8200
# Iter : 24001, loss: 0.8930, accuracy: 0.7940
# Iter : 25001, loss: 0.8899, accuracy: 0.8030
# Iter : 26001, loss: 0.6188, accuracy: 0.8010
# Iter : 27001, loss: 0.6289, accuracy: 0.8150
# Iter : 28001, loss: 0.5259, accuracy: 0.8310
# Iter : 29001, loss: 0.5942, accuracy: 0.8050
# Iter : 30001, loss: 0.7303, accuracy: 0.8020
# Iter : 31001, loss: 0.6951, accuracy: 0.7990
# Iter : 32001, loss: 0.4306, accuracy: 0.7950
# Iter : 33001, loss: 0.3879, accuracy: 0.8110
# Iter : 34001, loss: 0.8169, accuracy: 0.8030
# Iter : 35001, loss: 1.1438, accuracy: 0.7930
# Iter : 36001, loss: 1.2921, accuracy: 0.8020
# Iter : 37001, loss: 0.6891, accuracy: 0.8100
# Iter : 38001, loss: 0.6520, accuracy: 0.7860
# Iter : 39001, loss: 0.5312, accuracy: 0.8030
# Iter : 40001, loss: 1.1332, accuracy: 0.8080
# Iter : 41001, loss: 0.4869, accuracy: 0.8160
# Iter : 42001, loss: 0.4941, accuracy: 0.8180
# Iter : 43001, loss: 0.5624, accuracy: 0.8060
# Iter : 44001, loss: 0.2535, accuracy: 0.8050
# Iter : 45001, loss: 0.6528, accuracy: 0.8010
# Iter : 46001, loss: 1.1619, accuracy: 0.8050
# Iter : 47001, loss: 0.7044, accuracy: 0.8080
# Iter : 48001, loss: 1.0221, accuracy: 0.8110
# Iter : 49001, loss: 0.4893, accuracy: 0.8090
# Iter : 50001, loss: 0.6562, accuracy: 0.8220
# Iter : 51001, loss: 0.5547, accuracy: 0.8030
# Iter : 52001, loss: 0.5549, accuracy: 0.7910
# Iter : 53001, loss: 0.8276, accuracy: 0.8210
# Iter : 54001, loss: 1.1300, accuracy: 0.8060
# Iter : 55001, loss: 0.5672, accuracy: 0.8000
# Iter : 56001, loss: 0.7882, accuracy: 0.8050
# Iter : 57001, loss: 0.7740, accuracy: 0.7940
# Iter : 58001, loss: 0.5965, accuracy: 0.7780
# Iter : 59001, loss: 0.8895, accuracy: 0.7990
# Iter : 60001, loss: 0.7205, accuracy: 0.7970
# Iter : 61001, loss: 0.7306, accuracy: 0.8010
# Iter : 62001, loss: 0.6548, accuracy: 0.8180
# Iter : 63001, loss: 0.7641, accuracy: 0.8070
# Iter : 64001, loss: 0.9676, accuracy: 0.7900
# Iter : 65001, loss: 0.3916, accuracy: 0.8070
# Iter : 66001, loss: 0.6851, accuracy: 0.7970
# Iter : 67001, loss: 0.7724, accuracy: 0.8030
# Iter : 68001, loss: 0.6825, accuracy: 0.8090
# Iter : 69001, loss: 0.8028, accuracy: 0.8040
# Iter : 70001, loss: 0.6717, accuracy: 0.8100
# Iter : 71001, loss: 1.1171, accuracy: 0.8130
# Iter : 72001, loss: 0.8230, accuracy: 0.7880
# Iter : 73001, loss: 0.5461, accuracy: 0.8170
# Iter : 74001, loss: 0.8449, accuracy: 0.8130
# Iter : 75001, loss: 0.9955, accuracy: 0.7990
# Iter : 76001, loss: 0.5819, accuracy: 0.7950
# Iter : 77001, loss: 1.1403, accuracy: 0.8030
# Iter : 78001, loss: 0.6229, accuracy: 0.8310
# Iter : 79001, loss: 0.8772, accuracy: 0.7990
# Iter : 80001, loss: 1.2511, accuracy: 0.7960
# Iter : 81001, loss: 0.7131, accuracy: 0.7970
# Iter : 82001, loss: 0.7713, accuracy: 0.8170
# Iter : 83001, loss: 0.7397, accuracy: 0.7870
# Iter : 84001, loss: 0.8059, accuracy: 0.8040
# Iter : 85001, loss: 0.8964, accuracy: 0.7950
# Iter : 86001, loss: 1.3859, accuracy: 0.7930
# Iter : 87001, loss: 0.5119, accuracy: 0.7910
# Iter : 88001, loss: 1.2541, accuracy: 0.8080
# Iter : 89001, loss: 0.5220, accuracy: 0.8030
# Iter : 90001, loss: 0.8781, accuracy: 0.7890
# Iter : 91001, loss: 0.7354, accuracy: 0.7950
# Iter : 92001, loss: 0.7431, accuracy: 0.8110
# Iter : 93001, loss: 1.2589, accuracy: 0.7940
# Iter : 94001, loss: 1.0914, accuracy: 0.8150
# Iter : 95001, loss: 1.2489, accuracy: 0.7920
# Iter : 96001, loss: 0.4520, accuracy: 0.8240
# Iter : 97001, loss: 0.9919, accuracy: 0.8000
# Iter : 98001, loss: 0.7585, accuracy: 0.8050
# Iter : 99001, loss: 0.8794, accuracy: 0.7860
# Doing rep  1
# Iter : 1001, loss: 0.6316, accuracy: 0.4330
# Iter : 2001, loss: 0.6154, accuracy: 0.6950
# Iter : 3001, loss: 0.5285, accuracy: 0.7720
# Iter : 4001, loss: 0.6022, accuracy: 0.7930
# Iter : 5001, loss: 0.3341, accuracy: 0.8200
# Iter : 6001, loss: 0.7287, accuracy: 0.8160
# Iter : 7001, loss: 0.5560, accuracy: 0.8030
# Iter : 8001, loss: 0.6747, accuracy: 0.8020
# Iter : 9001, loss: 0.8587, accuracy: 0.7980
# Iter : 10001, loss: 1.0287, accuracy: 0.7950
# Iter : 11001, loss: 0.4969, accuracy: 0.8190
# Iter : 12001, loss: 0.5471, accuracy: 0.8050
# Iter : 13001, loss: 0.8067, accuracy: 0.7940
# Iter : 14001, loss: 0.4798, accuracy: 0.7980
# Iter : 15001, loss: 0.9174, accuracy: 0.7890
# Iter : 16001, loss: 0.8677, accuracy: 0.7870
# Iter : 17001, loss: 0.8900, accuracy: 0.7920
# Iter : 18001, loss: 0.6562, accuracy: 0.8010
# Iter : 19001, loss: 0.6604, accuracy: 0.7950
# Iter : 20001, loss: 0.8969, accuracy: 0.8070
# Iter : 21001, loss: 0.6143, accuracy: 0.7970
# Iter : 22001, loss: 0.6658, accuracy: 0.8080
# Iter : 23001, loss: 0.6859, accuracy: 0.7870
# Iter : 24001, loss: 0.6626, accuracy: 0.7850
# Iter : 25001, loss: 0.5750, accuracy: 0.8040
# Iter : 26001, loss: 0.3354, accuracy: 0.7920
# Iter : 27001, loss: 0.7575, accuracy: 0.7930
# Iter : 28001, loss: 0.5286, accuracy: 0.8120
# Iter : 29001, loss: 0.7929, accuracy: 0.7960
# Iter : 30001, loss: 0.7074, accuracy: 0.7950
# Iter : 31001, loss: 0.9836, accuracy: 0.7880
# Iter : 32001, loss: 0.7494, accuracy: 0.7900
# Iter : 33001, loss: 0.3746, accuracy: 0.8100
# Iter : 34001, loss: 0.7409, accuracy: 0.7930
# Iter : 35001, loss: 0.8635, accuracy: 0.8120
# Iter : 36001, loss: 0.7129, accuracy: 0.7880
# Iter : 37001, loss: 0.5012, accuracy: 0.8050
# Iter : 38001, loss: 0.8884, accuracy: 0.8020
# Iter : 39001, loss: 0.7838, accuracy: 0.8110
# Iter : 40001, loss: 0.4954, accuracy: 0.7980
# Iter : 41001, loss: 0.6959, accuracy: 0.8010
# Iter : 42001, loss: 0.9302, accuracy: 0.8070
# Iter : 43001, loss: 0.9314, accuracy: 0.7930
# Iter : 44001, loss: 0.5092, accuracy: 0.8220
# Iter : 45001, loss: 1.0712, accuracy: 0.8130
# Iter : 46001, loss: 0.7592, accuracy: 0.8000
# Iter : 47001, loss: 1.1216, accuracy: 0.8100
# Iter : 48001, loss: 0.5074, accuracy: 0.7940
# Iter : 49001, loss: 0.6348, accuracy: 0.7890
# Iter : 50001, loss: 0.5568, accuracy: 0.8000
# Iter : 51001, loss: 0.5024, accuracy: 0.8020
# Iter : 52001, loss: 0.7246, accuracy: 0.8040
# Iter : 53001, loss: 0.7013, accuracy: 0.7910
# Iter : 54001, loss: 0.8295, accuracy: 0.8150
# Iter : 55001, loss: 0.8148, accuracy: 0.7800
# Iter : 56001, loss: 0.7179, accuracy: 0.8170
# Iter : 57001, loss: 0.7624, accuracy: 0.7980
# Iter : 58001, loss: 0.8439, accuracy: 0.8090
# Iter : 59001, loss: 0.9569, accuracy: 0.8080
# Iter : 60001, loss: 0.7663, accuracy: 0.7960
# Iter : 61001, loss: 0.6655, accuracy: 0.8110
# Iter : 62001, loss: 0.5095, accuracy: 0.8040
# Iter : 63001, loss: 0.8256, accuracy: 0.7920
# Iter : 64001, loss: 0.5380, accuracy: 0.8060
# Iter : 65001, loss: 0.7967, accuracy: 0.8050
# Iter : 66001, loss: 0.5814, accuracy: 0.8050
# Iter : 67001, loss: 0.7905, accuracy: 0.8000
# Iter : 68001, loss: 0.9578, accuracy: 0.7990
# Iter : 69001, loss: 0.6956, accuracy: 0.7920
# Iter : 70001, loss: 0.6259, accuracy: 0.8170
# Iter : 71001, loss: 0.9666, accuracy: 0.8050
# Iter : 72001, loss: 0.5035, accuracy: 0.8060
# Iter : 73001, loss: 0.5365, accuracy: 0.8320
# Iter : 74001, loss: 0.8470, accuracy: 0.8000
# Iter : 75001, loss: 0.6186, accuracy: 0.8100
# Iter : 76001, loss: 0.7002, accuracy: 0.7970
# Iter : 77001, loss: 0.5361, accuracy: 0.8020
# Iter : 78001, loss: 0.9680, accuracy: 0.8170
# Iter : 79001, loss: 0.3351, accuracy: 0.8000
# Iter : 80001, loss: 1.0924, accuracy: 0.7930
# Iter : 81001, loss: 0.5731, accuracy: 0.8320
# Iter : 82001, loss: 0.8666, accuracy: 0.7930
# Iter : 83001, loss: 0.9538, accuracy: 0.7880
# Iter : 84001, loss: 0.3916, accuracy: 0.8060
# Iter : 85001, loss: 0.5702, accuracy: 0.8020
# Iter : 86001, loss: 0.4229, accuracy: 0.8240
# Iter : 87001, loss: 0.5779, accuracy: 0.7980
# Iter : 88001, loss: 1.0684, accuracy: 0.8180
# Iter : 89001, loss: 0.4941, accuracy: 0.8100
# Iter : 90001, loss: 0.7375, accuracy: 0.7960
# Iter : 91001, loss: 0.5599, accuracy: 0.8130
# Iter : 92001, loss: 0.5483, accuracy: 0.8010
# Iter : 93001, loss: 0.8546, accuracy: 0.8070
# Iter : 94001, loss: 0.6682, accuracy: 0.8040
# Iter : 95001, loss: 0.6465, accuracy: 0.8070
# Iter : 96001, loss: 0.5756, accuracy: 0.7950
# Iter : 97001, loss: 0.7831, accuracy: 0.8290
# Iter : 98001, loss: 0.8012, accuracy: 0.7790
# Iter : 99001, loss: 0.6988, accuracy: 0.8080
# Doing rep  2
# Iter : 1001, loss: 1.0669, accuracy: 0.4500
# Iter : 2001, loss: 0.5537, accuracy: 0.7390
# Iter : 3001, loss: 0.5187, accuracy: 0.7670
# Iter : 4001, loss: 0.5400, accuracy: 0.7990
# Iter : 5001, loss: 0.4126, accuracy: 0.8110
# Iter : 6001, loss: 0.5104, accuracy: 0.7950
# Iter : 7001, loss: 1.1005, accuracy: 0.8000
# Iter : 8001, loss: 0.7278, accuracy: 0.8050
# Iter : 9001, loss: 0.6610, accuracy: 0.8100
# Iter : 10001, loss: 0.4865, accuracy: 0.8040
# Iter : 11001, loss: 0.4614, accuracy: 0.8060
# Iter : 12001, loss: 0.5082, accuracy: 0.8160
# Iter : 13001, loss: 0.8583, accuracy: 0.8220
# Iter : 14001, loss: 1.2620, accuracy: 0.8220
# Iter : 15001, loss: 0.7914, accuracy: 0.8170
# Iter : 16001, loss: 0.4492, accuracy: 0.8180
# Iter : 17001, loss: 0.7315, accuracy: 0.8250
# Iter : 18001, loss: 0.9203, accuracy: 0.8040
# Iter : 19001, loss: 0.6088, accuracy: 0.8120
# Iter : 20001, loss: 0.5720, accuracy: 0.8070
# Iter : 21001, loss: 0.8120, accuracy: 0.8070
# Iter : 22001, loss: 0.8160, accuracy: 0.8070
# Iter : 23001, loss: 0.5457, accuracy: 0.7950
# Iter : 24001, loss: 0.5522, accuracy: 0.8030
# Iter : 25001, loss: 0.7198, accuracy: 0.7880
# Iter : 26001, loss: 0.7221, accuracy: 0.8370
# Iter : 27001, loss: 0.4135, accuracy: 0.8010
# Iter : 28001, loss: 0.8818, accuracy: 0.8010
# Iter : 29001, loss: 1.1814, accuracy: 0.8220
# Iter : 30001, loss: 0.3995, accuracy: 0.8140
# Iter : 31001, loss: 0.5902, accuracy: 0.8180
# Iter : 32001, loss: 0.9340, accuracy: 0.8440
# Iter : 33001, loss: 0.6088, accuracy: 0.8170
# Iter : 34001, loss: 0.3020, accuracy: 0.8090
# Iter : 35001, loss: 0.9083, accuracy: 0.8240
# Iter : 36001, loss: 1.1306, accuracy: 0.8050
# Iter : 37001, loss: 1.0052, accuracy: 0.7950
# Iter : 38001, loss: 0.7070, accuracy: 0.8020
# Iter : 39001, loss: 0.8745, accuracy: 0.8110
# Iter : 40001, loss: 0.8110, accuracy: 0.8080
# Iter : 41001, loss: 0.6974, accuracy: 0.8110
# Iter : 42001, loss: 1.4601, accuracy: 0.8280
# Iter : 43001, loss: 0.5272, accuracy: 0.8090
# Iter : 44001, loss: 0.4977, accuracy: 0.8280
# Iter : 45001, loss: 0.4995, accuracy: 0.8020
# Iter : 46001, loss: 0.8382, accuracy: 0.8260
# Iter : 47001, loss: 0.6844, accuracy: 0.8040
# Iter : 48001, loss: 0.9338, accuracy: 0.8260
# Iter : 49001, loss: 1.1279, accuracy: 0.8150
# Iter : 50001, loss: 0.4685, accuracy: 0.8090
# Iter : 51001, loss: 0.6010, accuracy: 0.8180
# Iter : 52001, loss: 0.4993, accuracy: 0.8190
# Iter : 53001, loss: 1.0907, accuracy: 0.8240
# Iter : 54001, loss: 0.5781, accuracy: 0.8120
# Iter : 55001, loss: 0.8984, accuracy: 0.8150
# Iter : 56001, loss: 0.8775, accuracy: 0.7930
# Iter : 57001, loss: 0.7146, accuracy: 0.8000
# Iter : 58001, loss: 0.7145, accuracy: 0.7950
# Iter : 59001, loss: 0.7369, accuracy: 0.8050
# Iter : 60001, loss: 0.8242, accuracy: 0.7920
# Iter : 61001, loss: 0.7191, accuracy: 0.8210
# Iter : 62001, loss: 0.8085, accuracy: 0.8010
# Iter : 63001, loss: 0.4534, accuracy: 0.8190
# Iter : 64001, loss: 0.5547, accuracy: 0.8190
# Iter : 65001, loss: 0.8155, accuracy: 0.8170
# Iter : 66001, loss: 0.8852, accuracy: 0.8180
# Iter : 67001, loss: 0.7873, accuracy: 0.8000
# Iter : 68001, loss: 0.7582, accuracy: 0.8060
# Iter : 69001, loss: 0.5371, accuracy: 0.8300
# Iter : 70001, loss: 0.3453, accuracy: 0.8090
# Iter : 71001, loss: 0.3806, accuracy: 0.7970
# Iter : 72001, loss: 0.5090, accuracy: 0.8120
# Iter : 73001, loss: 0.7413, accuracy: 0.8250
# Iter : 74001, loss: 0.7392, accuracy: 0.8280
# Iter : 75001, loss: 0.7347, accuracy: 0.8330
# Iter : 76001, loss: 0.9797, accuracy: 0.8160
# Iter : 77001, loss: 0.6032, accuracy: 0.8230
# Iter : 78001, loss: 0.4229, accuracy: 0.8230
# Iter : 79001, loss: 0.8907, accuracy: 0.8230
# Iter : 80001, loss: 0.6312, accuracy: 0.8130
# Iter : 81001, loss: 0.5967, accuracy: 0.8140
# Iter : 82001, loss: 0.4298, accuracy: 0.8320
# Iter : 83001, loss: 0.6270, accuracy: 0.7950
# Iter : 84001, loss: 0.6527, accuracy: 0.8070
# Iter : 85001, loss: 0.7471, accuracy: 0.8180
# Iter : 86001, loss: 0.7084, accuracy: 0.8130
# Iter : 87001, loss: 0.6999, accuracy: 0.8080
# Iter : 88001, loss: 0.8665, accuracy: 0.8200
# Iter : 89001, loss: 0.6282, accuracy: 0.8120
# Iter : 90001, loss: 1.2937, accuracy: 0.8170
# Iter : 91001, loss: 0.6662, accuracy: 0.8000
# Iter : 92001, loss: 1.0000, accuracy: 0.8120
# Iter : 93001, loss: 0.5462, accuracy: 0.8080
# Iter : 94001, loss: 0.5252, accuracy: 0.8050
# Iter : 95001, loss: 1.0244, accuracy: 0.8160
# Iter : 96001, loss: 1.0859, accuracy: 0.8220
# Iter : 97001, loss: 0.5623, accuracy: 0.8200
# Iter : 98001, loss: 0.5897, accuracy: 0.8240
# Iter : 99001, loss: 0.5820, accuracy: 0.8210
# Doing rep  3
# Iter : 1001, loss: 1.0187, accuracy: 0.3570
# Iter : 2001, loss: 0.6259, accuracy: 0.6050
# Iter : 3001, loss: 0.7779, accuracy: 0.7730
# Iter : 4001, loss: 0.7041, accuracy: 0.8080
# Iter : 5001, loss: 0.7090, accuracy: 0.7820
# Iter : 6001, loss: 0.6806, accuracy: 0.7860
# Iter : 7001, loss: 0.4950, accuracy: 0.8050
# Iter : 8001, loss: 0.5910, accuracy: 0.8060
# Iter : 9001, loss: 1.2194, accuracy: 0.7910
# Iter : 10001, loss: 0.7116, accuracy: 0.7830
# Iter : 11001, loss: 0.9721, accuracy: 0.7930
# Iter : 12001, loss: 0.9265, accuracy: 0.7870
# Iter : 13001, loss: 0.5385, accuracy: 0.8090
# Iter : 14001, loss: 0.3311, accuracy: 0.8100
# Iter : 15001, loss: 0.4767, accuracy: 0.8110
# Iter : 16001, loss: 0.8789, accuracy: 0.7860
# Iter : 17001, loss: 0.4248, accuracy: 0.7970
# Iter : 18001, loss: 0.3910, accuracy: 0.7970
# Iter : 19001, loss: 0.9109, accuracy: 0.7860
# Iter : 20001, loss: 0.8689, accuracy: 0.7920
# Iter : 21001, loss: 1.1025, accuracy: 0.8190
# Iter : 22001, loss: 1.0673, accuracy: 0.7970
# Iter : 23001, loss: 0.6532, accuracy: 0.7930
# Iter : 24001, loss: 0.7228, accuracy: 0.7930
# Iter : 25001, loss: 0.5811, accuracy: 0.8150
# Iter : 26001, loss: 0.8524, accuracy: 0.8080
# Iter : 27001, loss: 0.5207, accuracy: 0.8150
# Iter : 28001, loss: 0.9874, accuracy: 0.8140
# Iter : 29001, loss: 0.5148, accuracy: 0.8060
# Iter : 30001, loss: 0.4843, accuracy: 0.8050
# Iter : 31001, loss: 0.5591, accuracy: 0.8120
# Iter : 32001, loss: 0.4085, accuracy: 0.8060
# Iter : 33001, loss: 0.8248, accuracy: 0.8090
# Iter : 34001, loss: 0.7339, accuracy: 0.7980
# Iter : 35001, loss: 0.9212, accuracy: 0.8030
# Iter : 36001, loss: 0.8478, accuracy: 0.8100
# Iter : 37001, loss: 0.7857, accuracy: 0.8150
# Iter : 38001, loss: 0.8502, accuracy: 0.8160
# Iter : 39001, loss: 0.7979, accuracy: 0.7910
# Iter : 40001, loss: 0.7904, accuracy: 0.8070
# Iter : 41001, loss: 0.9813, accuracy: 0.8040
# Iter : 42001, loss: 1.1064, accuracy: 0.7970
# Iter : 43001, loss: 0.6463, accuracy: 0.8020
# Iter : 44001, loss: 0.6668, accuracy: 0.8180
# Iter : 45001, loss: 0.4636, accuracy: 0.8030
# Iter : 46001, loss: 0.5920, accuracy: 0.7990
# Iter : 47001, loss: 0.8894, accuracy: 0.8160
# Iter : 48001, loss: 0.8018, accuracy: 0.7950
# Iter : 49001, loss: 0.7090, accuracy: 0.8100
# Iter : 50001, loss: 0.4619, accuracy: 0.8040
# Iter : 51001, loss: 0.5593, accuracy: 0.8060
# Iter : 52001, loss: 0.5074, accuracy: 0.7990
# Iter : 53001, loss: 1.0030, accuracy: 0.8140
# Iter : 54001, loss: 0.4667, accuracy: 0.7990
# Iter : 55001, loss: 0.8818, accuracy: 0.8000
# Iter : 56001, loss: 0.4558, accuracy: 0.7990
# Iter : 57001, loss: 0.6979, accuracy: 0.7930
# Iter : 58001, loss: 0.9610, accuracy: 0.8050
# Iter : 59001, loss: 0.6856, accuracy: 0.7930
# Iter : 60001, loss: 0.9338, accuracy: 0.8010
# Iter : 61001, loss: 0.5030, accuracy: 0.7950
# Iter : 62001, loss: 0.7224, accuracy: 0.7880
# Iter : 63001, loss: 0.6895, accuracy: 0.7970
# Iter : 64001, loss: 0.4151, accuracy: 0.8000
# Iter : 65001, loss: 0.6674, accuracy: 0.7890
# Iter : 66001, loss: 0.6808, accuracy: 0.8200
# Iter : 67001, loss: 0.5235, accuracy: 0.8020
# Iter : 68001, loss: 0.7545, accuracy: 0.8050
# Iter : 69001, loss: 0.7838, accuracy: 0.7890
# Iter : 70001, loss: 0.7598, accuracy: 0.7960
# Iter : 71001, loss: 0.6224, accuracy: 0.8050
# Iter : 72001, loss: 0.7500, accuracy: 0.7970
# Iter : 73001, loss: 0.8811, accuracy: 0.8030
# Iter : 74001, loss: 0.4997, accuracy: 0.7930
# Iter : 75001, loss: 0.4842, accuracy: 0.7880
# Iter : 76001, loss: 0.4467, accuracy: 0.7970
# Iter : 77001, loss: 0.4644, accuracy: 0.7940
# Iter : 78001, loss: 0.4951, accuracy: 0.8050
# Iter : 79001, loss: 1.1866, accuracy: 0.8040
# Iter : 80001, loss: 0.6280, accuracy: 0.8090
# Iter : 81001, loss: 0.8348, accuracy: 0.7840
# Iter : 82001, loss: 0.6053, accuracy: 0.7770
# Iter : 83001, loss: 0.6699, accuracy: 0.7900
# Iter : 84001, loss: 0.9510, accuracy: 0.8020
# Iter : 85001, loss: 0.6347, accuracy: 0.8220
# Iter : 86001, loss: 1.1942, accuracy: 0.7950
# Iter : 87001, loss: 1.1319, accuracy: 0.8030
# Iter : 88001, loss: 0.9717, accuracy: 0.8060
# Iter : 89001, loss: 0.8297, accuracy: 0.8090
# Iter : 90001, loss: 0.6633, accuracy: 0.7830
# Iter : 91001, loss: 0.7027, accuracy: 0.7780
# Iter : 92001, loss: 0.6814, accuracy: 0.8000
# Iter : 93001, loss: 0.5380, accuracy: 0.8110
# Iter : 94001, loss: 1.0975, accuracy: 0.8060
# Iter : 95001, loss: 0.7229, accuracy: 0.7850
# Iter : 96001, loss: 0.6148, accuracy: 0.7870
# Iter : 97001, loss: 0.8990, accuracy: 0.7990
# Iter : 98001, loss: 0.8895, accuracy: 0.7930
# Iter : 99001, loss: 0.5863, accuracy: 0.8000
# Doing rep  4
# Iter : 1001, loss: 0.9029, accuracy: 0.4400
# Iter : 2001, loss: 0.5279, accuracy: 0.6800
# Iter : 3001, loss: 0.6332, accuracy: 0.7860
# Iter : 4001, loss: 0.7094, accuracy: 0.8120
# Iter : 5001, loss: 1.2097, accuracy: 0.7930
# Iter : 6001, loss: 0.4314, accuracy: 0.8130
# Iter : 7001, loss: 0.8985, accuracy: 0.8020
# Iter : 8001, loss: 0.9135, accuracy: 0.7960
# Iter : 9001, loss: 0.3462, accuracy: 0.7910
# Iter : 10001, loss: 0.3858, accuracy: 0.8090
# Iter : 11001, loss: 0.4426, accuracy: 0.7910
# Iter : 12001, loss: 0.9445, accuracy: 0.7870
# Iter : 13001, loss: 0.7066, accuracy: 0.8190
# Iter : 14001, loss: 0.5791, accuracy: 0.8080
# Iter : 15001, loss: 0.9703, accuracy: 0.7880
# Iter : 16001, loss: 0.5492, accuracy: 0.7980
# Iter : 17001, loss: 0.2872, accuracy: 0.8260
# Iter : 18001, loss: 0.5267, accuracy: 0.8070
# Iter : 19001, loss: 0.4488, accuracy: 0.8060
# Iter : 20001, loss: 0.7588, accuracy: 0.8080
# Iter : 21001, loss: 0.4731, accuracy: 0.8250
# Iter : 22001, loss: 0.9003, accuracy: 0.8210
# Iter : 23001, loss: 0.4206, accuracy: 0.8080
# Iter : 24001, loss: 0.6519, accuracy: 0.8000
# Iter : 25001, loss: 0.4092, accuracy: 0.8040
# Iter : 26001, loss: 1.0405, accuracy: 0.7980
# Iter : 27001, loss: 1.0308, accuracy: 0.8020
# Iter : 28001, loss: 0.7129, accuracy: 0.8150
# Iter : 29001, loss: 1.0556, accuracy: 0.8190
# Iter : 30001, loss: 0.9175, accuracy: 0.8010
# Iter : 31001, loss: 0.5171, accuracy: 0.8080
# Iter : 32001, loss: 0.5828, accuracy: 0.7950
# Iter : 33001, loss: 0.5791, accuracy: 0.8110
# Iter : 34001, loss: 1.2593, accuracy: 0.8150
# Iter : 35001, loss: 0.6472, accuracy: 0.8000
# Iter : 36001, loss: 0.9517, accuracy: 0.8210
# Iter : 37001, loss: 0.6835, accuracy: 0.8060
# Iter : 38001, loss: 0.6357, accuracy: 0.8180
# Iter : 39001, loss: 0.6980, accuracy: 0.8110
# Iter : 40001, loss: 0.5965, accuracy: 0.8150
# Iter : 41001, loss: 0.6592, accuracy: 0.7930
# Iter : 42001, loss: 0.7684, accuracy: 0.8030
# Iter : 43001, loss: 0.6867, accuracy: 0.7930
# Iter : 44001, loss: 0.7453, accuracy: 0.8050
# Iter : 45001, loss: 0.9534, accuracy: 0.8100
# Iter : 46001, loss: 0.3692, accuracy: 0.8290
# Iter : 47001, loss: 0.7907, accuracy: 0.8140
# Iter : 48001, loss: 0.4021, accuracy: 0.8150
# Iter : 49001, loss: 0.8322, accuracy: 0.7970
# Iter : 50001, loss: 0.6957, accuracy: 0.8020
# Iter : 51001, loss: 0.4882, accuracy: 0.8120
# Iter : 52001, loss: 1.2514, accuracy: 0.7970
# Iter : 53001, loss: 0.4212, accuracy: 0.8130
# Iter : 54001, loss: 0.4118, accuracy: 0.8140
# Iter : 55001, loss: 0.5871, accuracy: 0.8120
# Iter : 56001, loss: 1.0053, accuracy: 0.8130
# Iter : 57001, loss: 0.9013, accuracy: 0.7980
# Iter : 58001, loss: 1.1222, accuracy: 0.8030
# Iter : 59001, loss: 0.4241, accuracy: 0.7890
# Iter : 60001, loss: 0.6756, accuracy: 0.8050
# Iter : 61001, loss: 0.6884, accuracy: 0.8310
# Iter : 62001, loss: 0.7110, accuracy: 0.8110
# Iter : 63001, loss: 0.7117, accuracy: 0.8240
# Iter : 64001, loss: 0.4836, accuracy: 0.8150
# Iter : 65001, loss: 0.6119, accuracy: 0.8000
# Iter : 66001, loss: 0.5045, accuracy: 0.8120
# Iter : 67001, loss: 0.4792, accuracy: 0.8160
# Iter : 68001, loss: 0.7547, accuracy: 0.8170
# Iter : 69001, loss: 0.8165, accuracy: 0.7880
# Iter : 70001, loss: 0.9680, accuracy: 0.8070
# Iter : 71001, loss: 0.5632, accuracy: 0.8050
# Iter : 72001, loss: 0.5377, accuracy: 0.8110
# Iter : 73001, loss: 0.8363, accuracy: 0.8180
# Iter : 74001, loss: 0.4010, accuracy: 0.8130
# Iter : 75001, loss: 0.9318, accuracy: 0.8120
# Iter : 76001, loss: 0.7491, accuracy: 0.8090
# Iter : 77001, loss: 0.7794, accuracy: 0.8070
# Iter : 78001, loss: 0.4426, accuracy: 0.8060
# Iter : 79001, loss: 0.9605, accuracy: 0.8110
# Iter : 80001, loss: 0.8319, accuracy: 0.8090
# Iter : 81001, loss: 0.6245, accuracy: 0.8160
# Iter : 82001, loss: 0.8024, accuracy: 0.8180
# Iter : 83001, loss: 0.4205, accuracy: 0.8090
# Iter : 84001, loss: 0.7567, accuracy: 0.8020
# Iter : 85001, loss: 0.4863, accuracy: 0.8190
# Iter : 86001, loss: 0.5829, accuracy: 0.8170
# Iter : 87001, loss: 0.5404, accuracy: 0.8110
# Iter : 88001, loss: 0.9266, accuracy: 0.8010
# Iter : 89001, loss: 0.6037, accuracy: 0.8140
# Iter : 90001, loss: 0.9045, accuracy: 0.8170
# Iter : 91001, loss: 0.4608, accuracy: 0.8030
# Iter : 92001, loss: 0.5961, accuracy: 0.8080
# Iter : 93001, loss: 0.9012, accuracy: 0.7950
# Iter : 94001, loss: 0.6417, accuracy: 0.8090
# Iter : 95001, loss: 0.6573, accuracy: 0.8090
# Iter : 96001, loss: 0.5932, accuracy: 0.8160
# Iter : 97001, loss: 0.7009, accuracy: 0.8280
# Iter : 98001, loss: 0.8095, accuracy: 0.8270
# Iter : 99001, loss: 0.4781, accuracy: 0.8200

# %%
test_acc = np.array(test_acc)
test_acc_not_sparse = np.array(test_acc_not_sparse)
test_acc_control = np.array(test_acc_control)
sleep_break = 10000
sns.set(
        color_codes=True, palette="bright", style="white", context="talk", font_scale=1.5
    )
font = 40

fig, ax = plt.subplots(1, 1, figsize=(8,8), sharex=True, sharey=True)

ax.hlines(0.1, 0, total_samples+sleep_break, linestyles='dashed', label='Optimal Performance', color='k')

ax.plot(np.median(1-test_acc[:,:initial_training_sample],axis=0),linewidth=2, color='r', label='with cortex')
ax.fill_between(np.arange(1,initial_training_sample+1), np.quantile(1-test_acc[:,:initial_training_sample], 0.25, axis=0), np.quantile(1-test_acc[:,:initial_training_sample], 0.75, axis=0), color='r', alpha=.3)

ax.plot(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc[0][initial_training_sample+sleep_samples:])), np.median(1-test_acc[:,initial_training_sample+sleep_samples:],axis=0),linewidth=2, color='r')
ax.fill_between(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc[0][initial_training_sample+sleep_samples:])), np.quantile(1-test_acc[:,initial_training_sample+sleep_samples:], 0.25, axis=0), np.quantile(1-test_acc[:,initial_training_sample+sleep_samples:], 0.75, axis=0), color='r', alpha=.3)


ax.plot(np.median(1-test_acc_not_sparse[:,:initial_training_sample],axis=0),linewidth=2, color='b', label='with cortex no sparsity')
ax.fill_between(np.arange(1,initial_training_sample+1), np.quantile(1-test_acc_not_sparse[:,:initial_training_sample], 0.25, axis=0), np.quantile(1-test_acc_not_sparse[:,:initial_training_sample], 0.75, axis=0), color='b', alpha=.3)

ax.plot(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_not_sparse[0][initial_training_sample+sleep_samples:])), np.median(1-test_acc_not_sparse[:,initial_training_sample+sleep_samples:],axis=0),linewidth=2, color='b')
ax.fill_between(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_not_sparse[0][initial_training_sample+sleep_samples:])), np.quantile(1-test_acc_not_sparse[:,initial_training_sample+sleep_samples:], 0.25, axis=0), np.quantile(1-test_acc_not_sparse[:,initial_training_sample+sleep_samples:], 0.75, axis=0), color='b', alpha=.3)

ax.vlines(initial_training_sample, 0.1, 1, linestyles='dashed', color='b')
ax.vlines(initial_training_sample+sleep_break, 0.1, 1, linestyles='dashed', color='b')


ax.plot(np.median(1-test_acc_control[:,:initial_training_sample],axis=0),linewidth=2, color='k', label='without cortex')
ax.fill_between(np.arange(1,initial_training_sample+1), np.quantile(1-test_acc_control[:,:initial_training_sample], 0.25, axis=0), np.quantile(1-test_acc_control[:,:initial_training_sample], 0.75, axis=0), color='k', alpha=.3)

ax.plot(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_control[0][initial_training_sample:])), np.median(1-test_acc_control[:,initial_training_sample:],axis=0),linewidth=2, color='k')
ax.fill_between(np.arange(initial_training_sample+sleep_break,initial_training_sample+sleep_break+len(test_acc_control[0][initial_training_sample:])), np.quantile(1-test_acc_control[:,initial_training_sample:], 0.25, axis=0), np.quantile(1-test_acc_control[:,initial_training_sample:], 0.75, axis=0), color='k', alpha=.3)


plt.xticks([1, total_samples+sleep_break])
plt.yticks([0.1, 0.5, 1.0])

ax.set_ylabel('Error', fontsize=font)
# ax.set_yscale('log') 


ax.tick_params(labelsize=40)
    
right_side = ax.spines["right"]
right_side.set_visible(False)
top_side = ax.spines["top"]
top_side.set_visible(False)

fig.text(.36, .92, 'Sleep', rotation=0, fontsize=20)
fig.legend(bbox_to_anchor=(0.5, -0.02), bbox_transform=plt.gcf().transFigure,
                        ncol=2, loc='upper center', fontsize=20, frameon=False)
plt.tight_layout()

# %%
generate_sleep_samples(main_model, 1000)
# Out:
# '...'
