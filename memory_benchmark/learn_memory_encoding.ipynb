# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import random

# %%
#torch.manual_seed(0)
#random.seed(0)

vocab_size = 3
seq_len = 3
hidden_size = 20
num_epochs = 100000

def generate_sample():
    tokens = [random.randint(0, vocab_size - 1) for _ in range(seq_len)]
    x = F.one_hot(torch.tensor(tokens[:seq_len-1]), num_classes=vocab_size).float().unsqueeze(0)
    y = torch.tensor(tokens[-1]).unsqueeze(0)
    return x, y

class RNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.RNN(vocab_size, hidden_size, batch_first=True)
        self.out_linear = nn.Linear(hidden_size, vocab_size)

    def forward(self, x):
        out, h = self.encoder(x)
        out = self.out_linear(out[:,-1,:])
        return out, h

model = RNN()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

for epoch in range(num_epochs):
    x, y = generate_sample()
    logits, h = model(x)
    loss = criterion(logits, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epoch % 50 == 0:
        pred = logits.argmax(dim=1)
        print(f"Epoch {epoch}: Loss={loss.item():.4f}, Predicted={pred.tolist()}, Target={y.tolist()}")
# Out:
# Epoch 0: Loss=1.1230, Predicted=[1], Target=[2]
# Epoch 50: Loss=1.1734, Predicted=[0], Target=[2]
# Epoch 100: Loss=1.0360, Predicted=[1], Target=[1]
# Epoch 150: Loss=1.0935, Predicted=[0], Target=[2]
# Epoch 200: Loss=0.8480, Predicted=[0], Target=[0]
# Epoch 250: Loss=1.0401, Predicted=[2], Target=[1]
# Epoch 300: Loss=1.0914, Predicted=[0], Target=[1]
# Epoch 350: Loss=1.1367, Predicted=[0], Target=[2]
# Epoch 400: Loss=1.0388, Predicted=[0], Target=[0]
# Epoch 450: Loss=1.1242, Predicted=[1], Target=[0]
# Epoch 500: Loss=0.9471, Predicted=[0], Target=[0]
# Epoch 550: Loss=1.0185, Predicted=[2], Target=[0]
# Epoch 600: Loss=1.0330, Predicted=[0], Target=[2]
# Epoch 650: Loss=1.0888, Predicted=[2], Target=[0]
# Epoch 700: Loss=1.1706, Predicted=[0], Target=[1]
# Epoch 750: Loss=0.9562, Predicted=[0], Target=[0]
# Epoch 800: Loss=1.2034, Predicted=[0], Target=[2]
# Epoch 850: Loss=0.8557, Predicted=[0], Target=[0]
# Epoch 900: Loss=1.0868, Predicted=[0], Target=[2]
# Epoch 950: Loss=1.1585, Predicted=[0], Target=[1]
# Epoch 1000: Loss=1.1765, Predicted=[0], Target=[2]
# Epoch 1050: Loss=1.1276, Predicted=[0], Target=[2]
# Epoch 1100: Loss=0.7541, Predicted=[0], Target=[0]
# Epoch 1150: Loss=1.4077, Predicted=[1], Target=[0]
# Epoch 1200: Loss=1.0326, Predicted=[0], Target=[1]
# Epoch 1250: Loss=1.2042, Predicted=[1], Target=[0]
# Epoch 1300: Loss=1.0680, Predicted=[0], Target=[1]
# Epoch 1350: Loss=1.1706, Predicted=[1], Target=[2]
# Epoch 1400: Loss=1.1947, Predicted=[1], Target=[2]
# Epoch 1450: Loss=1.1771, Predicted=[1], Target=[0]
# Epoch 1500: Loss=0.9939, Predicted=[1], Target=[1]
# Epoch 1550: Loss=1.1391, Predicted=[1], Target=[2]
# Epoch 1600: Loss=1.1399, Predicted=[1], Target=[2]
# Epoch 1650: Loss=1.0937, Predicted=[1], Target=[2]
# Epoch 1700: Loss=1.1227, Predicted=[1], Target=[0]
# Epoch 1750: Loss=1.3731, Predicted=[1], Target=[2]
# Epoch 1800: Loss=1.1382, Predicted=[1], Target=[2]
# Epoch 1850: Loss=1.1093, Predicted=[1], Target=[2]
# Epoch 1900: Loss=0.9372, Predicted=[2], Target=[2]
# Epoch 1950: Loss=1.3942, Predicted=[2], Target=[1]
# Epoch 2000: Loss=1.0208, Predicted=[2], Target=[1]
# Epoch 2050: Loss=0.7834, Predicted=[0], Target=[0]
# Epoch 2100: Loss=0.9761, Predicted=[1], Target=[1]
# Epoch 2150: Loss=1.3555, Predicted=[2], Target=[1]
# Epoch 2200: Loss=0.9543, Predicted=[1], Target=[1]
# Epoch 2250: Loss=1.1727, Predicted=[1], Target=[2]
# Epoch 2300: Loss=0.9925, Predicted=[1], Target=[1]
# Epoch 2350: Loss=1.4330, Predicted=[1], Target=[0]
# Epoch 2400: Loss=1.3328, Predicted=[2], Target=[1]
# Epoch 2450: Loss=1.1711, Predicted=[1], Target=[2]
# Epoch 2500: Loss=1.1144, Predicted=[1], Target=[2]
# Epoch 2550: Loss=0.9934, Predicted=[1], Target=[1]
# Epoch 2600: Loss=1.0879, Predicted=[1], Target=[0]
# Epoch 2650: Loss=1.1228, Predicted=[1], Target=[2]
# Epoch 2700: Loss=1.0805, Predicted=[1], Target=[2]
# Epoch 2750: Loss=1.0076, Predicted=[1], Target=[1]
# Epoch 2800: Loss=1.2368, Predicted=[2], Target=[0]
# Epoch 2850: Loss=1.0363, Predicted=[1], Target=[1]
# Epoch 2900: Loss=0.9436, Predicted=[1], Target=[1]
# Epoch 2950: Loss=1.0008, Predicted=[2], Target=[2]
# Epoch 3000: Loss=1.0850, Predicted=[0], Target=[2]
# Epoch 3050: Loss=1.2147, Predicted=[0], Target=[2]
# Epoch 3100: Loss=1.0645, Predicted=[0], Target=[2]
# Epoch 3150: Loss=0.5460, Predicted=[0], Target=[0]
# Epoch 3200: Loss=1.3816, Predicted=[0], Target=[1]
# Epoch 3250: Loss=1.0238, Predicted=[2], Target=[2]
# Epoch 3300: Loss=1.2442, Predicted=[0], Target=[2]
# Epoch 3350: Loss=1.0366, Predicted=[1], Target=[1]
# Epoch 3400: Loss=1.2027, Predicted=[0], Target=[1]
# Epoch 3450: Loss=1.0840, Predicted=[0], Target=[2]
# Epoch 3500: Loss=1.2515, Predicted=[1], Target=[2]
# Epoch 3550: Loss=1.1309, Predicted=[0], Target=[1]
# Epoch 3600: Loss=1.4341, Predicted=[2], Target=[0]
# Epoch 3650: Loss=1.4335, Predicted=[2], Target=[0]
# Epoch 3700: Loss=1.1752, Predicted=[0], Target=[1]
# Epoch 3750: Loss=1.4382, Predicted=[1], Target=[0]
# Epoch 3800: Loss=1.2985, Predicted=[2], Target=[1]
# Epoch 3850: Loss=1.1487, Predicted=[1], Target=[2]
# Epoch 3900: Loss=1.2413, Predicted=[0], Target=[1]
# Epoch 3950: Loss=1.0282, Predicted=[0], Target=[0]
# Epoch 4000: Loss=0.9982, Predicted=[1], Target=[1]
# Epoch 4050: Loss=1.1304, Predicted=[2], Target=[1]
# Epoch 4100: Loss=1.2372, Predicted=[1], Target=[0]
# Epoch 4150: Loss=0.9183, Predicted=[1], Target=[0]
# Epoch 4200: Loss=1.0492, Predicted=[1], Target=[1]
# Epoch 4250: Loss=1.1232, Predicted=[1], Target=[0]
# Epoch 4300: Loss=1.3469, Predicted=[0], Target=[2]
# Epoch 4350: Loss=0.9669, Predicted=[0], Target=[0]
# Epoch 4400: Loss=1.1054, Predicted=[0], Target=[1]
# Epoch 4450: Loss=0.9911, Predicted=[0], Target=[0]
# Epoch 4500: Loss=0.9294, Predicted=[0], Target=[0]
# Epoch 4550: Loss=0.9396, Predicted=[1], Target=[1]
# Epoch 4600: Loss=1.0744, Predicted=[2], Target=[2]
# Epoch 4650: Loss=1.0164, Predicted=[1], Target=[1]
# Epoch 4700: Loss=1.3116, Predicted=[2], Target=[0]
# Epoch 4750: Loss=1.0325, Predicted=[0], Target=[0]
# Epoch 4800: Loss=1.0590, Predicted=[0], Target=[0]
# Epoch 4850: Loss=1.0899, Predicted=[0], Target=[0]
# Epoch 4900: Loss=1.1186, Predicted=[1], Target=[2]
# Epoch 4950: Loss=1.1572, Predicted=[1], Target=[0]
# Epoch 5000: Loss=1.1110, Predicted=[2], Target=[1]
# Epoch 5050: Loss=1.0286, Predicted=[2], Target=[2]
# Epoch 5100: Loss=1.1406, Predicted=[2], Target=[1]
# Epoch 5150: Loss=1.0731, Predicted=[2], Target=[1]
# Epoch 5200: Loss=1.2313, Predicted=[1], Target=[0]
# Epoch 5250: Loss=1.0621, Predicted=[1], Target=[2]
# Epoch 5300: Loss=1.1242, Predicted=[0], Target=[2]
# Epoch 5350: Loss=1.3963, Predicted=[0], Target=[2]
# Epoch 5400: Loss=1.0879, Predicted=[0], Target=[2]
# Epoch 5450: Loss=1.1776, Predicted=[2], Target=[1]
# Epoch 5500: Loss=1.4585, Predicted=[1], Target=[0]
# Epoch 5550: Loss=1.1353, Predicted=[2], Target=[1]
# Epoch 5600: Loss=1.1000, Predicted=[2], Target=[0]
# Epoch 5650: Loss=1.1119, Predicted=[1], Target=[2]
# Epoch 5700: Loss=0.9576, Predicted=[2], Target=[2]
# Epoch 5750: Loss=0.9690, Predicted=[0], Target=[0]
# Epoch 5800: Loss=1.3568, Predicted=[2], Target=[1]
# Epoch 5850: Loss=1.3147, Predicted=[2], Target=[0]
# Epoch 5900: Loss=1.1952, Predicted=[2], Target=[1]
# Epoch 5950: Loss=0.6629, Predicted=[1], Target=[1]
# Epoch 6000: Loss=1.0667, Predicted=[2], Target=[1]
# Epoch 6050: Loss=1.1274, Predicted=[1], Target=[0]
# Epoch 6100: Loss=1.1331, Predicted=[1], Target=[2]
# Epoch 6150: Loss=0.9475, Predicted=[2], Target=[2]
# Epoch 6200: Loss=1.2387, Predicted=[2], Target=[1]
# Epoch 6250: Loss=1.2590, Predicted=[2], Target=[0]
# Epoch 6300: Loss=1.1296, Predicted=[2], Target=[1]
# Epoch 6350: Loss=1.6272, Predicted=[0], Target=[1]
# Epoch 6400: Loss=1.0005, Predicted=[0], Target=[2]
# Epoch 6450: Loss=1.2078, Predicted=[1], Target=[2]
# Epoch 6500: Loss=0.9336, Predicted=[2], Target=[2]
# Epoch 6550: Loss=1.7034, Predicted=[1], Target=[0]
# Epoch 6600: Loss=1.2528, Predicted=[0], Target=[1]
# Epoch 6650: Loss=1.0015, Predicted=[1], Target=[1]
# Epoch 6700: Loss=1.1041, Predicted=[1], Target=[0]
# Epoch 6750: Loss=1.0358, Predicted=[2], Target=[2]
# Epoch 6800: Loss=1.3394, Predicted=[2], Target=[0]
# Epoch 6850: Loss=1.0572, Predicted=[1], Target=[1]
# Epoch 6900: Loss=1.1651, Predicted=[1], Target=[0]
# Epoch 6950: Loss=1.1281, Predicted=[1], Target=[0]
# Epoch 7000: Loss=1.5851, Predicted=[1], Target=[0]
# Epoch 7050: Loss=1.0306, Predicted=[0], Target=[0]
# Epoch 7100: Loss=0.9768, Predicted=[2], Target=[2]
# Epoch 7150: Loss=1.1043, Predicted=[2], Target=[0]
# Epoch 7200: Loss=1.2196, Predicted=[0], Target=[2]
# Epoch 7250: Loss=1.0227, Predicted=[0], Target=[0]
# Epoch 7300: Loss=1.1023, Predicted=[2], Target=[0]
# Epoch 7350: Loss=1.0394, Predicted=[2], Target=[2]
# Epoch 7400: Loss=1.0993, Predicted=[0], Target=[1]
# Epoch 7450: Loss=1.2146, Predicted=[2], Target=[1]
# Epoch 7500: Loss=1.1552, Predicted=[2], Target=[0]
# Epoch 7550: Loss=0.8950, Predicted=[2], Target=[2]
# Epoch 7600: Loss=1.2582, Predicted=[0], Target=[1]
# Epoch 7650: Loss=1.0787, Predicted=[0], Target=[0]
# Epoch 7700: Loss=1.2025, Predicted=[1], Target=[2]
# Epoch 7750: Loss=1.1695, Predicted=[0], Target=[1]
# Epoch 7800: Loss=1.1909, Predicted=[0], Target=[1]
# Epoch 7850: Loss=1.2530, Predicted=[1], Target=[2]
# Epoch 7900: Loss=0.9941, Predicted=[1], Target=[1]
# Epoch 7950: Loss=1.0276, Predicted=[2], Target=[0]
# Epoch 8000: Loss=1.0692, Predicted=[2], Target=[0]
# Epoch 8050: Loss=1.1220, Predicted=[0], Target=[2]
# Epoch 8100: Loss=1.0786, Predicted=[2], Target=[0]
# Epoch 8150: Loss=1.1127, Predicted=[0], Target=[2]
# Epoch 8200: Loss=1.2432, Predicted=[0], Target=[2]
# Epoch 8250: Loss=1.2196, Predicted=[0], Target=[1]
# Epoch 8300: Loss=0.9334, Predicted=[0], Target=[0]
# Epoch 8350: Loss=1.0127, Predicted=[0], Target=[0]
# Epoch 8400: Loss=0.9958, Predicted=[2], Target=[2]
# Epoch 8450: Loss=1.2524, Predicted=[2], Target=[1]
# Epoch 8500: Loss=1.0950, Predicted=[2], Target=[1]
# Epoch 8550: Loss=1.1803, Predicted=[0], Target=[2]
# Epoch 8600: Loss=1.0102, Predicted=[0], Target=[0]
# Epoch 8650: Loss=0.9169, Predicted=[0], Target=[0]
# Epoch 8700: Loss=1.0739, Predicted=[0], Target=[1]
# Epoch 8750: Loss=1.0021, Predicted=[0], Target=[0]
# Epoch 8800: Loss=1.1496, Predicted=[0], Target=[2]
# Epoch 8850: Loss=1.1360, Predicted=[0], Target=[1]
# Epoch 8900: Loss=1.2053, Predicted=[0], Target=[2]
# Epoch 8950: Loss=0.9338, Predicted=[0], Target=[0]
# Epoch 9000: Loss=0.9941, Predicted=[0], Target=[0]
# Epoch 9050: Loss=1.0129, Predicted=[2], Target=[2]
# Epoch 9100: Loss=1.1423, Predicted=[2], Target=[1]
# Epoch 9150: Loss=1.0904, Predicted=[1], Target=[2]
# Epoch 9200: Loss=1.0538, Predicted=[0], Target=[0]
# Epoch 9250: Loss=1.1200, Predicted=[1], Target=[0]
# Epoch 9300: Loss=1.0508, Predicted=[1], Target=[1]
# Epoch 9350: Loss=0.9929, Predicted=[1], Target=[1]
# Epoch 9400: Loss=0.9327, Predicted=[1], Target=[1]
# Epoch 9450: Loss=0.7736, Predicted=[1], Target=[1]
# Epoch 9500: Loss=1.1958, Predicted=[1], Target=[2]
# Epoch 9550: Loss=1.1520, Predicted=[0], Target=[1]
# Epoch 9600: Loss=1.1010, Predicted=[2], Target=[1]
# Epoch 9650: Loss=1.1119, Predicted=[2], Target=[1]
# Epoch 9700: Loss=1.2946, Predicted=[0], Target=[2]
# Epoch 9750: Loss=0.9604, Predicted=[0], Target=[0]
# Epoch 9800: Loss=1.0096, Predicted=[2], Target=[2]
# Epoch 9850: Loss=0.8043, Predicted=[2], Target=[2]
# Epoch 9900: Loss=0.9795, Predicted=[0], Target=[0]
# Epoch 9950: Loss=0.8910, Predicted=[1], Target=[1]
# Epoch 10000: Loss=1.1990, Predicted=[0], Target=[1]
# Epoch 10050: Loss=0.8283, Predicted=[1], Target=[1]
# Epoch 10100: Loss=1.1741, Predicted=[2], Target=[0]
# Epoch 10150: Loss=0.9393, Predicted=[0], Target=[0]
# Epoch 10200: Loss=1.0727, Predicted=[0], Target=[1]
# Epoch 10250: Loss=1.2930, Predicted=[0], Target=[2]
# Epoch 10300: Loss=1.1581, Predicted=[2], Target=[1]
# Epoch 10350: Loss=1.1188, Predicted=[2], Target=[1]
# Epoch 10400: Loss=1.2576, Predicted=[1], Target=[0]
# Epoch 10450: Loss=1.1241, Predicted=[2], Target=[0]
# Epoch 10500: Loss=1.0236, Predicted=[0], Target=[0]
# Epoch 10550: Loss=0.9349, Predicted=[0], Target=[0]
# Epoch 10600: Loss=1.1104, Predicted=[0], Target=[1]
# Epoch 10650: Loss=0.9362, Predicted=[0], Target=[0]
# Epoch 10700: Loss=1.2288, Predicted=[2], Target=[1]
# Epoch 10750: Loss=1.2202, Predicted=[2], Target=[1]
# Epoch 10800: Loss=1.0145, Predicted=[2], Target=[2]
# Epoch 10850: Loss=0.4430, Predicted=[1], Target=[1]
# Epoch 10900: Loss=1.1670, Predicted=[0], Target=[2]
# Epoch 10950: Loss=1.0081, Predicted=[2], Target=[0]
# Epoch 11000: Loss=1.0604, Predicted=[1], Target=[1]
# Epoch 11050: Loss=1.1639, Predicted=[2], Target=[0]
# Epoch 11100: Loss=1.0112, Predicted=[0], Target=[0]
# Epoch 11150: Loss=1.1580, Predicted=[0], Target=[2]
# Epoch 11200: Loss=1.2856, Predicted=[0], Target=[1]
# Epoch 11250: Loss=1.1858, Predicted=[2], Target=[0]
# Epoch 11300: Loss=0.9093, Predicted=[2], Target=[2]
# Epoch 11350: Loss=1.3516, Predicted=[1], Target=[2]
# Epoch 11400: Loss=1.0770, Predicted=[2], Target=[2]
# Epoch 11450: Loss=1.0505, Predicted=[0], Target=[1]
# Epoch 11500: Loss=1.1213, Predicted=[1], Target=[0]
# Epoch 11550: Loss=1.1227, Predicted=[0], Target=[1]
# Epoch 11600: Loss=1.1151, Predicted=[1], Target=[0]
# Epoch 11650: Loss=1.0250, Predicted=[0], Target=[0]
# Epoch 11700: Loss=1.2375, Predicted=[0], Target=[2]
# Epoch 11750: Loss=1.0586, Predicted=[0], Target=[1]
# Epoch 11800: Loss=1.0043, Predicted=[1], Target=[1]
# Epoch 11850: Loss=0.9674, Predicted=[1], Target=[1]
# Epoch 11900: Loss=1.2413, Predicted=[1], Target=[0]
# Epoch 11950: Loss=1.0964, Predicted=[0], Target=[2]
# Epoch 12000: Loss=1.1393, Predicted=[2], Target=[1]
# Epoch 12050: Loss=1.2195, Predicted=[1], Target=[0]
# Epoch 12100: Loss=1.2154, Predicted=[1], Target=[0]
# Epoch 12150: Loss=1.0313, Predicted=[1], Target=[2]
# Epoch 12200: Loss=1.1024, Predicted=[2], Target=[0]
# Epoch 12250: Loss=1.1031, Predicted=[2], Target=[1]
# Epoch 12300: Loss=1.5435, Predicted=[2], Target=[0]
# Epoch 12350: Loss=1.0700, Predicted=[2], Target=[2]
# Epoch 12400: Loss=0.9977, Predicted=[1], Target=[2]
# Epoch 12450: Loss=1.1396, Predicted=[2], Target=[0]
# Epoch 12500: Loss=1.0452, Predicted=[1], Target=[1]
# Epoch 12550: Loss=1.1355, Predicted=[1], Target=[0]
# Epoch 12600: Loss=1.1024, Predicted=[1], Target=[0]
# Epoch 12650: Loss=1.1031, Predicted=[0], Target=[2]
# Epoch 12700: Loss=0.8947, Predicted=[0], Target=[0]
# Epoch 12750: Loss=1.0126, Predicted=[0], Target=[0]
# Epoch 12800: Loss=0.9095, Predicted=[0], Target=[0]
# Epoch 12850: Loss=1.3127, Predicted=[2], Target=[0]
# Epoch 12900: Loss=1.2017, Predicted=[1], Target=[2]
# Epoch 12950: Loss=1.1255, Predicted=[1], Target=[2]
# Epoch 13000: Loss=1.3089, Predicted=[2], Target=[1]
# Epoch 13050: Loss=1.0326, Predicted=[0], Target=[0]
# Epoch 13100: Loss=1.0705, Predicted=[2], Target=[1]
# Epoch 13150: Loss=1.3633, Predicted=[1], Target=[2]
# Epoch 13200: Loss=1.0636, Predicted=[1], Target=[2]
# Epoch 13250: Loss=1.0878, Predicted=[2], Target=[0]
# Epoch 13300: Loss=1.1447, Predicted=[0], Target=[2]
# Epoch 13350: Loss=1.0746, Predicted=[0], Target=[2]
# Epoch 13400: Loss=1.0129, Predicted=[0], Target=[0]
# Epoch 13450: Loss=1.0713, Predicted=[1], Target=[1]
# Epoch 13500: Loss=1.0530, Predicted=[2], Target=[2]
# Epoch 13550: Loss=1.0838, Predicted=[1], Target=[2]
# Epoch 13600: Loss=1.1476, Predicted=[2], Target=[1]
# Epoch 13650: Loss=1.0829, Predicted=[2], Target=[1]
# Epoch 13700: Loss=1.5231, Predicted=[1], Target=[2]
# Epoch 13750: Loss=1.3887, Predicted=[0], Target=[1]
# Epoch 13800: Loss=1.0963, Predicted=[2], Target=[0]
# Epoch 13850: Loss=1.1461, Predicted=[0], Target=[1]
# Epoch 13900: Loss=0.9887, Predicted=[2], Target=[2]
# Epoch 13950: Loss=1.2075, Predicted=[2], Target=[0]
# Epoch 14000: Loss=1.5913, Predicted=[2], Target=[0]
# Epoch 14050: Loss=1.1069, Predicted=[2], Target=[0]
# Epoch 14100: Loss=1.1844, Predicted=[2], Target=[1]
# Epoch 14150: Loss=1.2312, Predicted=[2], Target=[0]
# Epoch 14200: Loss=1.0527, Predicted=[2], Target=[1]
# Epoch 14250: Loss=1.0988, Predicted=[2], Target=[1]
# Epoch 14300: Loss=1.2078, Predicted=[1], Target=[0]
# Epoch 14350: Loss=1.2475, Predicted=[2], Target=[0]
# Epoch 14400: Loss=1.0293, Predicted=[1], Target=[1]
# Epoch 14450: Loss=1.0284, Predicted=[2], Target=[2]
# Epoch 14500: Loss=1.1128, Predicted=[2], Target=[1]
# Epoch 14550: Loss=1.1659, Predicted=[2], Target=[0]
# Epoch 14600: Loss=1.0823, Predicted=[1], Target=[2]
# Epoch 14650: Loss=1.0376, Predicted=[1], Target=[1]
# Epoch 14700: Loss=1.0773, Predicted=[1], Target=[2]
# Epoch 14750: Loss=1.0138, Predicted=[2], Target=[2]
# Epoch 14800: Loss=1.0468, Predicted=[2], Target=[2]
# Epoch 14850: Loss=1.0633, Predicted=[2], Target=[2]
# Epoch 14900: Loss=0.9036, Predicted=[1], Target=[1]
# Epoch 14950: Loss=1.2761, Predicted=[1], Target=[0]
# Epoch 15000: Loss=1.0053, Predicted=[2], Target=[2]
# Epoch 15050: Loss=0.9494, Predicted=[2], Target=[2]
# Epoch 15100: Loss=0.9899, Predicted=[2], Target=[2]
# Epoch 15150: Loss=1.1930, Predicted=[2], Target=[1]
# Epoch 15200: Loss=0.7629, Predicted=[0], Target=[0]
# Epoch 15250: Loss=1.8764, Predicted=[1], Target=[0]
# Epoch 15300: Loss=1.0716, Predicted=[1], Target=[2]
# Epoch 15350: Loss=1.3837, Predicted=[1], Target=[0]
# Epoch 15400: Loss=1.4907, Predicted=[2], Target=[0]
# Epoch 15450: Loss=1.2368, Predicted=[2], Target=[1]
# Epoch 15500: Loss=0.9683, Predicted=[1], Target=[0]
# Epoch 15550: Loss=1.0926, Predicted=[0], Target=[1]
# Epoch 15600: Loss=1.5573, Predicted=[1], Target=[0]
# Epoch 15650: Loss=1.0117, Predicted=[1], Target=[2]
# Epoch 15700: Loss=1.0835, Predicted=[1], Target=[2]
# Epoch 15750: Loss=1.3352, Predicted=[1], Target=[0]
# Epoch 15800: Loss=1.1486, Predicted=[0], Target=[1]
# Epoch 15850: Loss=1.2139, Predicted=[2], Target=[0]
# Epoch 15900: Loss=0.6965, Predicted=[2], Target=[2]
# Epoch 15950: Loss=0.7632, Predicted=[2], Target=[2]
# Epoch 16000: Loss=1.4253, Predicted=[1], Target=[0]
# Epoch 16050: Loss=1.1433, Predicted=[1], Target=[2]
# Epoch 16100: Loss=0.8526, Predicted=[0], Target=[0]
# Epoch 16150: Loss=0.9428, Predicted=[0], Target=[0]
# Epoch 16200: Loss=0.9044, Predicted=[2], Target=[2]
# Epoch 16250: Loss=1.1550, Predicted=[2], Target=[0]
# Epoch 16300: Loss=1.1775, Predicted=[0], Target=[2]
# Epoch 16350: Loss=1.1269, Predicted=[0], Target=[2]
# Epoch 16400: Loss=1.2832, Predicted=[1], Target=[0]
# Epoch 16450: Loss=1.2895, Predicted=[1], Target=[2]
# Epoch 16500: Loss=0.9729, Predicted=[1], Target=[1]
# Epoch 16550: Loss=0.8829, Predicted=[1], Target=[1]
# Epoch 16600: Loss=1.1909, Predicted=[1], Target=[2]
# Epoch 16650: Loss=1.0400, Predicted=[1], Target=[1]
# Epoch 16700: Loss=1.0389, Predicted=[1], Target=[1]
# Epoch 16750: Loss=1.1333, Predicted=[1], Target=[2]
# Epoch 16800: Loss=1.1567, Predicted=[2], Target=[1]
# Epoch 16850: Loss=1.0423, Predicted=[2], Target=[2]
# Epoch 16900: Loss=0.9883, Predicted=[2], Target=[2]
# Epoch 16950: Loss=1.0589, Predicted=[1], Target=[1]
# Epoch 17000: Loss=0.9189, Predicted=[2], Target=[2]
# Epoch 17050: Loss=2.6546, Predicted=[0], Target=[2]
# Epoch 17100: Loss=1.1055, Predicted=[2], Target=[1]
# Epoch 17150: Loss=1.0752, Predicted=[2], Target=[2]
# Epoch 17200: Loss=1.0492, Predicted=[0], Target=[2]
# Epoch 17250: Loss=1.0332, Predicted=[0], Target=[0]
# Epoch 17300: Loss=1.0842, Predicted=[1], Target=[0]
# Epoch 17350: Loss=1.2070, Predicted=[1], Target=[0]
# Epoch 17400: Loss=1.1529, Predicted=[0], Target=[1]
# Epoch 17450: Loss=1.2005, Predicted=[0], Target=[1]
# Epoch 17500: Loss=1.1332, Predicted=[2], Target=[0]
# Epoch 17550: Loss=0.9716, Predicted=[2], Target=[2]
# Epoch 17600: Loss=1.1382, Predicted=[2], Target=[0]
# Epoch 17650: Loss=1.2495, Predicted=[2], Target=[0]
# Epoch 17700: Loss=1.2110, Predicted=[1], Target=[0]
# Epoch 17750: Loss=1.2645, Predicted=[2], Target=[0]
# Epoch 17800: Loss=1.1839, Predicted=[0], Target=[1]
# Epoch 17850: Loss=1.0381, Predicted=[0], Target=[0]
# Epoch 17900: Loss=1.1371, Predicted=[0], Target=[2]
# Epoch 17950: Loss=0.9302, Predicted=[0], Target=[0]
# Epoch 18000: Loss=1.1503, Predicted=[0], Target=[1]
# Epoch 18050: Loss=1.2307, Predicted=[0], Target=[1]
# Epoch 18100: Loss=1.0684, Predicted=[0], Target=[0]
# Epoch 18150: Loss=1.0677, Predicted=[0], Target=[0]
# Epoch 18200: Loss=1.0993, Predicted=[2], Target=[0]
# Epoch 18250: Loss=1.1464, Predicted=[0], Target=[1]
# Epoch 18300: Loss=1.1891, Predicted=[2], Target=[0]
# Epoch 18350: Loss=1.0874, Predicted=[1], Target=[2]
# Epoch 18400: Loss=1.2583, Predicted=[1], Target=[2]
# Epoch 18450: Loss=1.1396, Predicted=[1], Target=[2]
# Epoch 18500: Loss=1.1238, Predicted=[1], Target=[2]
# Epoch 18550: Loss=1.1207, Predicted=[1], Target=[0]
# Epoch 18600: Loss=1.1346, Predicted=[0], Target=[1]
# Epoch 18650: Loss=1.1054, Predicted=[1], Target=[0]
# Epoch 18700: Loss=1.1037, Predicted=[1], Target=[0]
# Epoch 18750: Loss=1.0956, Predicted=[2], Target=[0]
# Epoch 18800: Loss=1.1473, Predicted=[2], Target=[0]
# Epoch 18850: Loss=1.1176, Predicted=[2], Target=[1]
# Epoch 18900: Loss=1.0077, Predicted=[0], Target=[0]
# Epoch 18950: Loss=1.2927, Predicted=[0], Target=[2]
# Epoch 19000: Loss=1.2721, Predicted=[0], Target=[1]
# Epoch 19050: Loss=1.2045, Predicted=[1], Target=[2]
# Epoch 19100: Loss=0.9330, Predicted=[1], Target=[1]
# Epoch 19150: Loss=0.9608, Predicted=[1], Target=[1]
# Epoch 19200: Loss=0.9876, Predicted=[1], Target=[1]
# Epoch 19250: Loss=1.2358, Predicted=[1], Target=[0]
# Epoch 19300: Loss=1.0340, Predicted=[1], Target=[1]
# Epoch 19350: Loss=0.8903, Predicted=[1], Target=[1]
# Epoch 19400: Loss=0.9047, Predicted=[1], Target=[1]
# Epoch 19450: Loss=1.3517, Predicted=[1], Target=[0]
# Epoch 19500: Loss=1.1661, Predicted=[1], Target=[2]
# Epoch 19550: Loss=0.9937, Predicted=[1], Target=[1]
# Epoch 19600: Loss=1.0138, Predicted=[0], Target=[0]
# Epoch 19650: Loss=1.0521, Predicted=[1], Target=[0]
# Epoch 19700: Loss=1.1297, Predicted=[0], Target=[2]
# Epoch 19750: Loss=1.1554, Predicted=[0], Target=[1]
# Epoch 19800: Loss=1.1658, Predicted=[0], Target=[2]
# Epoch 19850: Loss=1.1500, Predicted=[0], Target=[2]
# Epoch 19900: Loss=1.1587, Predicted=[1], Target=[2]
# Epoch 19950: Loss=0.8691, Predicted=[1], Target=[1]
# Epoch 20000: Loss=1.0625, Predicted=[2], Target=[2]
# Epoch 20050: Loss=1.1328, Predicted=[1], Target=[2]
# Epoch 20100: Loss=1.0710, Predicted=[1], Target=[0]
# Epoch 20150: Loss=1.1637, Predicted=[0], Target=[1]
# Epoch 20200: Loss=0.8490, Predicted=[2], Target=[2]
# Epoch 20250: Loss=1.0412, Predicted=[2], Target=[2]
# Epoch 20300: Loss=0.5706, Predicted=[2], Target=[2]
# Epoch 20350: Loss=0.8640, Predicted=[2], Target=[2]
# Epoch 20400: Loss=1.0447, Predicted=[1], Target=[0]
# Epoch 20450: Loss=1.1459, Predicted=[0], Target=[2]
# Epoch 20500: Loss=1.2384, Predicted=[0], Target=[1]
# Epoch 20550: Loss=1.0675, Predicted=[1], Target=[2]
# Epoch 20600: Loss=1.1772, Predicted=[0], Target=[1]
# Epoch 20650: Loss=1.0764, Predicted=[2], Target=[1]
# Epoch 20700: Loss=1.1849, Predicted=[1], Target=[2]
# Epoch 20750: Loss=1.0693, Predicted=[1], Target=[0]
# Epoch 20800: Loss=0.6879, Predicted=[0], Target=[0]
# Epoch 20850: Loss=1.1262, Predicted=[1], Target=[0]
# Epoch 20900: Loss=1.2189, Predicted=[1], Target=[2]
# Epoch 20950: Loss=1.2338, Predicted=[0], Target=[1]
# Epoch 21000: Loss=0.9393, Predicted=[0], Target=[0]
# Epoch 21050: Loss=0.7836, Predicted=[1], Target=[1]
# Epoch 21100: Loss=1.1889, Predicted=[1], Target=[0]
# Epoch 21150: Loss=1.2157, Predicted=[1], Target=[2]
# Epoch 21200: Loss=0.2687, Predicted=[2], Target=[2]
# Epoch 21250: Loss=1.3829, Predicted=[2], Target=[0]
# Epoch 21300: Loss=1.6972, Predicted=[0], Target=[2]
# Epoch 21350: Loss=1.3715, Predicted=[0], Target=[1]
# Epoch 21400: Loss=0.9202, Predicted=[2], Target=[2]
# Epoch 21450: Loss=1.0647, Predicted=[0], Target=[0]
# Epoch 21500: Loss=1.1388, Predicted=[1], Target=[2]
# Epoch 21550: Loss=1.0542, Predicted=[1], Target=[1]
# Epoch 21600: Loss=1.1477, Predicted=[2], Target=[1]
# Epoch 21650: Loss=0.9764, Predicted=[2], Target=[2]
# Epoch 21700: Loss=1.1924, Predicted=[2], Target=[0]
# Epoch 21750: Loss=1.2721, Predicted=[0], Target=[1]
# Epoch 21800: Loss=1.4225, Predicted=[2], Target=[1]
# Epoch 21850: Loss=1.0927, Predicted=[2], Target=[2]
# Epoch 21900: Loss=1.1151, Predicted=[0], Target=[1]
# Epoch 21950: Loss=1.1143, Predicted=[0], Target=[1]
# Epoch 22000: Loss=0.9947, Predicted=[2], Target=[2]
# Epoch 22050: Loss=1.1542, Predicted=[0], Target=[1]
# Epoch 22100: Loss=1.2678, Predicted=[2], Target=[0]
# Epoch 22150: Loss=1.1464, Predicted=[2], Target=[0]
# Epoch 22200: Loss=1.0777, Predicted=[0], Target=[0]
# Epoch 22250: Loss=1.1533, Predicted=[2], Target=[1]
# Epoch 22300: Loss=0.9846, Predicted=[2], Target=[2]
# Epoch 22350: Loss=1.2322, Predicted=[1], Target=[0]
# Epoch 22400: Loss=1.0372, Predicted=[1], Target=[1]
# Epoch 22450: Loss=1.0280, Predicted=[1], Target=[1]
# Epoch 22500: Loss=1.1982, Predicted=[1], Target=[2]
# Epoch 22550: Loss=1.3297, Predicted=[2], Target=[0]
# Epoch 22600: Loss=1.2650, Predicted=[2], Target=[0]
# Epoch 22650: Loss=0.6173, Predicted=[0], Target=[0]
# Epoch 22700: Loss=1.0620, Predicted=[1], Target=[1]
# Epoch 22750: Loss=1.0084, Predicted=[1], Target=[1]
# Epoch 22800: Loss=1.0462, Predicted=[2], Target=[2]
# Epoch 22850: Loss=1.1238, Predicted=[2], Target=[1]
# Epoch 22900: Loss=1.1389, Predicted=[0], Target=[2]
# Epoch 22950: Loss=0.9915, Predicted=[2], Target=[2]
# Epoch 23000: Loss=1.2057, Predicted=[2], Target=[0]
# Epoch 23050: Loss=1.0957, Predicted=[1], Target=[2]
# Epoch 23100: Loss=1.0958, Predicted=[0], Target=[2]
# Epoch 23150: Loss=1.1114, Predicted=[2], Target=[0]
# Epoch 23200: Loss=1.1455, Predicted=[1], Target=[2]
# Epoch 23250: Loss=1.1023, Predicted=[1], Target=[2]
# Epoch 23300: Loss=1.1985, Predicted=[1], Target=[2]
# Epoch 23350: Loss=1.2655, Predicted=[0], Target=[2]
# Epoch 23400: Loss=1.1539, Predicted=[1], Target=[0]
# Epoch 23450: Loss=1.1537, Predicted=[0], Target=[1]
# Epoch 23500: Loss=1.0844, Predicted=[1], Target=[2]
# Epoch 23550: Loss=0.9835, Predicted=[2], Target=[2]
# Epoch 23600: Loss=1.1761, Predicted=[2], Target=[0]
# Epoch 23650: Loss=1.2863, Predicted=[2], Target=[1]
# Epoch 23700: Loss=0.9903, Predicted=[2], Target=[2]
# Epoch 23750: Loss=0.9714, Predicted=[0], Target=[1]
# Epoch 23800: Loss=1.1958, Predicted=[1], Target=[0]
# Epoch 23850: Loss=1.1216, Predicted=[2], Target=[0]
# Epoch 23900: Loss=0.9719, Predicted=[0], Target=[0]
# Epoch 23950: Loss=1.0946, Predicted=[0], Target=[2]
# Epoch 24000: Loss=1.1239, Predicted=[0], Target=[1]
# Epoch 24050: Loss=1.0908, Predicted=[1], Target=[1]
# Epoch 24100: Loss=1.3681, Predicted=[0], Target=[2]
# Epoch 24150: Loss=1.0840, Predicted=[1], Target=[0]
# Epoch 24200: Loss=1.1007, Predicted=[0], Target=[2]
# Epoch 24250: Loss=1.0193, Predicted=[0], Target=[1]
# Epoch 24300: Loss=1.1866, Predicted=[0], Target=[2]
# Epoch 24350: Loss=0.9373, Predicted=[2], Target=[1]
# Epoch 24400: Loss=1.0760, Predicted=[1], Target=[2]
# Epoch 24450: Loss=0.9731, Predicted=[2], Target=[2]
# Epoch 24500: Loss=0.9765, Predicted=[0], Target=[0]
# Epoch 24550: Loss=1.0770, Predicted=[0], Target=[0]
# Epoch 24600: Loss=1.2593, Predicted=[0], Target=[1]
# Epoch 24650: Loss=1.0291, Predicted=[0], Target=[0]
# Epoch 24700: Loss=1.0221, Predicted=[2], Target=[2]
# Epoch 24750: Loss=1.0951, Predicted=[1], Target=[2]
# Epoch 24800: Loss=1.1120, Predicted=[2], Target=[1]
# Epoch 24850: Loss=1.0935, Predicted=[1], Target=[2]
# Epoch 24900: Loss=1.1282, Predicted=[0], Target=[2]
# Epoch 24950: Loss=1.1880, Predicted=[0], Target=[2]
# Epoch 25000: Loss=1.5173, Predicted=[0], Target=[1]
# Epoch 25050: Loss=1.3324, Predicted=[1], Target=[2]
# Epoch 25100: Loss=0.9868, Predicted=[1], Target=[1]
# Epoch 25150: Loss=1.2636, Predicted=[0], Target=[2]
# Epoch 25200: Loss=1.2315, Predicted=[1], Target=[2]
# Epoch 25250: Loss=1.0423, Predicted=[1], Target=[1]
# Epoch 25300: Loss=1.1000, Predicted=[1], Target=[0]
# Epoch 25350: Loss=1.3213, Predicted=[1], Target=[2]
# Epoch 25400: Loss=1.0496, Predicted=[0], Target=[1]
# Epoch 25450: Loss=1.0234, Predicted=[1], Target=[1]
# Epoch 25500: Loss=0.9485, Predicted=[1], Target=[1]
# Epoch 25550: Loss=1.1585, Predicted=[0], Target=[1]
# Epoch 25600: Loss=1.1824, Predicted=[0], Target=[2]
# Epoch 25650: Loss=0.8953, Predicted=[1], Target=[1]
# Epoch 25700: Loss=1.0033, Predicted=[0], Target=[0]
# Epoch 25750: Loss=1.1342, Predicted=[0], Target=[1]
# Epoch 25800: Loss=1.4333, Predicted=[2], Target=[0]
# Epoch 25850: Loss=1.1319, Predicted=[1], Target=[2]
# Epoch 25900: Loss=1.1497, Predicted=[1], Target=[0]
# Epoch 25950: Loss=0.9642, Predicted=[1], Target=[1]
# Epoch 26000: Loss=1.4646, Predicted=[0], Target=[2]
# Epoch 26050: Loss=1.7632, Predicted=[1], Target=[0]
# Epoch 26100: Loss=0.2106, Predicted=[2], Target=[2]
# Epoch 26150: Loss=1.3984, Predicted=[2], Target=[0]
# Epoch 26200: Loss=0.8766, Predicted=[1], Target=[1]
# Epoch 26250: Loss=0.9955, Predicted=[1], Target=[1]
# Epoch 26300: Loss=1.8969, Predicted=[2], Target=[1]
# Epoch 26350: Loss=0.9390, Predicted=[2], Target=[2]
# Epoch 26400: Loss=0.7621, Predicted=[0], Target=[0]
# Epoch 26450: Loss=1.0097, Predicted=[2], Target=[2]
# Epoch 26500: Loss=1.1866, Predicted=[1], Target=[0]
# Epoch 26550: Loss=0.8838, Predicted=[2], Target=[2]
# Epoch 26600: Loss=1.1273, Predicted=[1], Target=[0]
# Epoch 26650: Loss=0.6899, Predicted=[2], Target=[2]
# Epoch 26700: Loss=1.3172, Predicted=[2], Target=[1]
# Epoch 26750: Loss=0.7242, Predicted=[1], Target=[1]
# Epoch 26800: Loss=1.1188, Predicted=[2], Target=[0]
# Epoch 26850: Loss=1.0619, Predicted=[2], Target=[2]
# Epoch 26900: Loss=1.2627, Predicted=[2], Target=[1]
# Epoch 26950: Loss=1.1076, Predicted=[0], Target=[2]
# Epoch 27000: Loss=1.1040, Predicted=[2], Target=[0]
# Epoch 27050: Loss=1.1203, Predicted=[0], Target=[2]
# Epoch 27100: Loss=1.3021, Predicted=[1], Target=[0]
# Epoch 27150: Loss=1.0629, Predicted=[2], Target=[0]
# Epoch 27200: Loss=1.0437, Predicted=[0], Target=[2]
# Epoch 27250: Loss=1.0731, Predicted=[2], Target=[0]
# Epoch 27300: Loss=1.0761, Predicted=[2], Target=[0]
# Epoch 27350: Loss=1.0590, Predicted=[2], Target=[0]
# Epoch 27400: Loss=1.1103, Predicted=[1], Target=[0]
# Epoch 27450: Loss=1.1965, Predicted=[2], Target=[1]
# Epoch 27500: Loss=1.1244, Predicted=[1], Target=[2]
# Epoch 27550: Loss=1.2595, Predicted=[2], Target=[1]
# Epoch 27600: Loss=1.1121, Predicted=[0], Target=[2]
# Epoch 27650: Loss=1.1508, Predicted=[2], Target=[1]
# Epoch 27700: Loss=0.6443, Predicted=[0], Target=[0]
# Epoch 27750: Loss=1.0875, Predicted=[0], Target=[2]
# Epoch 27800: Loss=0.9334, Predicted=[2], Target=[2]
# Epoch 27850: Loss=0.9323, Predicted=[1], Target=[1]
# Epoch 27900: Loss=1.4043, Predicted=[0], Target=[1]
# Epoch 27950: Loss=1.0494, Predicted=[2], Target=[0]
# Epoch 28000: Loss=0.9443, Predicted=[0], Target=[0]
# Epoch 28050: Loss=0.6741, Predicted=[2], Target=[2]
# Epoch 28100: Loss=1.1863, Predicted=[2], Target=[1]
# Epoch 28150: Loss=1.4673, Predicted=[2], Target=[1]
# Epoch 28200: Loss=1.1733, Predicted=[2], Target=[1]
# Epoch 28250: Loss=1.3715, Predicted=[1], Target=[2]
# Epoch 28300: Loss=1.1666, Predicted=[2], Target=[1]
# Epoch 28350: Loss=0.8985, Predicted=[2], Target=[2]
# Epoch 28400: Loss=1.3938, Predicted=[1], Target=[0]
# Epoch 28450: Loss=1.1960, Predicted=[1], Target=[0]
# Epoch 28500: Loss=1.1116, Predicted=[0], Target=[2]
# Epoch 28550: Loss=1.3180, Predicted=[0], Target=[2]
# Epoch 28600: Loss=1.0653, Predicted=[1], Target=[0]
# Epoch 28650: Loss=0.9836, Predicted=[1], Target=[0]
# Epoch 28700: Loss=0.7652, Predicted=[0], Target=[0]
# Epoch 28750: Loss=1.1114, Predicted=[2], Target=[0]
# Epoch 28800: Loss=0.9473, Predicted=[1], Target=[1]
# Epoch 28850: Loss=1.0193, Predicted=[1], Target=[1]
# Epoch 28900: Loss=1.1069, Predicted=[0], Target=[1]
# Epoch 28950: Loss=1.2868, Predicted=[1], Target=[2]
# Epoch 29000: Loss=1.0578, Predicted=[0], Target=[1]
# Epoch 29050: Loss=1.0206, Predicted=[0], Target=[0]
# Epoch 29100: Loss=1.0097, Predicted=[1], Target=[1]
# Epoch 29150: Loss=1.2254, Predicted=[1], Target=[2]
# Epoch 29200: Loss=1.0127, Predicted=[0], Target=[0]
# Epoch 29250: Loss=0.9907, Predicted=[0], Target=[0]
# Epoch 29300: Loss=1.2993, Predicted=[1], Target=[2]
# Epoch 29350: Loss=1.0358, Predicted=[0], Target=[0]
# Epoch 29400: Loss=1.2250, Predicted=[1], Target=[2]
# Epoch 29450: Loss=1.0856, Predicted=[2], Target=[0]
# Epoch 29500: Loss=1.1612, Predicted=[0], Target=[1]
# Epoch 29550: Loss=0.9126, Predicted=[0], Target=[0]
# Epoch 29600: Loss=0.9524, Predicted=[0], Target=[0]
# Epoch 29650: Loss=1.1653, Predicted=[1], Target=[2]
# Epoch 29700: Loss=1.2108, Predicted=[0], Target=[2]
# Epoch 29750: Loss=1.0726, Predicted=[1], Target=[2]
# Epoch 29800: Loss=1.2916, Predicted=[1], Target=[0]
# Epoch 29850: Loss=1.1084, Predicted=[1], Target=[2]
# Epoch 29900: Loss=1.0576, Predicted=[2], Target=[2]
# Epoch 29950: Loss=1.1016, Predicted=[0], Target=[1]
# Epoch 30000: Loss=1.1146, Predicted=[0], Target=[1]
# Epoch 30050: Loss=1.0050, Predicted=[0], Target=[0]
# Epoch 30100: Loss=1.1365, Predicted=[2], Target=[1]
# Epoch 30150: Loss=1.1286, Predicted=[0], Target=[2]
# Epoch 30200: Loss=1.0982, Predicted=[0], Target=[2]
# Epoch 30250: Loss=1.1012, Predicted=[0], Target=[2]
# Epoch 30300: Loss=1.1143, Predicted=[2], Target=[1]
# Epoch 30350: Loss=1.3356, Predicted=[2], Target=[1]
# Epoch 30400: Loss=1.0959, Predicted=[2], Target=[1]
# Epoch 30450: Loss=0.9448, Predicted=[0], Target=[0]
# Epoch 30500: Loss=1.1863, Predicted=[1], Target=[0]
# Epoch 30550: Loss=0.9822, Predicted=[2], Target=[2]
# Epoch 30600: Loss=1.1097, Predicted=[0], Target=[2]
# Epoch 30650: Loss=0.9342, Predicted=[1], Target=[1]
# Epoch 30700: Loss=1.1504, Predicted=[1], Target=[0]
# Epoch 30750: Loss=1.0674, Predicted=[0], Target=[1]
# Epoch 30800: Loss=1.1302, Predicted=[1], Target=[0]
# Epoch 30850: Loss=1.1762, Predicted=[2], Target=[0]
# Epoch 30900: Loss=0.9597, Predicted=[2], Target=[2]
# Epoch 30950: Loss=1.3631, Predicted=[2], Target=[1]
# Epoch 31000: Loss=1.2333, Predicted=[2], Target=[1]
# Epoch 31050: Loss=0.8174, Predicted=[2], Target=[2]
# Epoch 31100: Loss=1.3667, Predicted=[1], Target=[2]
# Epoch 31150: Loss=1.5664, Predicted=[2], Target=[1]
# Epoch 31200: Loss=0.8285, Predicted=[2], Target=[2]
# Epoch 31250: Loss=1.0186, Predicted=[2], Target=[2]
# Epoch 31300: Loss=1.2210, Predicted=[0], Target=[2]
# Epoch 31350: Loss=1.1681, Predicted=[0], Target=[2]
# Epoch 31400: Loss=0.7619, Predicted=[1], Target=[1]
# Epoch 31450: Loss=1.2332, Predicted=[2], Target=[1]
# Epoch 31500: Loss=1.0438, Predicted=[0], Target=[0]
# Epoch 31550: Loss=1.1892, Predicted=[0], Target=[2]
# Epoch 31600: Loss=1.0311, Predicted=[0], Target=[0]
# Epoch 31650: Loss=1.2047, Predicted=[0], Target=[2]
# Epoch 31700: Loss=0.9046, Predicted=[0], Target=[0]
# Epoch 31750: Loss=1.0739, Predicted=[2], Target=[0]
# Epoch 31800: Loss=1.1033, Predicted=[2], Target=[0]
# Epoch 31850: Loss=0.9063, Predicted=[0], Target=[0]
# Epoch 31900: Loss=1.2187, Predicted=[0], Target=[1]
# Epoch 31950: Loss=1.1543, Predicted=[0], Target=[2]
# Epoch 32000: Loss=1.0362, Predicted=[1], Target=[1]
# Epoch 32050: Loss=1.0641, Predicted=[1], Target=[1]
# Epoch 32100: Loss=1.1671, Predicted=[1], Target=[2]
# Epoch 32150: Loss=1.1184, Predicted=[1], Target=[0]
# Epoch 32200: Loss=1.1558, Predicted=[1], Target=[0]
# Epoch 32250: Loss=1.0134, Predicted=[0], Target=[0]
# Epoch 32300: Loss=1.1408, Predicted=[0], Target=[1]
# Epoch 32350: Loss=1.0868, Predicted=[1], Target=[0]
# Epoch 32400: Loss=1.0073, Predicted=[0], Target=[0]
# Epoch 32450: Loss=1.2503, Predicted=[0], Target=[1]
# Epoch 32500: Loss=1.7179, Predicted=[0], Target=[1]
# Epoch 32550: Loss=1.1151, Predicted=[0], Target=[2]
# Epoch 32600: Loss=1.1181, Predicted=[0], Target=[1]
# Epoch 32650: Loss=1.1408, Predicted=[0], Target=[1]
# Epoch 32700: Loss=1.0152, Predicted=[2], Target=[2]
# Epoch 32750: Loss=1.0881, Predicted=[2], Target=[2]
# Epoch 32800: Loss=1.1286, Predicted=[2], Target=[0]
# Epoch 32850: Loss=1.4967, Predicted=[0], Target=[1]
# Epoch 32900: Loss=1.1170, Predicted=[0], Target=[1]
# Epoch 32950: Loss=1.0338, Predicted=[0], Target=[0]
# Epoch 33000: Loss=1.1469, Predicted=[2], Target=[1]
# Epoch 33050: Loss=1.1001, Predicted=[1], Target=[2]
# Epoch 33100: Loss=1.1959, Predicted=[0], Target=[2]
# Epoch 33150: Loss=1.0462, Predicted=[2], Target=[2]
# Epoch 33200: Loss=1.3037, Predicted=[2], Target=[0]
# Epoch 33250: Loss=1.1221, Predicted=[2], Target=[0]
# Epoch 33300: Loss=1.1082, Predicted=[0], Target=[2]
# Epoch 33350: Loss=1.1140, Predicted=[1], Target=[2]
# Epoch 33400: Loss=1.1105, Predicted=[1], Target=[2]
# Epoch 33450: Loss=1.0331, Predicted=[1], Target=[1]
# Epoch 33500: Loss=1.1167, Predicted=[1], Target=[2]
# Epoch 33550: Loss=1.0456, Predicted=[2], Target=[2]
# Epoch 33600: Loss=1.1390, Predicted=[2], Target=[1]
# Epoch 33650: Loss=1.1637, Predicted=[1], Target=[0]
# Epoch 33700: Loss=1.1284, Predicted=[1], Target=[0]
# Epoch 33750: Loss=1.1635, Predicted=[1], Target=[2]
# Epoch 33800: Loss=1.3421, Predicted=[2], Target=[1]
# Epoch 33850: Loss=1.0585, Predicted=[2], Target=[2]
# Epoch 33900: Loss=1.0954, Predicted=[2], Target=[0]
# Epoch 33950: Loss=1.1417, Predicted=[2], Target=[1]
# Epoch 34000: Loss=1.0678, Predicted=[2], Target=[1]
# Epoch 34050: Loss=0.9772, Predicted=[2], Target=[2]
# Epoch 34100: Loss=0.7367, Predicted=[2], Target=[2]
# Epoch 34150: Loss=1.6444, Predicted=[1], Target=[2]
# Epoch 34200: Loss=1.0552, Predicted=[1], Target=[2]
# Epoch 34250: Loss=1.1985, Predicted=[2], Target=[1]
# Epoch 34300: Loss=1.1908, Predicted=[2], Target=[1]
# Epoch 34350: Loss=1.0847, Predicted=[1], Target=[1]
# Epoch 34400: Loss=1.2344, Predicted=[2], Target=[1]
# Epoch 34450: Loss=1.0516, Predicted=[1], Target=[1]
# Epoch 34500: Loss=1.0962, Predicted=[1], Target=[2]
# Epoch 34550: Loss=1.0667, Predicted=[2], Target=[2]
# Epoch 34600: Loss=0.9295, Predicted=[2], Target=[2]
# Epoch 34650: Loss=1.0192, Predicted=[1], Target=[1]
# Epoch 34700: Loss=1.0315, Predicted=[1], Target=[0]
# Epoch 34750: Loss=1.1844, Predicted=[1], Target=[2]
# Epoch 34800: Loss=0.8524, Predicted=[1], Target=[1]
# Epoch 34850: Loss=1.0869, Predicted=[1], Target=[2]
# Epoch 34900: Loss=1.1112, Predicted=[0], Target=[2]
# Epoch 34950: Loss=1.2049, Predicted=[0], Target=[1]
# Epoch 35000: Loss=1.2243, Predicted=[0], Target=[1]
# Epoch 35050: Loss=1.1245, Predicted=[2], Target=[0]
# Epoch 35100: Loss=1.1556, Predicted=[0], Target=[1]
# Epoch 35150: Loss=1.2321, Predicted=[0], Target=[2]
# Epoch 35200: Loss=0.9440, Predicted=[0], Target=[1]
# Epoch 35250: Loss=1.1029, Predicted=[0], Target=[2]
# Epoch 35300: Loss=1.0897, Predicted=[2], Target=[0]
# Epoch 35350: Loss=1.1414, Predicted=[1], Target=[0]
# Epoch 35400: Loss=1.1806, Predicted=[1], Target=[2]
# Epoch 35450: Loss=1.2225, Predicted=[1], Target=[2]
# Epoch 35500: Loss=0.9818, Predicted=[1], Target=[1]
# Epoch 35550: Loss=0.9711, Predicted=[1], Target=[1]
# Epoch 35600: Loss=1.1627, Predicted=[1], Target=[2]
# Epoch 35650: Loss=0.8191, Predicted=[1], Target=[1]
# Epoch 35700: Loss=0.9048, Predicted=[1], Target=[1]
# Epoch 35750: Loss=1.2262, Predicted=[1], Target=[2]
# Epoch 35800: Loss=1.3686, Predicted=[1], Target=[0]
# Epoch 35850: Loss=0.9093, Predicted=[1], Target=[1]
# Epoch 35900: Loss=0.8944, Predicted=[1], Target=[1]
# Epoch 35950: Loss=1.0225, Predicted=[1], Target=[1]
# Epoch 36000: Loss=1.0573, Predicted=[2], Target=[2]
# Epoch 36050: Loss=1.0923, Predicted=[0], Target=[2]
# Epoch 36100: Loss=1.1408, Predicted=[2], Target=[0]
# Epoch 36150: Loss=1.0379, Predicted=[0], Target=[0]
# Epoch 36200: Loss=1.1396, Predicted=[2], Target=[1]
# Epoch 36250: Loss=1.0007, Predicted=[0], Target=[0]
# Epoch 36300: Loss=1.1366, Predicted=[0], Target=[2]
# Epoch 36350: Loss=1.1015, Predicted=[1], Target=[2]
# Epoch 36400: Loss=1.1534, Predicted=[0], Target=[2]
# Epoch 36450: Loss=0.6609, Predicted=[0], Target=[0]
# Epoch 36500: Loss=1.2208, Predicted=[0], Target=[1]
# Epoch 36550: Loss=0.4621, Predicted=[1], Target=[1]
# Epoch 36600: Loss=0.9208, Predicted=[0], Target=[2]
# Epoch 36650: Loss=2.1672, Predicted=[1], Target=[0]
# Epoch 36700: Loss=1.4372, Predicted=[2], Target=[1]
# Epoch 36750: Loss=0.7355, Predicted=[1], Target=[1]
# Epoch 36800: Loss=1.0075, Predicted=[0], Target=[0]
# Epoch 36850: Loss=1.0471, Predicted=[2], Target=[0]
# Epoch 36900: Loss=1.2977, Predicted=[0], Target=[2]
# Epoch 36950: Loss=1.0202, Predicted=[0], Target=[0]
# Epoch 37000: Loss=0.9730, Predicted=[0], Target=[0]
# Epoch 37050: Loss=1.0573, Predicted=[2], Target=[2]
# Epoch 37100: Loss=1.0214, Predicted=[1], Target=[2]
# Epoch 37150: Loss=1.1678, Predicted=[2], Target=[1]
# Epoch 37200: Loss=1.0812, Predicted=[2], Target=[1]
# Epoch 37250: Loss=1.0749, Predicted=[2], Target=[1]
# Epoch 37300: Loss=1.2143, Predicted=[2], Target=[0]
# Epoch 37350: Loss=1.1730, Predicted=[0], Target=[2]
# Epoch 37400: Loss=1.2594, Predicted=[1], Target=[2]
# Epoch 37450: Loss=1.1178, Predicted=[1], Target=[2]
# Epoch 37500: Loss=1.1473, Predicted=[2], Target=[1]
# Epoch 37550: Loss=1.1778, Predicted=[2], Target=[0]
# Epoch 37600: Loss=1.0681, Predicted=[0], Target=[0]
# Epoch 37650: Loss=1.1338, Predicted=[2], Target=[1]
# Epoch 37700: Loss=1.0098, Predicted=[0], Target=[0]
# Epoch 37750: Loss=1.1481, Predicted=[0], Target=[1]
# Epoch 37800: Loss=0.7440, Predicted=[0], Target=[0]
# Epoch 37850: Loss=1.2425, Predicted=[2], Target=[1]
# Epoch 37900: Loss=0.8342, Predicted=[2], Target=[2]
# Epoch 37950: Loss=1.2696, Predicted=[2], Target=[1]
# Epoch 38000: Loss=1.2881, Predicted=[2], Target=[0]
# Epoch 38050: Loss=1.0688, Predicted=[0], Target=[1]
# Epoch 38100: Loss=1.0926, Predicted=[0], Target=[1]
# Epoch 38150: Loss=1.1928, Predicted=[1], Target=[0]
# Epoch 38200: Loss=1.0442, Predicted=[0], Target=[1]
# Epoch 38250: Loss=1.2853, Predicted=[1], Target=[0]
# Epoch 38300: Loss=1.0821, Predicted=[1], Target=[0]
# Epoch 38350: Loss=1.1453, Predicted=[0], Target=[1]
# Epoch 38400: Loss=1.0892, Predicted=[1], Target=[0]
# Epoch 38450: Loss=1.2553, Predicted=[2], Target=[0]
# Epoch 38500: Loss=0.8557, Predicted=[1], Target=[1]
# Epoch 38550: Loss=0.6921, Predicted=[1], Target=[1]
# Epoch 38600: Loss=1.2819, Predicted=[2], Target=[1]
# Epoch 38650: Loss=1.1500, Predicted=[1], Target=[0]
# Epoch 38700: Loss=1.0455, Predicted=[2], Target=[2]
# Epoch 38750: Loss=0.8241, Predicted=[2], Target=[2]
# Epoch 38800: Loss=1.3149, Predicted=[0], Target=[1]
# Epoch 38850: Loss=1.2484, Predicted=[1], Target=[0]
# Epoch 38900: Loss=1.2111, Predicted=[1], Target=[2]
# Epoch 38950: Loss=1.3754, Predicted=[2], Target=[0]
# Epoch 39000: Loss=1.2115, Predicted=[2], Target=[0]
# Epoch 39050: Loss=0.8891, Predicted=[0], Target=[0]
# Epoch 39100: Loss=0.9919, Predicted=[2], Target=[2]
# Epoch 39150: Loss=1.0777, Predicted=[0], Target=[1]
# Epoch 39200: Loss=0.9707, Predicted=[0], Target=[0]
# Epoch 39250: Loss=1.0593, Predicted=[1], Target=[1]
# Epoch 39300: Loss=1.0210, Predicted=[1], Target=[1]
# Epoch 39350: Loss=1.0297, Predicted=[0], Target=[0]
# Epoch 39400: Loss=1.3065, Predicted=[1], Target=[2]
# Epoch 39450: Loss=0.8930, Predicted=[1], Target=[1]
# Epoch 39500: Loss=1.1295, Predicted=[1], Target=[0]
# Epoch 39550: Loss=1.1442, Predicted=[0], Target=[2]
# Epoch 39600: Loss=1.0566, Predicted=[0], Target=[0]
# Epoch 39650: Loss=1.1299, Predicted=[0], Target=[2]
# Epoch 39700: Loss=1.0312, Predicted=[0], Target=[0]
# Epoch 39750: Loss=1.1692, Predicted=[0], Target=[1]
# Epoch 39800: Loss=0.9905, Predicted=[0], Target=[0]
# Epoch 39850: Loss=1.0420, Predicted=[2], Target=[0]
# Epoch 39900: Loss=1.1944, Predicted=[0], Target=[1]
# Epoch 39950: Loss=1.0972, Predicted=[0], Target=[1]
# Epoch 40000: Loss=1.0365, Predicted=[1], Target=[1]
# Epoch 40050: Loss=1.2156, Predicted=[1], Target=[0]
# Epoch 40100: Loss=1.0765, Predicted=[2], Target=[2]
# Epoch 40150: Loss=1.1345, Predicted=[2], Target=[0]
# Epoch 40200: Loss=1.2495, Predicted=[2], Target=[1]
# Epoch 40250: Loss=0.9278, Predicted=[2], Target=[2]
# Epoch 40300: Loss=1.0988, Predicted=[2], Target=[1]
# Epoch 40350: Loss=0.9937, Predicted=[2], Target=[2]
# Epoch 40400: Loss=0.9263, Predicted=[1], Target=[1]
# Epoch 40450: Loss=1.1963, Predicted=[2], Target=[0]
# Epoch 40500: Loss=1.1212, Predicted=[1], Target=[2]
# Epoch 40550: Loss=1.0646, Predicted=[1], Target=[1]
# Epoch 40600: Loss=1.2857, Predicted=[1], Target=[2]
# Epoch 40650: Loss=1.1331, Predicted=[2], Target=[1]
# Epoch 40700: Loss=1.1070, Predicted=[2], Target=[1]
# Epoch 40750: Loss=0.9813, Predicted=[1], Target=[1]
# Epoch 40800: Loss=1.0316, Predicted=[2], Target=[1]
# Epoch 40850: Loss=1.0727, Predicted=[1], Target=[2]
# Epoch 40900: Loss=1.3378, Predicted=[0], Target=[2]
# Epoch 40950: Loss=1.3933, Predicted=[2], Target=[0]
# Epoch 41000: Loss=1.0837, Predicted=[1], Target=[0]
# Epoch 41050: Loss=1.2240, Predicted=[1], Target=[2]
# Epoch 41100: Loss=0.8280, Predicted=[2], Target=[2]
# Epoch 41150: Loss=1.0048, Predicted=[0], Target=[0]
# Epoch 41200: Loss=1.0968, Predicted=[1], Target=[0]
# Epoch 41250: Loss=1.1168, Predicted=[0], Target=[2]
# Epoch 41300: Loss=1.1286, Predicted=[2], Target=[1]
# Epoch 41350: Loss=1.2347, Predicted=[2], Target=[0]
# Epoch 41400: Loss=1.1117, Predicted=[1], Target=[0]
# Epoch 41450: Loss=1.1808, Predicted=[0], Target=[2]
# Epoch 41500: Loss=1.1759, Predicted=[0], Target=[2]
# Epoch 41550: Loss=1.1130, Predicted=[0], Target=[1]
# Epoch 41600: Loss=0.9288, Predicted=[0], Target=[0]
# Epoch 41650: Loss=1.1514, Predicted=[1], Target=[2]
# Epoch 41700: Loss=1.1918, Predicted=[1], Target=[2]
# Epoch 41750: Loss=0.9554, Predicted=[0], Target=[2]
# Epoch 41800: Loss=1.0293, Predicted=[0], Target=[0]
# Epoch 41850: Loss=1.0386, Predicted=[0], Target=[0]
# Epoch 41900: Loss=1.1570, Predicted=[2], Target=[1]
# Epoch 41950: Loss=1.2535, Predicted=[0], Target=[2]
# Epoch 42000: Loss=0.9840, Predicted=[1], Target=[1]
# Epoch 42050: Loss=1.7743, Predicted=[1], Target=[2]
# Epoch 42100: Loss=1.4168, Predicted=[1], Target=[0]
# Epoch 42150: Loss=1.0271, Predicted=[1], Target=[0]
# Epoch 42200: Loss=1.5163, Predicted=[0], Target=[1]
# Epoch 42250: Loss=1.3344, Predicted=[1], Target=[2]
# Epoch 42300: Loss=1.0537, Predicted=[0], Target=[0]
# Epoch 42350: Loss=1.1466, Predicted=[2], Target=[1]
# Epoch 42400: Loss=0.9422, Predicted=[1], Target=[1]
# Epoch 42450: Loss=1.0192, Predicted=[1], Target=[1]
# Epoch 42500: Loss=1.2308, Predicted=[1], Target=[2]
# Epoch 42550: Loss=1.2042, Predicted=[1], Target=[0]
# Epoch 42600: Loss=1.2139, Predicted=[1], Target=[0]
# Epoch 42650: Loss=1.0885, Predicted=[1], Target=[2]
# Epoch 42700: Loss=1.2355, Predicted=[2], Target=[1]
# Epoch 42750: Loss=1.1374, Predicted=[2], Target=[0]
# Epoch 42800: Loss=1.1574, Predicted=[2], Target=[0]
# Epoch 42850: Loss=1.1625, Predicted=[2], Target=[1]
# Epoch 42900: Loss=1.1150, Predicted=[1], Target=[0]
# Epoch 42950: Loss=0.9966, Predicted=[0], Target=[0]
# Epoch 43000: Loss=1.1544, Predicted=[1], Target=[2]
# Epoch 43050: Loss=1.0231, Predicted=[0], Target=[0]
# Epoch 43100: Loss=0.9251, Predicted=[2], Target=[2]
# Epoch 43150: Loss=1.1004, Predicted=[0], Target=[2]
# Epoch 43200: Loss=1.0504, Predicted=[0], Target=[0]
# Epoch 43250: Loss=1.1839, Predicted=[2], Target=[1]
# Epoch 43300: Loss=1.0804, Predicted=[1], Target=[2]
# Epoch 43350: Loss=1.1300, Predicted=[0], Target=[1]
# Epoch 43400: Loss=1.1197, Predicted=[0], Target=[2]
# Epoch 43450: Loss=1.0855, Predicted=[2], Target=[2]
# Epoch 43500: Loss=1.1427, Predicted=[2], Target=[1]
# Epoch 43550: Loss=1.1798, Predicted=[2], Target=[1]
# Epoch 43600: Loss=1.2141, Predicted=[0], Target=[2]
# Epoch 43650: Loss=1.0802, Predicted=[0], Target=[2]
# Epoch 43700: Loss=1.0967, Predicted=[1], Target=[0]
# Epoch 43750: Loss=0.8820, Predicted=[2], Target=[2]
# Epoch 43800: Loss=0.9504, Predicted=[2], Target=[2]
# Epoch 43850: Loss=1.1702, Predicted=[1], Target=[0]
# Epoch 43900: Loss=0.7985, Predicted=[1], Target=[1]
# Epoch 43950: Loss=1.2272, Predicted=[0], Target=[1]
# Epoch 44000: Loss=1.2505, Predicted=[2], Target=[0]
# Epoch 44050: Loss=1.2894, Predicted=[1], Target=[2]
# Epoch 44100: Loss=0.6929, Predicted=[2], Target=[2]
# Epoch 44150: Loss=1.4720, Predicted=[2], Target=[1]
# Epoch 44200: Loss=1.1034, Predicted=[0], Target=[1]
# Epoch 44250: Loss=1.2047, Predicted=[2], Target=[0]
# Epoch 44300: Loss=1.0177, Predicted=[1], Target=[1]
# Epoch 44350: Loss=0.9970, Predicted=[1], Target=[1]
# Epoch 44400: Loss=1.1110, Predicted=[0], Target=[1]
# Epoch 44450: Loss=1.1000, Predicted=[1], Target=[0]
# Epoch 44500: Loss=1.1660, Predicted=[2], Target=[0]
# Epoch 44550: Loss=1.0677, Predicted=[2], Target=[2]
# Epoch 44600: Loss=1.0455, Predicted=[1], Target=[1]
# Epoch 44650: Loss=1.1408, Predicted=[2], Target=[0]
# Epoch 44700: Loss=1.1493, Predicted=[0], Target=[1]
# Epoch 44750: Loss=1.1420, Predicted=[0], Target=[1]
# Epoch 44800: Loss=1.0214, Predicted=[1], Target=[1]
# Epoch 44850: Loss=1.1787, Predicted=[2], Target=[0]
# Epoch 44900: Loss=1.0657, Predicted=[0], Target=[1]
# Epoch 44950: Loss=1.1607, Predicted=[0], Target=[2]
# Epoch 45000: Loss=1.1125, Predicted=[1], Target=[0]
# Epoch 45050: Loss=1.1736, Predicted=[1], Target=[0]
# Epoch 45100: Loss=1.0720, Predicted=[1], Target=[0]
# Epoch 45150: Loss=1.1394, Predicted=[1], Target=[0]
# Epoch 45200: Loss=0.9681, Predicted=[1], Target=[1]
# Epoch 45250: Loss=1.0453, Predicted=[1], Target=[1]
# Epoch 45300: Loss=1.5010, Predicted=[2], Target=[0]
# Epoch 45350: Loss=1.0268, Predicted=[0], Target=[0]
# Epoch 45400: Loss=1.1138, Predicted=[0], Target=[2]
# Epoch 45450: Loss=1.0726, Predicted=[1], Target=[2]
# Epoch 45500: Loss=1.1158, Predicted=[1], Target=[2]
# Epoch 45550: Loss=1.0982, Predicted=[1], Target=[2]
# Epoch 45600: Loss=1.1718, Predicted=[2], Target=[1]
# Epoch 45650: Loss=1.5171, Predicted=[2], Target=[0]
# Epoch 45700: Loss=0.8998, Predicted=[0], Target=[0]
# Epoch 45750: Loss=1.2755, Predicted=[0], Target=[2]
# Epoch 45800: Loss=1.0584, Predicted=[2], Target=[1]
# Epoch 45850: Loss=1.0694, Predicted=[2], Target=[1]
# Epoch 45900: Loss=0.9653, Predicted=[1], Target=[1]
# Epoch 45950: Loss=0.9808, Predicted=[1], Target=[1]
# Epoch 46000: Loss=1.1042, Predicted=[1], Target=[0]
# Epoch 46050: Loss=0.9013, Predicted=[1], Target=[1]
# Epoch 46100: Loss=0.9977, Predicted=[1], Target=[1]
# Epoch 46150: Loss=0.9662, Predicted=[2], Target=[1]
# Epoch 46200: Loss=1.0274, Predicted=[1], Target=[1]
# Epoch 46250: Loss=0.8892, Predicted=[1], Target=[1]
# Epoch 46300: Loss=1.8900, Predicted=[2], Target=[1]
# ...
# Epoch 84650: Loss=1.0760, Predicted=[1], Target=[0]
# Epoch 84700: Loss=1.1993, Predicted=[0], Target=[2]
# Epoch 84750: Loss=1.0988, Predicted=[0], Target=[2]
# Epoch 84800: Loss=1.1330, Predicted=[2], Target=[0]
# Epoch 84850: Loss=1.0560, Predicted=[2], Target=[2]
# Epoch 84900: Loss=1.1857, Predicted=[0], Target=[1]
# Epoch 84950: Loss=1.0826, Predicted=[2], Target=[0]
# Epoch 85000: Loss=1.1201, Predicted=[2], Target=[1]
# Epoch 85050: Loss=1.1932, Predicted=[2], Target=[0]
# Epoch 85100: Loss=1.1233, Predicted=[2], Target=[1]
# Epoch 85150: Loss=1.1218, Predicted=[1], Target=[2]
# Epoch 85200: Loss=1.0638, Predicted=[0], Target=[0]
# Epoch 85250: Loss=1.0744, Predicted=[2], Target=[2]
# Epoch 85300: Loss=1.0300, Predicted=[0], Target=[0]
# Epoch 85350: Loss=1.2202, Predicted=[1], Target=[2]
# Epoch 85400: Loss=1.0352, Predicted=[0], Target=[0]
# Epoch 85450: Loss=1.4647, Predicted=[2], Target=[0]
# Epoch 85500: Loss=1.1042, Predicted=[0], Target=[2]
# Epoch 85550: Loss=1.8848, Predicted=[0], Target=[1]
# Epoch 85600: Loss=1.0538, Predicted=[2], Target=[1]
# Epoch 85650: Loss=1.4905, Predicted=[1], Target=[0]
# Epoch 85700: Loss=1.1202, Predicted=[0], Target=[1]
# Epoch 85750: Loss=1.2082, Predicted=[0], Target=[2]
# Epoch 85800: Loss=0.7502, Predicted=[2], Target=[2]
# Epoch 85850: Loss=1.0065, Predicted=[0], Target=[1]
# Epoch 85900: Loss=1.0813, Predicted=[2], Target=[2]
# Epoch 85950: Loss=1.3905, Predicted=[0], Target=[2]
# Epoch 86000: Loss=1.0776, Predicted=[1], Target=[2]
# Epoch 86050: Loss=1.1832, Predicted=[0], Target=[1]
# Epoch 86100: Loss=1.2633, Predicted=[0], Target=[1]
# Epoch 86150: Loss=1.1113, Predicted=[1], Target=[2]
# Epoch 86200: Loss=1.2094, Predicted=[0], Target=[1]
# Epoch 86250: Loss=1.2789, Predicted=[0], Target=[2]
# Epoch 86300: Loss=1.1643, Predicted=[0], Target=[2]
# Epoch 86350: Loss=1.2938, Predicted=[0], Target=[1]
# Epoch 86400: Loss=1.0324, Predicted=[0], Target=[0]
# Epoch 86450: Loss=0.9583, Predicted=[0], Target=[0]
# Epoch 86500: Loss=1.1660, Predicted=[0], Target=[1]
# Epoch 86550: Loss=1.0831, Predicted=[2], Target=[1]
# Epoch 86600: Loss=1.0903, Predicted=[0], Target=[2]
# Epoch 86650: Loss=1.1423, Predicted=[0], Target=[2]
# Epoch 86700: Loss=0.9729, Predicted=[0], Target=[0]
# Epoch 86750: Loss=1.1954, Predicted=[0], Target=[1]
# Epoch 86800: Loss=1.1632, Predicted=[2], Target=[1]
# Epoch 86850: Loss=1.1545, Predicted=[2], Target=[0]
# Epoch 86900: Loss=0.9625, Predicted=[2], Target=[2]
# Epoch 86950: Loss=0.9988, Predicted=[0], Target=[0]
# Epoch 87000: Loss=0.9974, Predicted=[1], Target=[2]
# Epoch 87050: Loss=1.0718, Predicted=[2], Target=[1]
# Epoch 87100: Loss=1.0404, Predicted=[0], Target=[0]
# Epoch 87150: Loss=1.1380, Predicted=[0], Target=[1]
# Epoch 87200: Loss=1.1257, Predicted=[1], Target=[2]
# Epoch 87250: Loss=1.0035, Predicted=[0], Target=[0]
# Epoch 87300: Loss=0.8508, Predicted=[0], Target=[0]
# Epoch 87350: Loss=0.9725, Predicted=[0], Target=[0]
# Epoch 87400: Loss=1.0312, Predicted=[0], Target=[0]
# Epoch 87450: Loss=1.0435, Predicted=[0], Target=[2]
# Epoch 87500: Loss=1.1835, Predicted=[0], Target=[1]
# Epoch 87550: Loss=1.3650, Predicted=[1], Target=[2]
# Epoch 87600: Loss=1.1955, Predicted=[2], Target=[1]
# Epoch 87650: Loss=0.9040, Predicted=[1], Target=[1]
# Epoch 87700: Loss=1.1468, Predicted=[1], Target=[0]
# Epoch 87750: Loss=1.5835, Predicted=[2], Target=[0]
# Epoch 87800: Loss=1.2168, Predicted=[2], Target=[0]
# Epoch 87850: Loss=1.1261, Predicted=[2], Target=[1]
# Epoch 87900: Loss=1.4951, Predicted=[2], Target=[0]
# Epoch 87950: Loss=1.1170, Predicted=[1], Target=[0]
# Epoch 88000: Loss=1.0513, Predicted=[1], Target=[1]
# Epoch 88050: Loss=1.2151, Predicted=[0], Target=[2]
# Epoch 88100: Loss=1.1384, Predicted=[1], Target=[0]
# Epoch 88150: Loss=1.4648, Predicted=[0], Target=[1]
# Epoch 88200: Loss=1.3513, Predicted=[1], Target=[0]
# Epoch 88250: Loss=0.9214, Predicted=[2], Target=[2]
# Epoch 88300: Loss=0.9334, Predicted=[2], Target=[2]
# Epoch 88350: Loss=0.9615, Predicted=[2], Target=[2]
# Epoch 88400: Loss=1.1916, Predicted=[2], Target=[1]
# Epoch 88450: Loss=0.9765, Predicted=[2], Target=[2]
# Epoch 88500: Loss=1.1176, Predicted=[2], Target=[0]
# Epoch 88550: Loss=1.0960, Predicted=[2], Target=[0]
# Epoch 88600: Loss=1.2086, Predicted=[0], Target=[2]
# Epoch 88650: Loss=1.1723, Predicted=[2], Target=[1]
# Epoch 88700: Loss=1.1040, Predicted=[2], Target=[1]
# Epoch 88750: Loss=1.0928, Predicted=[2], Target=[1]
# Epoch 88800: Loss=1.1152, Predicted=[1], Target=[2]
# Epoch 88850: Loss=1.3355, Predicted=[1], Target=[2]
# Epoch 88900: Loss=1.0290, Predicted=[2], Target=[2]
# Epoch 88950: Loss=1.2351, Predicted=[0], Target=[2]
# Epoch 89000: Loss=1.0923, Predicted=[0], Target=[1]
# Epoch 89050: Loss=0.8670, Predicted=[1], Target=[1]
# Epoch 89100: Loss=0.6113, Predicted=[1], Target=[1]
# Epoch 89150: Loss=1.1070, Predicted=[2], Target=[0]
# Epoch 89200: Loss=1.4003, Predicted=[2], Target=[1]
# Epoch 89250: Loss=1.0000, Predicted=[0], Target=[0]
# Epoch 89300: Loss=0.9025, Predicted=[1], Target=[1]
# Epoch 89350: Loss=1.2096, Predicted=[1], Target=[2]
# Epoch 89400: Loss=1.0441, Predicted=[0], Target=[0]
# Epoch 89450: Loss=1.2198, Predicted=[1], Target=[0]
# Epoch 89500: Loss=1.2216, Predicted=[0], Target=[1]
# Epoch 89550: Loss=1.1683, Predicted=[1], Target=[0]
# Epoch 89600: Loss=1.1685, Predicted=[1], Target=[0]
# Epoch 89650: Loss=1.1705, Predicted=[1], Target=[0]
# Epoch 89700: Loss=1.0455, Predicted=[1], Target=[1]
# Epoch 89750: Loss=1.1237, Predicted=[2], Target=[1]
# Epoch 89800: Loss=1.0713, Predicted=[1], Target=[1]
# Epoch 89850: Loss=1.1570, Predicted=[2], Target=[0]
# Epoch 89900: Loss=1.1013, Predicted=[1], Target=[2]
# Epoch 89950: Loss=1.0843, Predicted=[1], Target=[1]
# Epoch 90000: Loss=1.1660, Predicted=[0], Target=[2]
# Epoch 90050: Loss=1.1243, Predicted=[0], Target=[1]
# Epoch 90100: Loss=1.0478, Predicted=[0], Target=[0]
# Epoch 90150: Loss=1.1083, Predicted=[1], Target=[0]
# Epoch 90200: Loss=1.0127, Predicted=[1], Target=[1]
# Epoch 90250: Loss=1.1992, Predicted=[1], Target=[2]
# Epoch 90300: Loss=1.1855, Predicted=[1], Target=[0]
# Epoch 90350: Loss=1.1632, Predicted=[1], Target=[2]
# Epoch 90400: Loss=1.0478, Predicted=[1], Target=[1]
# Epoch 90450: Loss=1.1523, Predicted=[1], Target=[2]
# Epoch 90500: Loss=1.1176, Predicted=[0], Target=[2]
# Epoch 90550: Loss=1.0548, Predicted=[0], Target=[0]
# Epoch 90600: Loss=1.1348, Predicted=[1], Target=[2]
# Epoch 90650: Loss=1.0533, Predicted=[0], Target=[0]
# Epoch 90700: Loss=1.1199, Predicted=[0], Target=[1]
# Epoch 90750: Loss=1.0970, Predicted=[0], Target=[1]
# Epoch 90800: Loss=1.0086, Predicted=[1], Target=[1]
# Epoch 90850: Loss=1.1010, Predicted=[1], Target=[2]
# Epoch 90900: Loss=1.1894, Predicted=[1], Target=[2]
# Epoch 90950: Loss=1.1065, Predicted=[1], Target=[2]
# Epoch 91000: Loss=1.0143, Predicted=[2], Target=[0]
# Epoch 91050: Loss=1.8007, Predicted=[2], Target=[0]
# Epoch 91100: Loss=1.1579, Predicted=[1], Target=[2]
# Epoch 91150: Loss=1.0587, Predicted=[2], Target=[2]
# Epoch 91200: Loss=1.1814, Predicted=[1], Target=[2]
# Epoch 91250: Loss=0.9202, Predicted=[0], Target=[2]
# Epoch 91300: Loss=1.1121, Predicted=[1], Target=[2]
# Epoch 91350: Loss=1.0143, Predicted=[2], Target=[2]
# Epoch 91400: Loss=1.1906, Predicted=[2], Target=[0]
# Epoch 91450: Loss=1.1013, Predicted=[2], Target=[0]
# Epoch 91500: Loss=1.0278, Predicted=[2], Target=[2]
# Epoch 91550: Loss=1.1982, Predicted=[2], Target=[1]
# Epoch 91600: Loss=1.1012, Predicted=[0], Target=[2]
# Epoch 91650: Loss=1.0641, Predicted=[2], Target=[0]
# Epoch 91700: Loss=1.0658, Predicted=[0], Target=[2]
# Epoch 91750: Loss=1.0228, Predicted=[0], Target=[0]
# Epoch 91800: Loss=1.6490, Predicted=[1], Target=[0]
# Epoch 91850: Loss=0.9773, Predicted=[2], Target=[1]
# Epoch 91900: Loss=0.7037, Predicted=[1], Target=[1]
# Epoch 91950: Loss=1.2880, Predicted=[0], Target=[1]
# Epoch 92000: Loss=1.9184, Predicted=[1], Target=[2]
# Epoch 92050: Loss=1.4799, Predicted=[0], Target=[1]
# Epoch 92100: Loss=1.5976, Predicted=[2], Target=[1]
# Epoch 92150: Loss=1.2423, Predicted=[2], Target=[1]
# Epoch 92200: Loss=1.1099, Predicted=[0], Target=[2]
# Epoch 92250: Loss=1.1461, Predicted=[2], Target=[1]
# Epoch 92300: Loss=0.8837, Predicted=[2], Target=[2]
# Epoch 92350: Loss=1.4256, Predicted=[1], Target=[2]
# Epoch 92400: Loss=0.8706, Predicted=[2], Target=[2]
# Epoch 92450: Loss=1.4087, Predicted=[2], Target=[1]
# Epoch 92500: Loss=1.3756, Predicted=[1], Target=[0]
# Epoch 92550: Loss=0.7366, Predicted=[1], Target=[1]
# Epoch 92600: Loss=0.9961, Predicted=[2], Target=[2]
# Epoch 92650: Loss=1.0430, Predicted=[1], Target=[2]
# Epoch 92700: Loss=1.1157, Predicted=[2], Target=[0]
# Epoch 92750: Loss=1.1030, Predicted=[0], Target=[2]
# Epoch 92800: Loss=1.1804, Predicted=[1], Target=[2]
# Epoch 92850: Loss=1.2608, Predicted=[2], Target=[0]
# Epoch 92900: Loss=1.3665, Predicted=[0], Target=[1]
# Epoch 92950: Loss=1.1200, Predicted=[2], Target=[0]
# Epoch 93000: Loss=1.0160, Predicted=[0], Target=[0]
# Epoch 93050: Loss=1.1286, Predicted=[2], Target=[0]
# Epoch 93100: Loss=1.0060, Predicted=[2], Target=[2]
# Epoch 93150: Loss=1.0277, Predicted=[2], Target=[2]
# Epoch 93200: Loss=1.0625, Predicted=[2], Target=[0]
# Epoch 93250: Loss=1.0736, Predicted=[0], Target=[2]
# Epoch 93300: Loss=1.0813, Predicted=[2], Target=[0]
# Epoch 93350: Loss=1.1293, Predicted=[2], Target=[1]
# Epoch 93400: Loss=1.0999, Predicted=[1], Target=[2]
# Epoch 93450: Loss=1.0788, Predicted=[2], Target=[1]
# Epoch 93500: Loss=1.0699, Predicted=[1], Target=[1]
# Epoch 93550: Loss=1.0891, Predicted=[2], Target=[2]
# Epoch 93600: Loss=1.0898, Predicted=[1], Target=[2]
# Epoch 93650: Loss=1.1995, Predicted=[2], Target=[0]
# Epoch 93700: Loss=1.0012, Predicted=[2], Target=[2]
# Epoch 93750: Loss=1.0100, Predicted=[2], Target=[2]
# Epoch 93800: Loss=1.1491, Predicted=[2], Target=[0]
# Epoch 93850: Loss=1.0654, Predicted=[1], Target=[1]
# Epoch 93900: Loss=0.9597, Predicted=[1], Target=[1]
# Epoch 93950: Loss=1.2037, Predicted=[1], Target=[2]
# Epoch 94000: Loss=1.2461, Predicted=[1], Target=[0]
# Epoch 94050: Loss=1.0439, Predicted=[0], Target=[0]
# Epoch 94100: Loss=0.9677, Predicted=[1], Target=[1]
# Epoch 94150: Loss=1.0411, Predicted=[0], Target=[0]
# Epoch 94200: Loss=1.0920, Predicted=[1], Target=[0]
# Epoch 94250: Loss=1.1224, Predicted=[2], Target=[0]
# Epoch 94300: Loss=0.9757, Predicted=[1], Target=[1]
# Epoch 94350: Loss=1.0697, Predicted=[1], Target=[2]
# Epoch 94400: Loss=1.2587, Predicted=[2], Target=[1]
# Epoch 94450: Loss=1.0777, Predicted=[1], Target=[2]
# Epoch 94500: Loss=1.0921, Predicted=[2], Target=[0]
# Epoch 94550: Loss=1.3172, Predicted=[0], Target=[1]
# Epoch 94600: Loss=1.3475, Predicted=[0], Target=[1]
# Epoch 94650: Loss=0.9560, Predicted=[0], Target=[0]
# Epoch 94700: Loss=1.6028, Predicted=[2], Target=[1]
# Epoch 94750: Loss=1.2201, Predicted=[0], Target=[2]
# Epoch 94800: Loss=1.1775, Predicted=[0], Target=[1]
# Epoch 94850: Loss=0.9979, Predicted=[1], Target=[0]
# Epoch 94900: Loss=0.9304, Predicted=[0], Target=[0]
# Epoch 94950: Loss=1.0530, Predicted=[1], Target=[1]
# Epoch 95000: Loss=0.3521, Predicted=[2], Target=[2]
# Epoch 95050: Loss=1.3898, Predicted=[2], Target=[1]
# Epoch 95100: Loss=1.2068, Predicted=[0], Target=[1]
# Epoch 95150: Loss=0.9672, Predicted=[2], Target=[2]
# Epoch 95200: Loss=1.0480, Predicted=[2], Target=[0]
# Epoch 95250: Loss=0.8707, Predicted=[1], Target=[1]
# Epoch 95300: Loss=1.0641, Predicted=[2], Target=[2]
# Epoch 95350: Loss=0.9829, Predicted=[2], Target=[2]
# Epoch 95400: Loss=0.9454, Predicted=[0], Target=[0]
# Epoch 95450: Loss=1.1809, Predicted=[0], Target=[1]
# Epoch 95500: Loss=1.1721, Predicted=[1], Target=[0]
# Epoch 95550: Loss=0.9988, Predicted=[1], Target=[1]
# Epoch 95600: Loss=0.9357, Predicted=[2], Target=[2]
# Epoch 95650: Loss=1.1916, Predicted=[0], Target=[2]
# Epoch 95700: Loss=0.9814, Predicted=[0], Target=[2]
# Epoch 95750: Loss=1.4880, Predicted=[2], Target=[1]
# Epoch 95800: Loss=0.9891, Predicted=[2], Target=[2]
# Epoch 95850: Loss=1.1734, Predicted=[1], Target=[2]
# Epoch 95900: Loss=1.0650, Predicted=[0], Target=[2]
# Epoch 95950: Loss=1.0125, Predicted=[0], Target=[0]
# Epoch 96000: Loss=1.1799, Predicted=[1], Target=[0]
# Epoch 96050: Loss=0.9374, Predicted=[0], Target=[0]
# Epoch 96100: Loss=1.0535, Predicted=[1], Target=[1]
# Epoch 96150: Loss=1.1577, Predicted=[2], Target=[1]
# Epoch 96200: Loss=1.1563, Predicted=[0], Target=[2]
# Epoch 96250: Loss=1.5915, Predicted=[0], Target=[2]
# Epoch 96300: Loss=1.1092, Predicted=[0], Target=[2]
# Epoch 96350: Loss=1.0542, Predicted=[0], Target=[0]
# Epoch 96400: Loss=1.1095, Predicted=[0], Target=[2]
# Epoch 96450: Loss=0.9731, Predicted=[0], Target=[0]
# Epoch 96500: Loss=1.7903, Predicted=[1], Target=[0]
# Epoch 96550: Loss=1.0671, Predicted=[1], Target=[0]
# Epoch 96600: Loss=1.3534, Predicted=[2], Target=[1]
# Epoch 96650: Loss=0.9902, Predicted=[1], Target=[1]
# Epoch 96700: Loss=1.0949, Predicted=[0], Target=[1]
# Epoch 96750: Loss=1.0493, Predicted=[1], Target=[1]
# Epoch 96800: Loss=1.0872, Predicted=[0], Target=[0]
# Epoch 96850: Loss=1.1584, Predicted=[0], Target=[2]
# Epoch 96900: Loss=1.0834, Predicted=[1], Target=[1]
# Epoch 96950: Loss=1.1643, Predicted=[0], Target=[1]
# Epoch 97000: Loss=1.2894, Predicted=[1], Target=[2]
# Epoch 97050: Loss=1.0893, Predicted=[2], Target=[0]
# Epoch 97100: Loss=1.1334, Predicted=[2], Target=[1]
# Epoch 97150: Loss=1.3843, Predicted=[2], Target=[0]
# Epoch 97200: Loss=1.1178, Predicted=[2], Target=[1]
# Epoch 97250: Loss=0.9984, Predicted=[1], Target=[0]
# Epoch 97300: Loss=1.1753, Predicted=[1], Target=[0]
# Epoch 97350: Loss=0.6208, Predicted=[0], Target=[0]
# Epoch 97400: Loss=1.1910, Predicted=[2], Target=[1]
# Epoch 97450: Loss=1.2892, Predicted=[1], Target=[0]
# Epoch 97500: Loss=0.9650, Predicted=[0], Target=[0]
# Epoch 97550: Loss=1.1352, Predicted=[0], Target=[2]
# Epoch 97600: Loss=1.1044, Predicted=[1], Target=[2]
# Epoch 97650: Loss=1.0734, Predicted=[1], Target=[1]
# Epoch 97700: Loss=1.1234, Predicted=[1], Target=[2]
# Epoch 97750: Loss=1.1392, Predicted=[1], Target=[2]
# Epoch 97800: Loss=1.0574, Predicted=[0], Target=[2]
# Epoch 97850: Loss=1.0332, Predicted=[2], Target=[0]
# Epoch 97900: Loss=1.0858, Predicted=[2], Target=[0]
# Epoch 97950: Loss=0.8702, Predicted=[0], Target=[0]
# Epoch 98000: Loss=1.3028, Predicted=[0], Target=[1]
# Epoch 98050: Loss=1.5698, Predicted=[0], Target=[1]
# Epoch 98100: Loss=1.1702, Predicted=[0], Target=[2]
# Epoch 98150: Loss=1.0541, Predicted=[2], Target=[0]
# Epoch 98200: Loss=1.0767, Predicted=[0], Target=[1]
# Epoch 98250: Loss=1.2049, Predicted=[2], Target=[0]
# Epoch 98300: Loss=1.1120, Predicted=[0], Target=[1]
# Epoch 98350: Loss=1.1245, Predicted=[0], Target=[1]
# Epoch 98400: Loss=1.1602, Predicted=[0], Target=[2]
# Epoch 98450: Loss=0.9664, Predicted=[2], Target=[2]
# Epoch 98500: Loss=1.3438, Predicted=[0], Target=[1]
# Epoch 98550: Loss=1.0227, Predicted=[0], Target=[0]
# Epoch 98600: Loss=1.3149, Predicted=[0], Target=[1]
# Epoch 98650: Loss=1.0608, Predicted=[2], Target=[0]
# Epoch 98700: Loss=1.4250, Predicted=[2], Target=[0]
# Epoch 98750: Loss=1.0050, Predicted=[2], Target=[2]
# Epoch 98800: Loss=0.7810, Predicted=[0], Target=[0]
# Epoch 98850: Loss=1.2968, Predicted=[2], Target=[0]
# Epoch 98900: Loss=1.1435, Predicted=[2], Target=[0]
# Epoch 98950: Loss=1.0960, Predicted=[0], Target=[2]
# Epoch 99000: Loss=1.0690, Predicted=[0], Target=[2]
# Epoch 99050: Loss=0.9325, Predicted=[0], Target=[0]
# Epoch 99100: Loss=0.9992, Predicted=[1], Target=[1]
# Epoch 99150: Loss=1.0489, Predicted=[2], Target=[0]
# Epoch 99200: Loss=1.1466, Predicted=[1], Target=[0]
# Epoch 99250: Loss=1.1405, Predicted=[0], Target=[1]
# Epoch 99300: Loss=0.9692, Predicted=[2], Target=[2]
# Epoch 99350: Loss=0.8767, Predicted=[2], Target=[2]
# Epoch 99400: Loss=1.0224, Predicted=[1], Target=[1]
# Epoch 99450: Loss=1.0169, Predicted=[2], Target=[2]
# Epoch 99500: Loss=1.2554, Predicted=[1], Target=[0]
# Epoch 99550: Loss=1.2981, Predicted=[2], Target=[0]
# Epoch 99600: Loss=1.1565, Predicted=[2], Target=[0]
# Epoch 99650: Loss=0.9364, Predicted=[2], Target=[2]
# Epoch 99700: Loss=0.9751, Predicted=[0], Target=[0]
# Epoch 99750: Loss=1.0513, Predicted=[1], Target=[2]
# Epoch 99800: Loss=0.9449, Predicted=[1], Target=[1]
# Epoch 99850: Loss=1.6321, Predicted=[0], Target=[2]
# Epoch 99900: Loss=0.8738, Predicted=[2], Target=[2]
# Epoch 99950: Loss=1.2815, Predicted=[2], Target=[0]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import itertools

# Step 1: Generate all 27 sequences
sequences = list(itertools.product(range(3), repeat=3))

# Step 2–3: Run through encoder and collect hidden states
hidden_codes = []
labels = []
model.eval()
with torch.no_grad():
    for seq in sequences:
        x = F.one_hot(torch.tensor(seq), num_classes=3).float().unsqueeze(0)  # (1, 3, 3)
        _, h = model.encoder(x)
        hidden_codes.append(h[0,0].numpy())  # extract (H,) from (1,1,H)
        labels.append("".join(map(str, seq)))

# Step 4: Reduce dimension
hidden_codes = torch.tensor(hidden_codes)
tsne = TSNE(n_components=2, perplexity=5, random_state=42)
embeddings = tsne.fit_transform(hidden_codes)

# Step 5: Plot
plt.figure(figsize=(10, 8))
for i, txt in enumerate(labels):
    plt.scatter(embeddings[i,0], embeddings[i,1], s=60)
    plt.text(embeddings[i,0]+0.1, embeddings[i,1]+0.1, txt, fontsize=10)
plt.title("t-SNE of Encoder Hidden States for All 27 Sequences")
plt.grid(True)
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random

# Hyperparameters
vocab_size = 3          # Tokens: 0,1,2 (for 1,2,3)
embedding_dim = 8
hidden_size = 40
seq_len = 3
batch_size = 1
num_epochs = 10000

# Model
class RNNEncoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_size, batch_first=True)
    
    def forward(self, x):
        embedded = self.embedding(x)
        out, h = self.rnn(embedded)
        return h  # Return final hidden state

class RNNDecoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, vocab_size)
    
    def forward(self, x, h):
        embedded = self.embedding(x)
        out, _ = self.rnn(embedded, h)
        return self.fc(out)  # shape: [batch, seq_len, vocab_size]

# Full Autoencoder
class RNNAutoencoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.encoder = RNNEncoder(vocab_size, embedding_dim, hidden_size)
        self.decoder = RNNDecoder(vocab_size, embedding_dim, hidden_size)
    
    def forward(self, x, decoder_input):
        h = self.encoder(x)
        output = self.decoder(decoder_input, h)
        return output

# Instantiate model
model = RNNAutoencoder(vocab_size, embedding_dim, hidden_size)
optimizer = optim.Adam(model.parameters(), lr=1e-2)
loss_fn = nn.CrossEntropyLoss()

# Training loop
for epoch in range(num_epochs):
    batch = []
    targets = []
    for _ in range(batch_size):
        seq = [random.randint(0, vocab_size - 1) for _ in range(seq_len)]
        batch.append(seq)
        targets.append(seq)

    x = torch.tensor(batch, dtype=torch.long)
    y_true = torch.tensor(targets, dtype=torch.long)

    # Shift decoder input by one (teacher forcing with <sos>=0)
    decoder_input = torch.cat([torch.zeros((batch_size, 1), dtype=torch.long), x[:, :-1]], dim=1)

    optimizer.zero_grad()
    y_pred = model(x, decoder_input)
    loss = loss_fn(y_pred.view(-1, vocab_size), y_true.view(-1))
    loss.backward()
    optimizer.step()

    if (epoch+1) % 50 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 50, Loss: 0.8921
# Epoch 100, Loss: 1.3255
# Epoch 150, Loss: 0.0721
# Epoch 200, Loss: 0.0077
# Epoch 250, Loss: 0.0046
# Epoch 300, Loss: 0.0025
# Epoch 350, Loss: 0.0048
# Epoch 400, Loss: 0.0015
# Epoch 450, Loss: 0.0018
# Epoch 500, Loss: 0.0024
# Epoch 550, Loss: 0.0011
# Epoch 600, Loss: 0.0017
# Epoch 650, Loss: 0.0011
# Epoch 700, Loss: 0.0006
# Epoch 750, Loss: 0.0010
# Epoch 800, Loss: 0.0005
# Epoch 850, Loss: 0.0004
# Epoch 900, Loss: 0.0005
# Epoch 950, Loss: 0.0004
# Epoch 1000, Loss: 0.0005
# Epoch 1050, Loss: 0.0003
# Epoch 1100, Loss: 0.0005
# Epoch 1150, Loss: 0.0003
# Epoch 1200, Loss: 0.0002
# Epoch 1250, Loss: 0.0002
# Epoch 1300, Loss: 0.0003
# Epoch 1350, Loss: 0.0003
# Epoch 1400, Loss: 0.0003
# Epoch 1450, Loss: 0.0004
# Epoch 1500, Loss: 0.0002
# Epoch 1550, Loss: 0.0002
# Epoch 1600, Loss: 0.0002
# Epoch 1650, Loss: 0.0001
# Epoch 1700, Loss: 0.0003
# Epoch 1750, Loss: 0.0002
# Epoch 1800, Loss: 0.0002
# Epoch 1850, Loss: 0.0001
# Epoch 1900, Loss: 0.0001
# Epoch 1950, Loss: 0.0001
# Epoch 2000, Loss: 0.0001
# Epoch 2050, Loss: 0.0001
# Epoch 2100, Loss: 0.0002
# Epoch 2150, Loss: 0.0001
# Epoch 2200, Loss: 0.0001
# Epoch 2250, Loss: 0.0001
# Epoch 2300, Loss: 0.0001
# Epoch 2350, Loss: 0.0001
# Epoch 2400, Loss: 0.0001
# Epoch 2450, Loss: 0.0001
# Epoch 2500, Loss: 0.0001
# Epoch 2550, Loss: 0.0001
# Epoch 2600, Loss: 0.0000
# Epoch 2650, Loss: 0.0001
# Epoch 2700, Loss: 0.0000
# Epoch 2750, Loss: 0.0001
# Epoch 2800, Loss: 0.0001
# Epoch 2850, Loss: 0.0000
# Epoch 2900, Loss: 0.0001
# Epoch 2950, Loss: 0.0001
# Epoch 3000, Loss: 0.0000
# Epoch 3050, Loss: 0.0001
# Epoch 3100, Loss: 0.0001
# Epoch 3150, Loss: 0.0000
# Epoch 3200, Loss: 0.0000
# Epoch 3250, Loss: 0.0000
# Epoch 3300, Loss: 0.0000
# Epoch 3350, Loss: 0.0000
# Epoch 3400, Loss: 0.0000
# Epoch 3450, Loss: 0.0000
# Epoch 3500, Loss: 0.0000
# Epoch 3550, Loss: 0.0000
# Epoch 3600, Loss: 0.0000
# Epoch 3650, Loss: 0.0000
# Epoch 3700, Loss: 0.0000
# Epoch 3750, Loss: 0.0000
# Epoch 3800, Loss: 0.0000
# Epoch 3850, Loss: 0.0000
# Epoch 3900, Loss: 0.0000
# Epoch 3950, Loss: 0.0000
# Epoch 4000, Loss: 0.0000
# Epoch 4050, Loss: 0.0000
# Epoch 4100, Loss: 0.0000
# Epoch 4150, Loss: 0.0000
# Epoch 4200, Loss: 0.0000
# Epoch 4250, Loss: 0.0000
# Epoch 4300, Loss: 0.0000
# Epoch 4350, Loss: 0.0000
# Epoch 4400, Loss: 0.0000
# Epoch 4450, Loss: 0.0000
# Epoch 4500, Loss: 0.0000
# Epoch 4550, Loss: 0.0000
# Epoch 4600, Loss: 0.0000
# Epoch 4650, Loss: 0.0000
# Epoch 4700, Loss: 0.0000
# Epoch 4750, Loss: 0.0000
# Epoch 4800, Loss: 0.0000
# Epoch 4850, Loss: 0.0000
# Epoch 4900, Loss: 0.0000
# Epoch 4950, Loss: 0.0000
# Epoch 5000, Loss: 0.0000
# Epoch 5050, Loss: 0.0000
# Epoch 5100, Loss: 0.0000
# Epoch 5150, Loss: 0.0000
# Epoch 5200, Loss: 0.0000
# Epoch 5250, Loss: 0.0000
# Epoch 5300, Loss: 0.0000
# Epoch 5350, Loss: 0.0000
# Epoch 5400, Loss: 0.0000
# Epoch 5450, Loss: 0.0000
# Epoch 5500, Loss: 0.0000
# Epoch 5550, Loss: 0.0000
# Epoch 5600, Loss: 0.0000
# Epoch 5650, Loss: 0.0000
# Epoch 5700, Loss: 0.0000
# Epoch 5750, Loss: 0.0000
# Epoch 5800, Loss: 0.0000
# Epoch 5850, Loss: 0.0000
# Epoch 5900, Loss: 0.0000
# Epoch 5950, Loss: 0.0000
# Epoch 6000, Loss: 0.0000
# Epoch 6050, Loss: 0.0000
# Epoch 6100, Loss: 0.0000
# Epoch 6150, Loss: 0.0000
# Epoch 6200, Loss: 0.0000
# Epoch 6250, Loss: 0.0000
# Epoch 6300, Loss: 0.0000
# Epoch 6350, Loss: 0.0000
# Epoch 6400, Loss: 0.0000
# Epoch 6450, Loss: 0.0000
# Epoch 6500, Loss: 0.0000
# Epoch 6550, Loss: 0.0000
# Epoch 6600, Loss: 0.0000
# Epoch 6650, Loss: 0.0000
# Epoch 6700, Loss: 0.0000
# Epoch 6750, Loss: 0.0000
# Epoch 6800, Loss: 0.0000
# Epoch 6850, Loss: 0.0000
# Epoch 6900, Loss: 0.0000
# Epoch 6950, Loss: 0.0000
# Epoch 7000, Loss: 0.0000
# Epoch 7050, Loss: 0.0000
# Epoch 7100, Loss: 0.0000
# Epoch 7150, Loss: 0.0000
# Epoch 7200, Loss: 0.0000
# Epoch 7250, Loss: 0.0000
# Epoch 7300, Loss: 0.0000
# Epoch 7350, Loss: 0.0000
# Epoch 7400, Loss: 0.0000
# Epoch 7450, Loss: 0.0000
# Epoch 7500, Loss: 0.0000
# Epoch 7550, Loss: 0.0000
# Epoch 7600, Loss: 0.0000
# Epoch 7650, Loss: 0.0000
# Epoch 7700, Loss: 0.0000
# Epoch 7750, Loss: 0.0000
# Epoch 7800, Loss: 0.0000
# Epoch 7850, Loss: 0.0000
# Epoch 7900, Loss: 0.0000
# Epoch 7950, Loss: 0.0000
# Epoch 8000, Loss: 0.0000
# Epoch 8050, Loss: 0.0000
# Epoch 8100, Loss: 0.0000
# Epoch 8150, Loss: 0.0000
# Epoch 8200, Loss: 0.0000
# Epoch 8250, Loss: 0.0000
# Epoch 8300, Loss: 0.0000
# Epoch 8350, Loss: 0.0000
# Epoch 8400, Loss: 0.0000
# Epoch 8450, Loss: 0.0000
# Epoch 8500, Loss: 0.0000
# Epoch 8550, Loss: 0.0000
# Epoch 8600, Loss: 0.0000
# Epoch 8650, Loss: 0.0000
# Epoch 8700, Loss: 0.0000
# Epoch 8750, Loss: 0.0000
# Epoch 8800, Loss: 0.0000
# Epoch 8850, Loss: 0.0000
# Epoch 8900, Loss: 0.0000
# Epoch 8950, Loss: 0.0000
# Epoch 9000, Loss: 0.0000
# Epoch 9050, Loss: 0.0000
# Epoch 9100, Loss: 0.0000
# Epoch 9150, Loss: 0.0000
# Epoch 9200, Loss: 0.0000
# Epoch 9250, Loss: 0.0000
# Epoch 9300, Loss: 0.0000
# Epoch 9350, Loss: 0.0000
# Epoch 9400, Loss: 0.0000
# Epoch 9450, Loss: 0.0000
# Epoch 9500, Loss: 0.0000
# Epoch 9550, Loss: 0.0000
# Epoch 9600, Loss: 0.0000
# Epoch 9650, Loss: 0.0000
# Epoch 9700, Loss: 0.0000
# Epoch 9750, Loss: 0.0000
# Epoch 9800, Loss: 0.0000
# Epoch 9850, Loss: 0.0000
# Epoch 9900, Loss: 0.0000
# Epoch 9950, Loss: 0.0000
# Epoch 10000, Loss: 0.0000

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np 

def visualize_hidden_states(model, vocab_size=3, seq_len=3, method='pca'):
    model.eval()
    all_seqs = []
    all_hidden_states = []

    # Generate all 27 possible sequences of length 3
    from itertools import product
    sequences = list(product(range(vocab_size), repeat=seq_len))

    for seq in sequences:
        x = torch.tensor(seq, dtype=torch.long).unsqueeze(0)  # shape [1, seq_len]
        with torch.no_grad():
            h = model.encoder(x)  # shape [1, 1, hidden_size]
        all_hidden_states.append(h.squeeze().numpy())
        all_seqs.append("".join(str(s+1) for s in seq))  # label as string e.g., '123'

    X = np.array(all_hidden_states)

    # Reduce to 2D
    if method == 'tsne':
        reducer = TSNE(n_components=2, perplexity=5, init='random', random_state=42)
    else:
        reducer = PCA(n_components=2)
    
    X_2d = reducer.fit_transform(X)

    # Plot
    plt.figure(figsize=(8, 6))
    for i, (x, y) in enumerate(X_2d):
        plt.scatter(x, y, c='blue')
        plt.text(x + 0.1, y, all_seqs[i], fontsize=9)
    
    plt.title(f"Hidden State Representation ({method.upper()})")
    plt.xlabel("Dim 1")
    plt.ylabel("Dim 2")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
visualize_hidden_states(model)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from itertools import product

# Hyperparameters
vocab_size = 3          # Tokens: 0,1,2 (representing 1,2,3)
embedding_dim = 8
hidden_size = 40
seq_len = 3             # window size
long_seq_len = 20       # total length of sequence
num_epochs = 1000

# Model
class RNNEncoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_size, batch_first=True)
    
    def forward(self, x):
        embedded = self.embedding(x)
        _, h = self.rnn(embedded)
        return h  # final hidden state

class RNNDecoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, vocab_size)
    
    def forward(self, x, h):
        embedded = self.embedding(x)
        out, _ = self.rnn(embedded, h)
        return self.fc(out)

class RNNAutoencoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.encoder = RNNEncoder(vocab_size, embedding_dim, hidden_size)
        self.decoder = RNNDecoder(vocab_size, embedding_dim, hidden_size)
    
    def forward(self, x, decoder_input):
        h = self.encoder(x)
        output = self.decoder(decoder_input, h)
        return output

# Instantiate model and optimizer
model = RNNAutoencoder(vocab_size, embedding_dim, hidden_size)
optimizer = optim.Adam(model.parameters(), lr=1e-2)
loss_fn = nn.CrossEntropyLoss()

# Training loop
for epoch in range(num_epochs):
    # Step 1: Generate a long sequence
    long_seq = [random.randint(0, vocab_size - 1) for _ in range(long_seq_len)]

    total_loss = 0
    num_windows = 0

    # Step 2: Slide over 3-token windows
    for i in range(long_seq_len - seq_len + 1):
        window = long_seq[i:i+seq_len]
        x = torch.tensor([window], dtype=torch.long)  # input
        y_true = torch.tensor([window], dtype=torch.long)  # target

        # Step 3: Prepare decoder input with <sos> = 0
        decoder_input = torch.cat([torch.zeros((1, 1), dtype=torch.long), x[:, :-1]], dim=1)

        # Step 4: Forward and backprop
        optimizer.zero_grad()
        y_pred = model(x, decoder_input)
        loss = loss_fn(y_pred.view(-1, vocab_size), y_true.view(-1))
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        num_windows += 1

    if (epoch + 1) % 50 == 0:
        avg_loss = total_loss / num_windows
        print(f"Epoch {epoch+1}, Avg Loss per window: {avg_loss:.4f}")
# Out:
# Epoch 50, Avg Loss per window: 0.0006
# Epoch 100, Avg Loss per window: 0.0002
# Epoch 150, Avg Loss per window: 0.0001
# Epoch 200, Avg Loss per window: 0.0000
# Epoch 250, Avg Loss per window: 0.0000
# Epoch 300, Avg Loss per window: 0.0000
# Epoch 350, Avg Loss per window: 0.0000
# Epoch 400, Avg Loss per window: 0.0000
# Epoch 450, Avg Loss per window: 0.0000
# Epoch 500, Avg Loss per window: 0.0000
# Epoch 550, Avg Loss per window: 0.0000
# Epoch 600, Avg Loss per window: 0.0000
# Epoch 650, Avg Loss per window: 0.0000
# Epoch 700, Avg Loss per window: 0.0000
# Epoch 750, Avg Loss per window: 0.0000
# Epoch 800, Avg Loss per window: 0.0000
# Epoch 850, Avg Loss per window: 0.0000
# Epoch 900, Avg Loss per window: 0.0000
# Epoch 950, Avg Loss per window: 0.0000
# Epoch 1000, Avg Loss per window: 0.0000

# %%
# Visualization
def visualize_hidden_states(model, vocab_size=3, seq_len=3, method='pca'):
    model.eval()
    all_seqs = []
    all_hidden_states = []

    # Generate all 27 possible sequences of length 3
    sequences = list(product(range(vocab_size), repeat=seq_len))

    for seq in sequences:
        x = torch.tensor(seq, dtype=torch.long).unsqueeze(0)  # shape [1, 3]
        with torch.no_grad():
            h = model.encoder(x)  # shape [1, 1, hidden_size]
        all_hidden_states.append(h.squeeze().numpy())
        all_seqs.append("".join(str(s + 1) for s in seq))  # label e.g., '123'

    X = np.array(all_hidden_states)

    # Reduce to 2D
    if method == 'tsne':
        reducer = TSNE(n_components=2, perplexity=5, init='random', random_state=42)
    else:
        reducer = PCA(n_components=2)

    X_2d = reducer.fit_transform(X)

    # Plot
    plt.figure(figsize=(8, 6))
    for i, (x, y) in enumerate(X_2d):
        plt.scatter(x, y, c='blue')
        plt.text(x + 0.1, y, all_seqs[i], fontsize=9)
    plt.title(f"Hidden State Representation ({method.upper()})")
    plt.xlabel("Dim 1")
    plt.ylabel("Dim 2")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Call this after training:
visualize_hidden_states(model, method='pca')  # or use method='tsne'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random

# Hyperparameters
vocab_size = 3          # Tokens: 0,1,2 (for 1,2,3)
embedding_dim = 8
hidden_size = 40
seq_len = 20            # Length of streaming sequence
context_len = 3         # How many past tokens to reconstruct
batch_size = 1
num_epochs = 1000

# Model components
class RNNEncoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_size, batch_first=True)

    def forward(self, x, h_prev=None):
        emb = self.embedding(x)
        out, h = self.rnn(emb, h_prev)
        return out, h  # out: [batch, 1, hidden_size], h: [1, batch, hidden_size]

class RNNDecoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size, context_len):
        super().__init__()
        self.rnn = nn.RNN(hidden_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, vocab_size)
        self.context_len = context_len

    def forward(self, h_context):
        # h_context: [batch, context_len, hidden_size]
        out, _ = self.rnn(h_context)
        logits = self.fc(out)  # [batch, context_len, vocab_size]
        return logits

# Full streaming autoencoder
class StreamingRNNAutoencoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size, context_len):
        super().__init__()
        self.encoder = RNNEncoder(vocab_size, embedding_dim, hidden_size)
        self.decoder = RNNDecoder(vocab_size, embedding_dim, hidden_size, context_len)
        self.hidden_size = hidden_size
        self.context_len = context_len

    def forward(self, x):
        batch_size, seq_len = x.size()
        h_prev = torch.zeros(1, batch_size, self.hidden_size)

        losses = []
        criterion = nn.CrossEntropyLoss()
        context_buffer = []

        for t in range(seq_len):
            token_t = x[:, t].unsqueeze(1)  # shape: [batch, 1]
            _, h_prev = self.encoder(token_t, h_prev)
            context_buffer.append(h_prev.squeeze(0).clone())  # [batch, hidden_size]

            if len(context_buffer) < self.context_len:
                continue

            # Collect last `context_len` hidden states
            h_context = torch.stack(context_buffer[-self.context_len:], dim=1)  # [batch, context_len, hidden_size]

            # Get true tokens to predict (previous 3 tokens)
            target_tokens = x[:, max(0, t - self.context_len + 1):t + 1]
            if target_tokens.size(1) < self.context_len:
                # Pad with zeros on the left if not enough context
                pad_len = self.context_len - target_tokens.size(1)
                pad = torch.zeros(batch_size, pad_len, dtype=torch.long)
                target_tokens = torch.cat([pad, target_tokens], dim=1)

            logits = self.decoder(h_context)  # [batch, context_len, vocab_size]
            loss = criterion(logits.view(-1, vocab_size), target_tokens.view(-1))
            losses.append(loss)

        return sum(losses) / len(losses)


# Instantiate model
model = StreamingRNNAutoencoder(vocab_size, embedding_dim, hidden_size, context_len)
optimizer = optim.Adam(model.parameters(), lr=1e-2)

# Training loop
for epoch in range(num_epochs):
    seq = [random.randint(0, vocab_size - 1) for _ in range(seq_len)]
    x = torch.tensor(seq, dtype=torch.long).unsqueeze(0)  # shape: [1, seq_len]

    optimizer.zero_grad()
    loss = model(x)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 100 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 100, Loss: 0.0002
# Epoch 200, Loss: 0.0001
# Epoch 300, Loss: 0.0001
# Epoch 400, Loss: 0.0001
# Epoch 500, Loss: 0.0001
# Epoch 600, Loss: 0.0000
# Epoch 700, Loss: 0.0000
# Epoch 800, Loss: 0.0000
# Epoch 900, Loss: 0.0000
# Epoch 1000, Loss: 0.0000

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from itertools import product
import numpy as np

def visualize_hidden_states(model, vocab_size=3, seq_len=3, method='pca'):
    model.eval()
    all_hidden_states = []
    all_labels = []

    with torch.no_grad():
        for seq in product(range(vocab_size), repeat=seq_len):
            x = torch.tensor(seq, dtype=torch.long).unsqueeze(0)  # [1, seq_len]
            h_prev = torch.zeros(1, 1, model.hidden_size)
            context_buffer = []

            for t in range(seq_len):
                token_t = x[:, t].unsqueeze(1)  # [1, 1]
                _, h_prev = model.encoder(token_t, h_prev)
                context_buffer.append(h_prev.squeeze(0).clone())  # [1, hidden_size]

            # Grab the last 3 hidden states (entire sequence, since seq_len = 3)
            h_stack = torch.stack(context_buffer[-seq_len:], dim=1)  # [1, 3, hidden_size]
            avg_context = h_stack.mean(dim=1).squeeze(0).numpy()     # [hidden_size]

            all_hidden_states.append(avg_context)
            all_labels.append("".join(str(d + 1) for d in seq))

    X = np.array(all_hidden_states)

    if method == 'tsne':
        reducer = TSNE(n_components=2, perplexity=5, init='random', random_state=42)
    else:
        reducer = PCA(n_components=2)

    X_2d = reducer.fit_transform(X)

    plt.figure(figsize=(8, 6))
    for i, (x, y) in enumerate(X_2d):
        plt.scatter(x, y, c='blue')
        plt.text(x + 0.1, y, all_labels[i], fontsize=9)

    plt.title(f"RNN Context Representation ({method.upper()})")
    plt.xlabel("Dim 1")
    plt.ylabel("Dim 2")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
visualize_hidden_states(model, method='pca')   # or method='tsne'
